# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Выделение dev-корпуса, как в бейзлайне:

# %%
texts, ids = [], []
with open('train_reviews.txt', encoding = 'utf-8') as f:
    for line in f:
        text_id, text = line.rstrip('\r\n').split('\t')
        texts.append(text)
        ids.append(text_id)

# %%
train_texts, dev_texts, train_ids, dev_ids = train_test_split(texts, ids)

# %%
train_aspects, dev_aspects = [], []
with open('train_aspects.txt', encoding = 'utf-8') as f:
    for line in f:
        line = line.rstrip('\r\n')
        text_id = line.split('\t')[0]
        if text_id in train_ids:
            train_aspects.append(line)
        if text_id in dev_ids:
            dev_aspects.append(line)

# %%
train_sentiment, dev_sentiment = [], []
with open('train_cats.txt') as f:
    for line in f:
        line = line.rstrip('\r\n')
        text_id = line.split('\t')[0]
        if text_id in train_ids:
            train_sentiment.append(line)
        if text_id in dev_ids:
            dev_sentiment.append(line)

# %%
with open('train_split_aspects.txt', 'w') as f:
    for l in train_aspects:
        print(l, file=f)
with open('dev_aspects.txt', 'w') as f:
    for l in dev_aspects:
        print(l, file=f)
with open('train_split_reviews.txt', 'w') as f:
    for i, l in zip(train_ids, train_texts):
        print(i, l, sep="\t", file=f)
with open('dev_reviews.txt', 'w') as f:
    for i, l in zip(dev_ids, dev_texts):
        print(i, l, sep="\t", file=f)
with open('train_split_cats.txt', 'w') as f:
    for l in train_sentiment:
        print(l, file=f)
with open('dev_cats.txt', 'w') as f:
    for l in dev_sentiment:
        print(l, file=f)

# %%
import pandas as pd

# %%
import csv

# %%
train_asp = pd.read_csv(
    'train_split_aspects.txt', 
    delimiter='\t', 
    names=['text_id', 'category', 'mention', 'start', 'end', 'sentiment']
)
train_texts = pd.read_csv('train_split_reviews.txt', delimiter='\t', names=['text_id','text'])

# %%
train_asp
# Out:
#       text_id  category                   mention  start  end sentiment
# 0       30808     Whole                 ресторане     16   25   neutral
# 1       30808  Interior              первом этаже     43   55   neutral
# 2       30808     Whole     руководству ресторана    124  145  positive
# 3       30808   Service  обслуживающему персоналу    147  171  positive
# 4       30808   Service               сотрудникам    189  200  positive
# ...       ...       ...                       ...    ...  ...       ...
# 3561    16630   Service              обслуживание     85   97  positive
# 3562    16630      Food                       Еда     99  102  positive
# 3563    16630   Service                 персоналу    244  253  positive
# 3564    16630     Whole                  ресторан    294  302  positive
# 3565    16630     Whole                     место    315  320  positive
#
# [3566 rows x 6 columns]

# %%
train_texts
# Out:
#      text_id                                               text
# 0       2468  Итак, начну с конца. ПОНРАВИЛОСЬ ВСЁ!!! Наверн...
# 1      22975  Недавно посетила данный ресторан,я согласна со...
# 2      33912  Добрый день! Были с подружкой еще две недели н...
# 3      38772  Наша семья в восторге от данного ресторана!!! ...
# 4       9870  Семейное торжество отмечали в Амадеусе 30 мая ...
# ..       ...                                                ...
# 208    33816  Праздновали здесь юбилей подруги. Довольны оче...
# 209    18372  Ресторанчик очень милый.бывала там не раз!Гото...
# 210    16676  Зашел в это местечко после работы поужинать. В...
# 211    36926  Добрый день! Первый раз пишу отзыв о ресторане...
# 212    35904  27.04.2013 Посетила ваш ресторан Евразия,с сем...
#
# [213 rows x 2 columns]

# %%
from pymorphy2 import MorphAnalyzer
from pymorphy2.tokenizers import simple_word_tokenize

# %%
punct = '/.,:;!?"<>(){}[]*-+'
m = MorphAnalyzer()
def normalize_text(text):
    lemmas = []
    for t in simple_word_tokenize(text):
        if t not in punct:
            lemmas.append(
                m.parse(t)[0].normal_form
            )
    return ' '.join(lemmas)

# %% [markdown]
# Добавление столбца с текстами отзывов, токенизированными и лемматизированными

# %%
train_texts['texts_normalized'] = [normalize_text(t) for t in train_texts['text']]
train_texts
# Out:
#      text_id                                               text  \
# 0       2468  Итак, начну с конца. ПОНРАВИЛОСЬ ВСЁ!!! Наверн...
# 1      22975  Недавно посетила данный ресторан,я согласна со...
# 2      33912  Добрый день! Были с подружкой еще две недели н...
# 3      38772  Наша семья в восторге от данного ресторана!!! ...
# 4       9870  Семейное торжество отмечали в Амадеусе 30 мая ...
# ..       ...                                                ...
# 208    33816  Праздновали здесь юбилей подруги. Довольны оче...
# 209    18372  Ресторанчик очень милый.бывала там не раз!Гото...
# 210    16676  Зашел в это местечко после работы поужинать. В...
# 211    36926  Добрый день! Первый раз пишу отзыв о ресторане...
# 212    35904  27.04.2013 Посетила ваш ресторан Евразия,с сем...
#
#                                       texts_normalized
# 0    итак начать с конец понравиться всё наверное я...
# 1    недавно посетить данный ресторан я согласный с...
# 2    добрый день быть с подружка ещё два неделя наз...
# 3    наш семья в восторг от данный ресторан жить не...
# 4    семейный торжество отмечать в амадеуса 30 май ...
# ..                                                 ...
# 208  праздновать здесь юбилей подруга довольный оче...
# 209  ресторанчик очень милый бывать там не раз гото...
# 210  зайти в это местечко после работа поужинать вс...
# 211  добрый день первый раз писать отзыв о ресторан...
# 212  27 04 2013 посетить ваш ресторан евразия с сем...
#
# [213 rows x 3 columns]

# %%
train_texts_list = train_texts['texts_normalized'].to_list()
train_texts_list_of_lists = []
for elem in train_texts_list:
    train_texts_list_of_lists.append(elem.split(' '))

# %%
train_asp['mention_lemmatized'] = [normalize_text(m) for m in train_asp['mention']]
train_asp
# Out:
#       text_id  category                   mention  start  end sentiment  \
# 0       30808     Whole                 ресторане     16   25   neutral
# 1       30808  Interior              первом этаже     43   55   neutral
# 2       30808     Whole     руководству ресторана    124  145  positive
# 3       30808   Service  обслуживающему персоналу    147  171  positive
# 4       30808   Service               сотрудникам    189  200  positive
# ...       ...       ...                       ...    ...  ...       ...
# 3561    16630   Service              обслуживание     85   97  positive
# 3562    16630      Food                       Еда     99  102  positive
# 3563    16630   Service                 персоналу    244  253  positive
# 3564    16630     Whole                  ресторан    294  302  positive
# 3565    16630     Whole                     место    315  320  positive
#
#           mention_lemmatized
# 0                   ресторан
# 1                первый этаж
# 2       руководство ресторан
# 3     обслуживающий персонал
# 4                  сотрудник
# ...                      ...
# 3561            обслуживание
# 3562                     еда
# 3563                персонал
# 3564                ресторан
# 3565                   место
#
# [3566 rows x 7 columns]

# %%
from collections import defaultdict, Counter

# %%
def get_mention_category(data, cat_type):
    mention_categories = data.value_counts(subset=['mention_lemmatized', cat_type])
    mention_categories_dict = defaultdict(dict)
    for key, value in mention_categories.items():
        mention_categories_dict[key[0]][key[1]] = value
    return {k: Counter(v).most_common(1)[0][0] for k, v in mention_categories_dict.items()}

# %% [markdown]
# Как в бейзлайне, подсчет самой частотной категории для каждого индикатора аспекта:

# %%
counted_cat_for_mention = get_mention_category(train_asp, 'category')
counted_cat_for_mention
# Out:
# {'ресторан': 'Whole',
#  'обслуживание': 'Service',
#  'интерьер': 'Interior',
#  'официант': 'Service',
#  'заведение': 'Whole',
#  'кухня': 'Food',
#  'место': 'Whole',
#  'блюдо': 'Food',
#  'еда': 'Food',
#  'цена': 'Price',
#  'персонал': 'Service',
#  'официантка': 'Service',
#  'порция': 'Food',
#  'пиво': 'Food',
#  'салат': 'Food',
#  'меню': 'Food',
#  'атмосфера': 'Interior',
#  'десерт': 'Food',
#  'встретить': 'Service',
#  'девушка': 'Service',
#  'музыка': 'Interior',
#  'обстановка': 'Interior',
#  'администратор': 'Service',
#  'обслуживать': 'Service',
#  'сервис': 'Service',
#  'зал': 'Interior',
#  'горячий': 'Food',
#  'ждать': 'Service',
#  'кафе': 'Whole',
#  'паста': 'Food',
#  'напиток': 'Food',
#  'мясо': 'Food',
#  'вино': 'Food',
#  'вечер': 'Whole',
#  'принести': 'Service',
#  'столик': 'Interior',
#  'поесть': 'Food',
#  'соус': 'Food',
#  'пицца': 'Food',
#  'суп': 'Food',
#  'живой музыка': 'Interior',
#  'ролл': 'Food',
#  'заказать': 'Service',
#  'молодой человек': 'Service',
#  'закуска': 'Food',
#  'приготовить': 'Food',
#  'заказ': 'Service',
#  'счёт': 'Price',
#  'стол': 'Interior',
#  'чай': 'Food',
#  'рыба': 'Food',
#  'шашлык': 'Food',
#  'готовить': 'Food',
#  'ресторанчик': 'Whole',
#  'сушить': 'Food',
#  'провести время': 'Whole',
#  'диванчик': 'Interior',
#  'съесть': 'Food',
#  'обслуживающий персонал': 'Service',
#  'проводить': 'Service',
#  'предложить': 'Service',
#  'вкус': 'Food',
#  'помочь': 'Service',
#  'поужинать': 'Food',
#  'скидка': 'Price',
#  'заказать столик': 'Service',
#  'торт': 'Food',
#  'кальян': 'Food',
#  'алкоголь': 'Food',
#  'кофе': 'Food',
#  'приносить': 'Service',
#  'местечко': 'Whole',
#  'диван': 'Interior',
#  'стейк': 'Food',
#  'рассказать': 'Service',
#  'паб': 'Whole',
#  'человек': 'Service',
#  'принести меню': 'Service',
#  'повар': 'Service',
#  'коктейль': 'Food',
#  'мороженое': 'Food',
#  'впечатление': 'Whole',
#  'выпить': 'Food',
#  'выбор блюдо': 'Food',
#  'свет': 'Interior',
#  'оформить': 'Food',
#  'ценник': 'Price',
#  'покушать': 'Food',
#  'сотрудник': 'Service',
#  'тирамис': 'Food',
#  'мужчина': 'Service',
#  'заказ принять': 'Service',
#  'работать': 'Service',
#  'курица': 'Food',
#  'девушка официантка': 'Service',
#  'встречать': 'Service',
#  'ребята': 'Service',
#  'менеджер': 'Service',
#  'мебель': 'Interior',
#  'улыбаться': 'Service',
#  'горячее': 'Food',
#  'салат цезарь': 'Food',
#  'кушать': 'Food',
#  'говядина': 'Food',
#  'дача': 'Whole',
#  'стул': 'Interior',
#  'чебурек': 'Food',
#  'овощ': 'Food',
#  'чек': 'Price',
#  'бизнес-ланч': 'Food',
#  'пообедать': 'Food',
#  'шеф-повар': 'Service',
#  'аппетит': 'Whole',
#  'пить': 'Food',
#  'чаевой': 'Service',
#  'хлеб': 'Food',
#  'помещение': 'Interior',
#  'отдохнуть': 'Whole',
#  'бармен': 'Service',
#  'подходить': 'Service',
#  'принять заказ': 'Service',
#  'обслужить': 'Service',
#  'потанцевать': 'Interior',
#  'перекусить': 'Food',
#  'зал для некурящий': 'Interior',
#  'зал для курящий': 'Interior',
#  'котлетка': 'Food',
#  'детский комната': 'Interior',
#  'дизайн': 'Interior',
#  'праздник': 'Whole',
#  'салями': 'Food',
#  'горячий блюдо': 'Food',
#  'ужин': 'Food',
#  'посуда': 'Interior',
#  'зала': 'Interior',
#  'свеча': 'Interior',
#  'свинин': 'Food',
#  'свинина': 'Food',
#  'арагви': 'Whole',
#  'барный стойка': 'Interior',
#  'попить': 'Food',
#  'шампанский': 'Food',
#  'попробовать': 'Food',
#  'бар': 'Whole',
#  'посоветовать': 'Service',
#  'посещение': 'Whole',
#  'телятина': 'Food',
#  'посадить': 'Service',
#  'прибор': 'Interior',
#  'фрукт': 'Food',
#  'столик заказать': 'Service',
#  'есть': 'Food',
#  'вид из окно': 'Interior',
#  'нельсон паб': 'Whole',
#  'филадельфия': 'Food',
#  'заказ принести': 'Service',
#  'веранда': 'Interior',
#  'супчик': 'Food',
#  'второй этаж': 'Interior',
#  'выбор алкоголь': 'Food',
#  'администрация': 'Service',
#  'цезарь с креветка': 'Food',
#  'сыр': 'Food',
#  'цезарь': 'Food',
#  'управлять': 'Service',
#  'ужинать': 'Food',
#  'устрица': 'Food',
#  'заказывать': 'Service',
#  'рис': 'Food',
#  'освещение': 'Interior',
#  'подать': 'Service',
#  'закуска к пиво': 'Food',
#  'подушка': 'Interior',
#  'соотношение цена качество': 'Price',
#  'подаваться': 'Service',
#  'подать меню': 'Service',
#  'итальянский кухня': 'Food',
#  'соотношение цена и качество': 'Price',
#  'палочка': 'Food',
#  'столик забронировать': 'Service',
#  'запечь': 'Food',
#  'здороваться': 'Service',
#  'первый зал': 'Interior',
#  'пирожное': 'Food',
#  'пивоварня': 'Food',
#  'стена': 'Interior',
#  'занавесочка': 'Interior',
#  'стейк из лосось': 'Food',
#  'заказывать столик': 'Service',
#  'стейк из тунец': 'Food',
#  'подойти': 'Service',
#  'подсказать': 'Service',
#  'продукт': 'Food',
#  'сок': 'Food',
#  'кальять зал': 'Interior',
#  'основный блюдо': 'Food',
#  'масло': 'Food',
#  'организовать': 'Service',
#  'оливка': 'Food',
#  'овощ на гриль': 'Food',
#  'место для танец': 'Interior',
#  'ресторан roll & roll': 'Whole',
#  'провести вечер': 'Whole',
#  'обедать': 'Food',
#  'проводить до столик': 'Service',
#  'проводить к стол': 'Service',
#  'разнообразие': 'Food',
#  'размер порция': 'Food',
#  'проводить к столик': 'Service',
#  'мясной': 'Food',
#  'мясной блюдо': 'Food',
#  'радио': 'Interior',
#  'провожать': 'Service',
#  'программа': 'Interior',
#  'макароны': 'Food',
#  'лосось': 'Food',
#  'предупредить': 'Service',
#  'свежевыжать сок': 'Food',
#  'каминный зал': 'Interior',
#  'оформление зал': 'Interior',
#  'оформление блюдо': 'Food',
#  'качество блюдо': 'Food',
#  'качество еда': 'Food',
#  'качество приготовление': 'Food',
#  'свободный столик': 'Interior',
#  'китайский кухня': 'Food',
#  'наесться': 'Food',
#  'свадебный зал': 'Interior',
#  'лаваш': 'Food',
#  'санторинить': 'Whole',
#  'салатик': 'Food',
#  'креветка': 'Food',
#  'салат из тунец': 'Food',
#  'отношение': 'Service',
#  'рыбка': 'Food',
#  'отдать': 'Service',
#  'осьминог': 'Food',
#  'рассказывать': 'Service',
#  'японский кухня': 'Food',
#  'убираться': 'Service',
#  'выпилить': 'Food',
#  'выносить': 'Service',
#  'деньга': 'Price',
#  'хачапури': 'Food',
#  'выпечка': 'Food',
#  'тарелка': 'Interior',
#  'блюдо из мясо': 'Food',
#  'вечером': 'Whole',
#  'тарелка к пиво': 'Food',
#  'визит': 'Whole',
#  'токио': 'Whole',
#  'дать меню': 'Service',
#  'декор': 'Interior',
#  'два палочка': 'Whole',
#  'америкать': 'Food',
#  'винный карта': 'Food',
#  'чукк салат': 'Food',
#  'баклажан': 'Food',
#  'виски': 'Food',
#  'гардероб': 'Interior',
#  'телевизор': 'Interior',
#  'бифштекс': 'Food',
#  'терраса': 'Whole',
#  'банкетный зал': 'Interior',
#  'тесто': 'Food',
#  'гарнир': 'Food',
#  'белый вино': 'Food',
#  'водка': 'Food',
#  'танец': 'Interior',
#  'украсить': 'Interior',
#  'тортик': 'Food',
#  'выбор': 'Food',
#  'утка по-пекински': 'Food',
#  'второй блюдо': 'Food',
#  'бронировать столик': 'Service',
#  'встреча': 'Service',
#  'шоколадный фонтан': 'Food',
#  'десерт тирамис': 'Food',
#  'уносить': 'Service',
#  'шеф повар': 'Food',
#  'упаковать': 'Service',
#  'детский меню': 'Food',
#  'ведущий': 'Service',
#  'сырный тарелка': 'Food',
#  'провести до столик': 'Service',
#  'приём': 'Whole',
#  'проводить до место': 'Service',
#  'прощаться': 'Service',
#  'профессионал': 'Service',
#  'хачапури по-аджарски': 'Food',
#  'пропитка': 'Food',
#  'приправить': 'Food',
#  'прожарка': 'Food',
#  'прожарить': 'Food',
#  'хинкали': 'Food',
#  'хозяин': 'Whole',
#  'провести там время': 'Whole',
#  'хлебный корзина': 'Food',
#  'проводить до наш столик': 'Service',
#  'хлебный козинка': 'Food',
#  'харбин на приморский': 'Whole',
#  'хачапури с сыр': 'Food',
#  'проводить за столик': 'Service',
#  'фуа-грой': 'Food',
#  'проём окно': 'Interior',
#  'стульчик для кормление': 'Interior',
#  'фроузный парфе': 'Food',
#  'публика': 'Interior',
#  'разложить прибор': 'Service',
#  'фокачча с прованский трава и сыр пармезан': 'Food',
#  'фиш & чипс': 'Food',
#  'фирменный блюдо': 'Food',
#  'разнообразие в меню': 'Food',
#  'филе норвежский лосось с овощ и креветка': 'Food',
#  'разрешать': 'Service',
#  'расположить': 'Interior',
#  'расположиться': 'Whole',
#  'фантанчик': 'Interior',
#  'уютный': 'Interior',
#  'рататуй': 'Food',
#  'уют': 'Interior',
#  'результат вместе с чаевой': 'Price',
#  'рекомендовать': 'Service',
#  'ухо': 'Food',
#  'ресторан la fabrik': 'Whole',
#  'разливный пиво': 'Food',
#  'раздеть-проводить': 'Service',
#  'фондю': 'Food',
#  'французский кухня': 'Food',
#  'пустой помещение': 'Interior',
#  'пшеничный и ячменный пиво': 'Food',
#  'пюре': 'Food',
#  'работа': 'Service',
#  'франческо': 'Whole',
#  'работа она выполнять': 'Service',
#  'холодное напиток': 'Food',
#  'равиоли с трюфель и рикоттой': 'Food',
#  'фонтан в центр зал': 'Interior',
#  'равиолли с гриб': 'Food',
#  'рагу': 'Food',
#  'французский красный сухой вино': 'Food',
#  'форель запечь с овощ': 'Food',
#  'развлекательный программа': 'Interior',
#  'развлекательный программа ресторан': 'Interior',
#  'холодное закуска': 'Food',
#  'приветливый': 'Service',
#  'холодный закуска': 'Food',
#  'помогать': 'Service',
#  'шашлык из свинин': 'Food',
#  'пол порция': 'Food',
#  'полента': 'Whole',
#  'шашлык из лосось': 'Food',
#  'полумрак': 'Interior',
#  'полусухой': 'Food',
#  'шашлык из курица': 'Food',
#  'помидор': 'Food',
#  'шашлык из куриный грудка': 'Food',
#  'шашлык ягнёнок': 'Food',
#  'помочь с выбор': 'Service',
#  'шашлык из баранина на кость и мякоть': 'Food',
#  'попилить': 'Food',
#  'шатёр': 'Whole',
#  'шаверма с курица': 'Food',
#  'поприветствовать': 'Service',
#  'шаверма': 'Food',
#  'поработать': 'Service',
#  'показывать': 'Service',
#  'показать': 'Service',
#  'принести специя': 'Service',
#  'подача блюдо': 'Service',
#  'японский и итальянский кухня': 'Food',
#  'яблочный пирог': 'Food',
#  'эспрессо': 'Food',
#  'штора': 'Interior',
#  'подача': 'Service',
#  'шпинат с голубой сыр под фантастический заправка': 'Food',
#  'шоу программа': 'Interior',
#  'шоу': 'Interior',
#  'поиинтересоваться': 'Service',
#  'шоколадный шкатулка': 'Food',
#  'подождать': 'Service',
#  'шницель': 'Food',
#  'подоконник': 'Interior',
#  'шеф-повар ресторан': 'Service',
#  'шеф': 'Service',
#  'швейцар': 'Service',
#  'порекомендовать': 'Service',
#  'порция салат': 'Food',
#  'чистота скатерть': 'Interior',
#  'цезарь с лосось': 'Food',
#  'предложить присесть': 'Service',
#  'предложить сесть': 'Service',
#  'предложить столик': 'Service',
#  'предоставить': 'Service',
#  'цена на кальян': 'Price',
#  'цена на вино': 'Price',
#  'цезарь-салат': 'Food',
#  'утка в апельсиновый соус': 'Food',
#  'приглашать': 'Service',
#  'посадить за столик': 'Service',
#  'цезарь с курица': 'Food',
#  'цветочный композиция': 'Interior',
#  'цветовой решение': 'Interior',
#  'приготовление': 'Food',
#  'цвет': 'Interior',
#  'хочухарчо': 'Whole',
#  'хостёс': 'Service',
#  'принести мы заказ': 'Service',
#  'предложить напиток': 'Service',
#  'ценовой категория': 'Price',
#  'предложить меню': 'Service',
#  'чаемый': 'Food',
#  'посетитель vip-зал': 'Interior',
#  'чипсы': 'Food',
#  'посидеть': 'Whole',
#  'послевкусие': 'Food',
#  'чердак художник': 'Whole',
#  'чебурек с сыр сулугуни и зелень': 'Food',
#  'чаплин-холл': 'Whole',
#  'чай с чабрец': 'Food',
#  'чай с лимон и чабрец': 'Food',
#  'чай с десерт': 'Food',
#  'чай по восточный с инжирный варение': 'Food',
#  'появиться': 'Service',
#  'предварительный резервация': 'Service',
#  'предлагать': 'Service',
#  'чаемый с пирожное': 'Food',
#  'предлагать попробовать': 'Service',
#  'ресторан « кирочный двор »': 'Whole',
#  'ресторан трес амигос': 'Whole',
#  'утка': 'Food',
#  'советовать': 'Service',
#  'смотреть за посетитель': 'Service',
#  'смотреть за стол': 'Service',
#  'смузи злаковый': 'Food',
#  'смузи овощной': 'Food',
#  'собеседник': 'Service',
#  'собрать': 'Service',
#  'совет': 'Service',
#  'тиммерманс': 'Food',
#  'тест': 'Food',
#  'следить за стол': 'Service',
#  'повор': 'Food',
#  'солёный': 'Food',
#  'солёный гриб': 'Food',
#  'твинс': 'Whole',
#  'тбилисо': 'Whole',
#  'сорбета': 'Food',
#  'состав десерт': 'Food',
#  'тарелка фрукт': 'Food',
#  'слушать': 'Service',
#  'скульптура': 'Interior',
#  'сотрудник данный заведение': 'Whole',
#  'сельдь под шуба … с краб': 'Food',
#  'свинина по-пекински': 'Food',
#  'свинина с моцарелла и гриб': 'Food',
#  'свиной рулька': 'Food',
#  'свободный место': 'Interior',
#  'торт тирамис на десерт': 'Food',
#  'торт из шоколад': 'Food',
#  'томатный суп': 'Food',
#  'сделать заказ': 'Service',
#  'селёдка': 'Food',
#  'скорость': 'Service',
#  'сервировать': 'Service',
#  'томатный паста': 'Food',
#  'сервировка': 'Food',
#  'сервировка блюдо': 'Food',
#  'сетевой заведение японский кухня': 'Whole',
#  'скатерть': 'Service',
#  'тирам': 'Food',
#  'скидочный карта': 'Price',
#  'тарелка убираться': 'Service',
#  'сотрудник ресторан': 'Service',
#  'ресторан волна': 'Whole',
#  'суп чанахи': 'Food',
#  'сыр филадельфия': 'Food',
#  'стоимость ужин': 'Price',
#  'счёт мы принести': 'Service',
#  'суша-бар': 'Whole',
#  'суп-харчо': 'Food',
#  'суп-пюре из белый гриб': 'Food',
#  'стол для рисование': 'Interior',
#  'стол забронировать': 'Service',
#  'стол обслуживать': 'Service',
#  'сырный корочка и базилик': 'Food',
#  'суп с норвежский лосось': 'Food',
#  'суп из печёный чеснок': 'Food',
#  'суп из морепрдукт': 'Food',
#  'суп из два рыба': 'Food',
#  'столик не заказывать': 'Service',
#  'столовая': 'Interior',
#  'судак с овощ и рис': 'Food',
#  'стрейк нью-йорк': 'Food',
#  'сырный и мясной тарелка': 'Food',
#  'стейк-хаус': 'Whole',
#  'соус из петрушка': 'Food',
#  'срок ожидание': 'Service',
#  'соус к мясо и картофель': 'Food',
#  'соус тара-тара': 'Food',
#  'спагетти': 'Food',
#  'спагетти карбонар': 'Food',
#  'спагетти с фрикаделька': 'Food',
#  'спиртной напиток': 'Food',
#  'спокойный': 'Interior',
#  'спрашивать': 'Service',
#  'стейк из говядина с шпинат': 'Food',
#  'сырный палочка': 'Food',
#  'танцполый': 'Interior',
#  'тамада': 'Service',
#  'таверна': 'Interior',
#  'стейк из мраморный говядина': 'Food',
#  'сытый хавронья из свинин': 'Food',
#  'стейк рибай': 'Food',
#  'стейк с соус из белый гриб': 'Food',
#  'сырный шарик': 'Food',
#  'свинина в кисло-сладкий соус': 'Food',
#  'трапеза итальянский кухня': 'Food',
#  'траттория чили пицца': 'Whole',
#  'угощение': 'Food',
#  'ролл запечь на уголь': 'Food',
#  'ролл на гриль': 'Food',
#  'ролл филадельфияй': 'Food',
#  'рубить котлетка из лосось и судак с голландский соус и белый спаржа': 'Food',
#  'руккола с креветка': 'Food',
#  'руководство ресторан': 'Whole',
#  'рулет из лосось с зелёный спаржа': 'Food',
#  'рулетик с гриб': 'Food',
#  'рыба-стейк из форель': 'Food',
#  'рис с курица': 'Food',
#  'угорь': 'Food',
#  'уголок': 'Interior',
#  'убирать': 'Service',
#  'салат греческий': 'Food',
#  'салат грибной': 'Food',
#  'салат из лисичка с кроличий печень': 'Food',
#  'ролл без рис': 'Food',
#  'ризотто с спраж и горгонзола': 'Food',
#  'светлый зал': 'Interior',
#  'ресторан палкин': 'Whole',
#  'утиный грудка гриль с фрукт': 'Food',
#  'ресторан гламур': 'Whole',
#  'ресторан крапива': 'Whole',
#  'ресторан мисо': 'Whole',
#  'ресторан на приморский': 'Whole',
#  'усадить': 'Service',
#  'управлять ресторан': 'Service',
#  'ресторан оливье': 'Whole',
#  'ресторан русский китч': 'Whole',
#  'украшение зал': 'Interior',
#  'судак': 'Food',
#  'ресторан фаворит': 'Whole',
#  'ресторан харбин на академический': 'Whole',
#  'ресторан харбин на приморский': 'Whole',
#  'ресторан эскалибур': 'Whole',
#  'улитка': 'Food',
#  'рибай': 'Food',
#  'ризотто с белый гриб': 'Food',
#  'салат из лосось': 'Food',
#  'салат из морепродукт': 'Food',
#  'салат из руккола с печёный картофель': 'Food',
#  'туалет': 'Interior',
#  'салат с угорь': 'Food',
#  'салат салмона с лосось': 'Food',
#  'тунец с овощ гриль': 'Food',
#  'салат цезарь с креветка': 'Food',
#  'тунец': 'Food',
#  'салатик оливье': 'Food',
#  'туалет с аквариум': 'Interior',
#  'сан': 'Whole',
#  'сануть': 'Food',
#  'салат из язык и морепродукт': 'Food',
#  'саперави': 'Whole',
#  'сацивить из баклажан': 'Food',
#  'трефо': 'Whole',
#  'свежесварить пиво': 'Food',
#  'свежий': 'Food',
#  'свежий овощ': 'Food',
#  'трес амигос': 'Whole',
#  'тревелс': 'Whole',
#  'салат с тёплый куриный печень': 'Food',
#  'салат с руккола и вяленый помидор': 'Food',
#  'тёплый мексиканский салат': 'Food',
#  'салат с малосольный лосось': 'Food',
#  'салат кавказский': 'Food',
#  'салат лагуна': 'Food',
#  'салат на закуска': 'Food',
#  'салат от шеф-повар с курица': 'Food',
#  'тёртый сыр': 'Food',
#  'салат пампелона': 'Food',
#  'салат розан': 'Food',
#  'салат с авокадо': 'Food',
#  'салат с апельсин руккола и лосось': 'Food',
#  'салат с говядина': 'Food',
#  'салат с домашний сыр': 'Food',
#  'салат с креветка': 'Food',
#  'салат с креветка и краб': 'Food',
#  'салат с куриный печень': 'Food',
#  'тёплый салат из говядина': 'Food',
#  'салат с лосось': 'Food',
#  'салат с лосось краб тунец': 'Food',
#  'соление': 'Food',
#  '1450-1750р с человек': 'Price',
#  'по цена': 'Price',
#  'девушка-официант': 'Service',
#  'девушка-певица': 'Interior',
#  'девушко-официантка': 'Service',
#  'декорирование': 'Interior',
#  'декорированный': 'Interior',
#  'деликатес': 'Food',
#  'делфима бар': 'Whole',
#  'депозит 5 тыс': 'Price',
#  'десерт с банан': 'Food',
#  'десерт семифреддый': 'Food',
#  'диванчик-купе': 'Interior',
#  'директор': 'Service',
#  'дисконтный карта': 'Service',
#  'дитая': 'Whole',
#  'добавлять вино': 'Service',
#  'доедать': 'Food',
#  'домашний куриный супчик': 'Food',
#  'домашний лимонад': 'Food',
#  'домашний мороженое': 'Food',
#  'домашний морс': 'Food',
#  'допинг': 'Food',
#  'дорада с овощ': 'Food',
#  'дорогой': 'Price',
#  'доска с мелок': 'Interior',
#  'драник с бекон': 'Food',
#  'дуглас': 'Whole',
#  'девушка-официантка': 'Service',
#  'девушка хостёс': 'Service',
#  'европейский кухня': 'Food',
#  'девушка официант': 'Service',
#  'главный зал': 'Interior',
#  'глинтвейн': 'Food',
#  'глобус': 'Whole',
#  'говядина по-дижонск': 'Food',
#  'голос солистка': 'Interior',
#  'горячий полотенце': 'Interior',
#  'гость': 'Service',
#  'готовиться': 'Food',
#  'гранд-кафе 21 верста': 'Whole',
#  'гребешок': 'Food',
#  'гребешок с спаржа': 'Food',
#  'грейпфрут': 'Food',
#  'гриб': 'Food',
#  'гроссенштрасса': 'Whole',
#  'грузинский вино': 'Food',
#  'грузинский танцевальный коллектив': 'Interior',
#  'дамский комната': 'Interior',
#  'дать': 'Service',
#  'два этаж': 'Interior',
#  'двор': 'Interior',
#  'девочки-официантка': 'Service',
#  'девушка из гардероб': 'Service',
#  'девушка мария': 'Service',
#  'европейский и японский блюдо': 'Food',
#  'европейский меню': 'Food',
#  'карбонар': 'Food',
#  'запечь сушить': 'Food',
#  'запечёный': 'Food',
#  'запивать': 'Food',
#  'запоминать': 'Service',
#  'заправка': 'Food',
#  'зелень': 'Food',
#  'зелень с овощ': 'Food',
#  'знать меню': 'Service',
#  'зона для курящий': 'Interior',
#  'зонирование': 'Interior',
#  'империя': 'Whole',
#  'ингридиент': 'Food',
#  'инегридиент': 'Food',
#  'интерьер зал': 'Interior',
#  'интерьер ресторан': 'Interior',
#  'итальянский блюдо': 'Food',
#  'итальянский ресторан': 'Whole',
#  'итоговый сумма': 'Price',
#  'кальмар': 'Food',
#  'кальянщик': 'Service',
#  'камин': 'Interior',
#  'канадский ролл': 'Food',
#  'капреза': 'Food',
#  'каракатица': 'Food',
#  'караоке': 'Interior',
#  'запечь сыр': 'Food',
#  'запечь картошка': 'Food',
#  'еда приносить': 'Service',
#  'запечь баклажан': 'Food',
#  'жан-жак': 'Whole',
#  'жареный камамбер': 'Food',
#  'жареный осьминог': 'Food',
#  'жарить крылышко': 'Food',
#  'ждать ещё минута': 'Service',
#  'ждать заказ': 'Service',
#  'жевать': 'Food',
#  'живопись': 'Interior',
#  'забирать': 'Service',
#  'забронировать': 'Service',
#  'забронировать стол': 'Service',
#  'завернуть с себя': 'Service',
#  'заказ быть выполнить': 'Service',
#  'заказ быть принять': 'Service',
#  'заказ столик': 'Service',
#  'заказать заранее': 'Service',
#  'заказать обычный столик': 'Service',
#  'заказать по купон': 'Service',
#  'заказывать стол': 'Service',
#  'закусок-крыло': 'Food',
#  'закусочка': 'Food',
#  'закусывать': 'Food',
#  'зал для курящий и некурящий': 'Interior',
#  'занавеска': 'Interior',
#  'гардеробщик': 'Service',
#  'гардеробный': 'Interior',
#  'выслушать': 'Service',
#  'базилик': 'Whole',
#  'банкет': 'Whole',
#  'банкетный меню': 'Food',
#  'бараний ножка': 'Food',
#  'барный карта': 'Food',
#  'бекон на хрустеть тост с помидор черри': 'Food',
#  'берест светлый': 'Food',
#  'бесплатно': 'Price',
#  'бесплатный': 'Price',
#  'бефстроганов с пюре': 'Food',
#  'бивштекс': 'Food',
#  'биза с сливка и фрукт': 'Food',
#  'бизнес ланч': 'Food',
#  'бизнес-ланча': 'Food',
#  'билл-хук': 'Whole',
#  'блинчик с мясо': 'Food',
#  'блюдо восточный кухня': 'Food',
#  'блюдо европейский кухня': 'Food',
#  'блюдо и напиток выноситься': 'Service',
#  'блюдо из меню': 'Food',
#  'блюдо из мясо на мангал': 'Food',
#  'блюдо из осьминог': 'Food',
#  'блюдо китайский кухня': 'Food',
#  'блюдо на гриль': 'Food',
#  'блюдо садж': 'Food',
#  'бокал': 'Interior',
#  'баклажан запечь с сыр': 'Food',
#  'ассортимент ролл': 'Food',
#  'выполнение заказ': 'Service',
#  'ассортимент блюдо': 'Food',
#  '2 этаж': 'Interior',
#  '2ом этаж': 'Interior',
#  'da albertone': 'Whole',
#  'le glamure': 'Whole',
#  'mon petit cafe': 'Whole',
#  'vip зона': 'Interior',
#  'админ': 'Service',
#  'администратор екатерина': 'Service',
#  'администратор ирина': 'Service',
#  'азиатский такой кухня': 'Food',
#  'аквариум': 'Interior',
#  'алкогольный коктейль': 'Food',
#  'алкогольный напиток': 'Food',
#  'альмонд': 'Food',
#  'амадеуса': 'Whole',
#  'америка': 'Food',
#  'америка маки': 'Food',
#  'аниматор': 'Service',
#  'антураж': 'Interior',
#  'апельсиновый сок': 'Food',
#  'апрель': 'Whole',
#  'асаха': 'Whole',
#  'ассортимент': 'Food',
#  'ассортимент бар': 'Food',
#  'бокал коньяк': 'Food',
#  'бокал красный сухой вино': 'Food',
#  'больший окно': 'Interior',
#  'больший порция': 'Food',
#  'восточный экспресс': 'Whole',
#  'впечатление от паб': 'Whole',
#  'впечатление от посещение': 'Whole',
#  'времяпрепровождение': 'Whole',
#  'вручить меню': 'Service',
#  'всё убирать': 'Service',
#  'второе': 'Food',
#  'второй зал': 'Interior',
#  'выбор алкогольный коктейль': 'Food',
#  'выбор вино': 'Food',
#  'выбор горячее': 'Food',
#  'выбор горячий блюдо': 'Food',
#  'выбор десерт': 'Food',
#  'выбор еда': 'Food',
#  'выбор закуска': 'Food',
#  'выбор коктейль': 'Food',
#  'выбор место': 'Whole',
#  'выбор пиво': 'Food',
#  'выбор по меню и напиток': 'Food',
#  'выбор салат': 'Food',
#  'выбрать': 'Service',
#  'вынести': 'Service',
#  'выпекать': 'Food',
#  'выпивка': 'Food',
#  'выпить пиво': 'Food',
#  'восточный салат': 'Food',
#  'вок': 'Food',
#  'вода': 'Food',
#  'вареник': 'Food',
#  'большой выбор': 'Food',
#  'борщ с копчёность': 'Food',
#  'бронирование столик': 'Service',
#  'бронирование столик по телефон': 'Service',
#  'бронировать': 'Service',
#  'бронировать стол': 'Service',
#  'бронь столик': 'Service',
#  'бульон с мясо': 'Food',
#  'бутылка вино': 'Food',
#  'бытылочко вино': 'Food',
#  'вайнштефан светлый': 'Food',
#  'васаби': 'Whole',
#  'внимание': 'Service',
#  'вентиляция': 'Interior',
#  'верхний этаж': 'Interior',
#  'вечер пройти': 'Whole',
#  'винишко': 'Food',
#  'вино красный домашний': 'Food',
#  'вишня': 'Food',
#  'вишнёвый штрудель': 'Food',
#  'вкус блюдо': 'Food',
#  'владелец': 'Service',
#  'внешний вид зал': 'Interior',
#  'караоке-программа': 'Interior',
#  'кармашек с гриб и рыба': 'Food',
#  'площадь ресторан': 'Whole',
#  'невский': 'Food',
#  'недорогой': 'Price',
#  'некурящий зал': 'Interior',
#  'нести': 'Service',
#  'нести заказ': 'Service',
#  'нижний зал': 'Interior',
#  'няня': 'Service',
#  'облицовка стена': 'Interior',
#  'обслуга': 'Service',
#  'обслуживающий': 'Service',
#  'обстановка в ресторан': 'Interior',
#  'обстановка ресторан': 'Interior',
#  'обтановка': 'Interior',
#  'общий впечатление': 'Whole',
#  'общий мнение': 'Whole',
#  'общий оценка ресторан': 'Whole',
#  'объесться': 'Food',
#  'овощ с моцарелла': 'Food',
#  'овощной гарнир': 'Food',
#  'окно': 'Interior',
#  'омлет по-баварски': 'Food',
#  'оргазм': 'Food',
#  'организация работа': 'Service',
#  'основной зал': 'Interior',
#  'оставить': 'Service',
#  'невский 166': 'Whole',
#  'небо': 'Whole',
#  'острый': 'Food',
#  'не курящий зал': 'Interior',
#  'мороженный': 'Food',
#  'морс': 'Food',
#  'морс из натуральный клюква': 'Food',
#  'мраморный говядина': 'Food',
#  'мужчина из гардероб': 'Service',
#  'музыкальный коллектив': 'Interior',
#  'музыкальный фон': 'Interior',
#  'мясной нарезка': 'Food',
#  'мясной стейк': 'Food',
#  'мясной сырный рыбный тарелка': 'Food',
#  'мясной чипсы из говядина': 'Food',
#  'мясо и рыба гриль': 'Food',
#  'мясо на мангал': 'Food',
#  'мясо утка': 'Food',
#  'на вкус': 'Food',
#  'набор блюдо': 'Food',
#  'найти': 'Service',
#  'накладывать': 'Service',
#  'накопительный скидка': 'Service',
#  'накрыть стол': 'Service',
#  'налить': 'Service',
#  'наполеон': 'Food',
#  'народ быть не очень много': 'Interior',
#  'настойка': 'Food',
#  'настроение': 'Whole',
#  'оставить 10 тысяча': 'Price',
#  '1ом этаж': 'Interior',
#  'карпачо сибас': 'Food',
#  'паста карбонар': 'Food',
#  'паста с креветка': 'Food',
#  'паста с лосось': 'Food',
#  'паулайнер': 'Whole',
#  'паэлить с курица и кролик': 'Food',
#  'пенна 4 сыр': 'Food',
#  'пенна с утка': 'Food',
#  'первый блюдо': 'Food',
#  'первый этаж': 'Interior',
#  'перепробовать': 'Food',
#  'пересесть': 'Service',
#  'перечный стейк': 'Food',
#  'персонал паберти': 'Service',
#  'персонал ресторан': 'Service',
#  'перчик халапена': 'Food',
#  'песня': 'Interior',
#  'петь': 'Interior',
#  'печёный груша': 'Food',
#  'пивко': 'Food',
#  'пивная тарелка': 'Food',
#  'пивной бар': 'Whole',
#  'пиво хугарден': 'Food',
#  'пирожок к первый блюдо': 'Food',
#  'пицца на тонкий тест': 'Food',
#  'плата': 'Price',
#  'плов': 'Food',
#  'паста с гриб сливка и томатный паста': 'Food',
#  'паста 4 сыр': 'Food',
#  'ответить': 'Service',
#  'парковщик': 'Service',
#  'ответить на мой вопрос': 'Service',
#  'отвечать': 'Service',
#  'отдельный зал': 'Interior',
#  'открытый кухня': 'Interior',
#  'открыть': 'Service',
#  'открыть дверь': 'Service',
#  'отношение к клиент': 'Service',
#  'отношение к свой дело': 'Service',
#  'отношение официант': 'Service',
#  'отношение персонал': 'Service',
#  'офицантка': 'Service',
#  'официант-бармен': 'Service',
#  'официатка': 'Service',
#  'оформление стена': 'Interior',
#  'охрана': 'Interior',
#  'охранник': 'Service',
#  'очерёдность блюдо': 'Service',
#  'паб джон донна': 'Whole',
#  'паб метрополь': 'Whole',
#  'паберти': 'Whole',
#  'палкин': 'Whole',
#  'палтус': 'Food',
#  'палтус запечь': 'Food',
#  'панакот': 'Food',
#  'панакот с клубничный пюре': 'Food',
#  'морковь': 'Food',
#  'молочный улуна': 'Food',
#  'молочный и алкогольный коктейль': 'Food',
#  'колечко лука': 'Food',
#  'коллектив официант': 'Service',
#  'колонка': 'Interior',
#  'кольцо кальмар в кляр': 'Food',
#  'комната': 'Interior',
#  'комната для караоке': 'Interior',
#  'комплимент': 'Service',
#  'комплимент от шеф-повар': 'Service',
#  'комплимент-апперетив': 'Food',
#  'компьютер': 'Interior',
#  'кон-коронель': 'Whole',
#  'кондитерский': 'Whole',
#  'корзина': 'Food',
#  'кормить': 'Food',
#  'королевский креветка с соус': 'Food',
#  'котлета с пюре': 'Food',
#  'котлетка из лосось и креветка': 'Food',
#  'котлетка из лосось с пюре': 'Food',
#  'котлетка из телятина с пюре': 'Food',
#  'кофе борджиа': 'Food',
#  'кофе капуччиный': 'Food',
#  'кофе-десерт': 'Food',
#  'крабовый суп': 'Food',
#  'крапива': 'Whole',
#  'красный вино': 'Food',
#  'красный рыба': 'Food',
#  'количество': 'Food',
#  'кол-в закуска': 'Food',
#  'молодой человек-администратор': 'Service',
#  'коктель': 'Food',
#  'карпаччо': 'Food',
#  'карпаччо из говядина': 'Food',
#  'карпаччо из утиный грудка': 'Food',
#  'карта с скидка': 'Price',
#  'картина': 'Interior',
#  'картофель айдахо': 'Food',
#  'картофель фри': 'Food',
#  'кафе кон-коронель': 'Whole',
#  'кафе-бар': 'Whole',
#  'качество вино': 'Food',
#  'качество кухня': 'Food',
#  'качество мясо': 'Food',
#  'качество напиток': 'Food',
#  'качество обслуживание': 'Service',
#  'кеталонский крем': 'Food',
#  'китайский ресторан': 'Whole',
#  'китайский ресторанчик': 'Whole',
#  'клиент': 'Service',
#  'клубничный маргарита': 'Food',
#  'клубничный суп': 'Food',
#  'клубничный чай': 'Food',
#  'клубнчный десерт': 'Food',
#  'кокосовый суп с морепродукт': 'Food',
#  'кокосовый шота': 'Food',
#  'коктейльный напиток': 'Food',
#  'красный сухой': 'Food',
#  ...}

# %%
import math

# %%
def tfidf(corpus):
    words_list = []
    for doc in corpus:
        for word in doc:
            word_counter = 0
            for doc1 in corpus:
                if word in doc1:
                    word_counter +=1 
            tf = doc.count(word)/len(doc)
            idf = math.log(len(corpus)/word_counter)
            tf_idf = tf*idf
            word_tuple = [word, tf_idf]
            words_list.append(word_tuple)
    return words_list

# %%
tfidf_data = tfidf(train_texts_list_of_lists)
tfidf_data[0:100]
# Out:
# [['итак', 0.0247491450482182],
#  ['начать', 0.02292802600270439],
#  ['с', 0.0018503383464409026],
#  ['конец', 0.01875872060485249],
#  ['понравиться', 0.013973767269876751],
#  ['всё', 0.0067703512708671325],
#  ['наверное', 0.02084337330377844],
#  ['я', 0.008682872911763319],
#  ['консерватор', 0.038849943229778444],
#  ['так', 0.017099591026218313],
#  ['к', 0.005850835319629596],
#  ['любить', 0.019726339391986716],
#  ['заведение', 0.007096127036489446],
#  ['именно', 0.03663882350222042],
#  ['такой', 0.008713109292389517],
#  ['план', 0.03382713757354696],
#  ['хороший', 0.004403637497123627],
#  ['интерьер', 0.0044663770822186595],
#  ['негромкий', 0.02586617896000993],
#  ['музыка', 0.010797761991315465],
#  ['спокойный', 0.017513428887992642],
#  ['атмосфера', 0.013296606094878722],
#  ['вежливый', 0.01396597797988608],
#  ['и', 0.0012049174062083291],
#  ['учтивый', 0.030888984616241417],
#  ['персонал', 0.009552470274455617],
#  ['решить', 0.011940000717428387],
#  ['отметить', 0.014203585391646883],
#  ['свой', 0.009061002185044303],
#  ['день', 0.007563797479515324],
#  ['рождение', 0.014203585391646883],
#  ['недалеко', 0.0247491450482182],
#  ['от', 0.010501950436820864],
#  ['дом', 0.021473890528340974],
#  ['долго', 0.012302395069418687],
#  ['выбирать', 0.027187349661415398],
#  ['местечко', 0.0494982900964364],
#  ['чтоб', 0.061777969232482834],
#  ['пешком', 0.038849943229778444],
#  ['дойти', 0.030888984616241417],
#  ['ребёнок', 0.02084337330377844],
#  ['пристроить', 0.038849943229778444],
#  ['в', 0.0011527058327874],
#  ['детский', 0.02586617896000993],
#  ['комната', 0.021473890528340974],
#  ['ну', 0.03164113529509391],
#  ['и', 0.0012049174062083291],
#  ['по', 0.006488290196049575],
#  ['отзыв', 0.013086551479855154],
#  ['чтоб', 0.061777969232482834],
#  ['быть', 0.004716795248363711],
#  ['более-менее', 0.038849943229778444],
#  ['выбор', 0.009426443153355115],
#  ['пасть', 0.03382713757354696],
#  ['именно', 0.03663882350222042],
#  ['на', 0.002765335806830048],
#  ['этот', 0.010217742370492737],
#  ['ресторанчик', 0.021473890528340974],
#  ['зал', 0.008713109292389517],
#  ['быть', 0.004716795248363711],
#  ['пустой', 0.020263353682955714],
#  ['наполовину', 0.038849943229778444],
#  ['девушка', 0.011765380778449687],
#  ['сам', 0.012683871399023194],
#  ['предложить', 0.015524756093052351],
#  ['местечко', 0.0494982900964364],
#  ['в', 0.0011527058327874],
#  ['угол', 0.030888984616241417],
#  ['для', 0.007373092346780735],
#  ['мы', 0.002786655241223556],
#  ['я', 0.008682872911763319],
#  ['супруг', 0.06765427514709392],
#  ['и', 0.0012049174062083291],
#  ['сын', 0.030888984616241417],
#  ['6', 0.027187349661415398],
#  ['год', 0.01645108487210949],
#  ['блюдо', 0.005551973301266921],
#  ['который', 0.010217742370492737],
#  ['заказать', 0.009180779735415394],
#  ['понравиться', 0.013973767269876751],
#  ['всё', 0.0067703512708671325],
#  ['без', 0.015240548026724223],
#  ['исключение', 0.02880433191731547],
#  ['супруг', 0.06765427514709392],
#  ['понравиться', 0.013973767269876751],
#  ['приготовить', 0.02084337330377844],
#  ['овощ', 0.02084337330377844],
#  ['салат', 0.008600760114592666],
#  ['цезарь', 0.02084337330377844],
#  ['тоже', 0.010358453137573186],
#  ['на', 0.002765335806830048],
#  ['слава', 0.02880433191731547],
#  ['лосось', 0.017513428887992642],
#  ['-без', 0.038849943229778444],
#  ['вопрос', 0.020263353682955714],
#  ['и', 0.0012049174062083291],
#  ['так', 0.017099591026218313],
#  ['далее', 0.02378152626108398],
#  ['официантка', 0.010797761991315465],
#  ['следить', 0.027187349661415398]]

# %% [markdown]
# Беру 1000 вхождений с самым большим tf * idf (частотны в пределах документа, в корпусе - не очень). Можно видеть, что это в основном специальная лексика

# %%
tf_idf_df = pd.DataFrame(tfidf_data, columns = ['word', 'word_tfidf'])
tf_idf_df.sort_values(by="word_tfidf", ascending=False).head(1000)
# Out:
#            word  word_tfidf
# 20693   палочка    0.176156
# 20742   палочка    0.176156
# 7557      майкл    0.147288
# 7636      майкл    0.147288
# 7593      майкл    0.147288
# ...         ...         ...
# 19801    важный    0.055359
# 19931    важный    0.055359
# 6254    ужинать    0.055359
# 6292   подавать    0.055359
# 6267    русский    0.055359
#
# [1000 rows x 2 columns]

# %%
tf_idf_df1 = tf_idf_df.sort_values(by="word_tfidf", ascending=False).head(2000)
rare_words = tf_idf_df1['word'].to_list()
rare_words
# Out:
# ['палочка',
#  'палочка',
#  'майкл',
#  'майкл',
#  'майкл',
#  'майкл',
#  'майкл',
#  'квас',
#  'квас',
#  'квас',
#  'квас',
#  'roll',
#  'roll',
#  'roll',
#  'roll',
#  '260р',
#  '260р',
#  'молодец',
#  'молодец',
#  'случайный',
#  'случайный',
#  'нельсон',
#  'нельсон',
#  'нельсон',
#  'чукк',
#  'чукк',
#  'базилик',
#  'базилик',
#  'прежний',
#  'прежний',
#  'арагви',
#  'арагви',
#  'арагви',
#  'выпечка',
#  'выпечка',
#  '–',
#  '–',
#  'харбин',
#  'приморский',
#  'харбин',
#  'харбин',
#  'приморский',
#  'харбин',
#  'приморский',
#  'приморский',
#  'долгожданный',
#  'знающий',
#  'привыкнуть',
#  'осьминог',
#  'осьминог',
#  'осьминог',
#  'крапива',
#  'крапива',
#  'салями',
#  'салями',
#  'салями',
#  'пиво',
#  'пиво',
#  'пиво',
#  'пиво',
#  'пиво',
#  'работа',
#  'работа',
#  'работа',
#  'детский',
#  'детский',
#  'детский',
#  'детский',
#  'детский',
#  'детский',
#  'более',
#  'более',
#  'более',
#  'банкет',
#  'банкет',
#  'банкет',
#  'солёный',
#  'солёный',
#  'испортиться',
#  'испортиться',
#  'попадать',
#  'расслаблять',
#  'словно',
#  'обед',
#  'звучать',
#  'запоминться',
#  'упаковывать',
#  'китайский',
#  'китайский',
#  'китайский',
#  'руб',
#  'руб',
#  'руб',
#  'руб',
#  'шестеро',
#  'площадь',
#  'повелеть',
#  'москва',
#  'вновь',
#  'вновь',
#  'удивить',
#  'удивить',
#  'империя',
#  'санкт-петербург',
#  'империя',
#  'два',
#  'два',
#  'удаваться',
#  'отзывчивый',
#  'устрица',
#  'устрица',
#  'устрица',
#  'состав',
#  'баклажан',
#  'баклажан',
#  'состав',
#  '15мина',
#  'картинка',
#  'хрустальный',
#  'резиновый',
#  'glamure',
#  'le',
#  'кат',
#  '2013г',
#  'пиво',
#  'пиво',
#  'пиво',
#  'пиво',
#  'пиво',
#  'пиво',
#  'пиво',
#  'пиво',
#  'токио',
#  'токио',
#  'вдруг',
#  'вдруг',
#  'мясо',
#  'мясо',
#  'мясо',
#  'мясо',
#  'гарнир',
#  'гарнир',
#  'мороженое',
#  'мороженое',
#  'приготовить',
#  'приготовить',
#  'терраса',
#  'терраса',
#  'терраса',
#  'устроить',
#  'устроить',
#  'назвать',
#  'санторинить',
#  'моджо',
#  'полупустой',
#  '1ом',
#  'санторинить',
#  'котлетка',
#  'котлетка',
#  'котлетка',
#  'котлетка',
#  'распитие',
#  'распитие',
#  'смузи',
#  'смузи',
#  'о',
#  'о',
#  'о',
#  'о',
#  'о',
#  'о',
#  'о',
#  'мальчик',
#  'блинчик',
#  'мороженный',
#  'иногда',
#  'иногда',
#  'иногда',
#  'умело',
#  'умело',
#  '23',
#  '23',
#  'трудно',
#  'создать',
#  'ломоносов',
#  'невероятно',
#  'команда',
#  'евразия',
#  'мастер',
#  'бивштекс',
#  'надолго',
#  'сказка',
#  'этаж',
#  'этаж',
#  'итальянский',
#  'цезарь',
#  'цезарь',
#  'итальянский',
#  'бахра',
#  'всяческий',
#  'праздничный',
#  'профессиональный',
#  'узнавать',
#  'обслуживание-очень',
#  'впечатлять',
#  'столь',
#  'кальян-супер',
#  'закусок-крыло',
#  'фрукты-всё',
#  'десятый',
#  'бармен',
#  'бармен',
#  'бармен',
#  'бармен',
#  'гребешок',
#  'гребешок',
#  'холодильник',
#  'холодильник',
#  'холодильник',
#  'коллега',
#  'коллега',
#  'порадовало--порция',
#  'девушка-певица',
#  'сине-белый',
#  'людно',
#  'олёк',
#  'вновь',
#  'благодарный',
#  'палтус',
#  'палтус',
#  'отличие',
#  'отличие',
#  'отличие',
#  'палкин',
#  'палкин',
#  'несколько',
#  'несколько',
#  'пиво',
#  'пиво',
#  'пиво',
#  'пиво',
#  'пиво',
#  'корпоратив',
#  'красота',
#  'поменять',
#  'заметить',
#  'заметить',
#  'ролл',
#  'ролл',
#  'ролл',
#  'ролл',
#  'оч',
#  'оч',
#  'при',
#  'при',
#  'при',
#  'при',
#  'при',
#  'особенный',
#  'креветка',
#  'креветка',
#  'креветка',
#  'креветка',
#  'кон-коронель',
#  'новогодний',
#  'новогодний',
#  'кон-коронель',
#  'предложный',
#  'предложный',
#  'снаружи',
#  'запах',
#  'замечательный',
#  'замечательный',
#  'замечательный',
#  'стейк',
#  'стейк',
#  'стейк',
#  'свинина',
#  'скорее',
#  'свинина',
#  'свинина',
#  'скорее',
#  'дизайн',
#  'дизайн',
#  'стоящий',
#  'складываться',
#  'заставлять',
#  'прилично',
#  '400',
#  'обходительный',
#  'сок',
#  'сок',
#  'сок',
#  'банкет',
#  'банкет',
#  'восточный',
#  'восточный',
#  'восточный',
#  'восточный',
#  'вино',
#  'вино',
#  'вино',
#  'вино',
#  '2ом',
#  'оч',
#  'оба',
#  'кто',
#  'кто',
#  'паб',
#  'паб',
#  'паб',
#  'расслабиться',
#  'свадебный',
#  'свадебный',
#  'свадебный',
#  'расслабиться',
#  'рядом',
#  'рядом',
#  'палочка',
#  'палочка',
#  'палочка',
#  'желание',
#  'желание',
#  'мамин',
#  'сравнительно',
#  'ибо',
#  'милый',
#  'милый',
#  'завернуть',
#  'завернуть',
#  'проводиться',
#  '–',
#  '–',
#  '–',
#  'поставить',
#  'поставить',
#  'поставить',
#  'марина',
#  'г',
#  '04',
#  '27',
#  'помогать',
#  'помогать',
#  'отдых',
#  '23',
#  'ремонт',
#  'светло',
#  'розан',
#  'н-р',
#  'алёна',
#  'оттуда',
#  'руководство',
#  'любезный',
#  'подготовить',
#  'назначить',
#  'г',
#  'небольшой',
#  'небольшой',
#  'лично',
#  'лично',
#  'супчик',
#  'причём',
#  'причём',
#  'привередливый',
#  'шт',
#  'шт',
#  'редкость',
#  'petit',
#  'cafe',
#  'натура',
#  'mon',
#  'оливье',
#  'оливье',
#  'поблагодарить',
#  'балл',
#  'припарковаться',
#  'отзывчивый',
#  'душа',
#  'большинство',
#  'дружеский',
#  'залив',
#  'руб',
#  'детский',
#  'детский',
#  'ощущение',
#  'грузинский',
#  '00',
#  'руб',
#  '00',
#  'чувствовать',
#  'руб',
#  'оргазм',
#  'никаий',
#  'маргарита',
#  '--',
#  'ненавящивый',
#  '--',
#  'сан',
#  'зависеть',
#  'зависеть',
#  '2013',
#  'питер',
#  'потом',
#  'потом',
#  'потом',
#  'ли',
#  'ли',
#  'там',
#  'там',
#  'там',
#  'там',
#  'учитывать',
#  '2013',
#  '16',
#  'рекомендация',
#  'живот',
#  'раздавать',
#  'приготовления-',
#  'полагать',
#  'тяжело',
#  'таверна',
#  'тип',
#  'выносить',
#  'выносить',
#  'осилить',
#  'незабываемый',
#  'ребёнок',
#  'ребёнок',
#  'ребёнок',
#  'ребёнок',
#  'ребёнок',
#  'нигде',
#  'нигде',
#  'счёт',
#  'счёт',
#  'счёт',
#  'счёт',
#  'счёт',
#  'счёт',
#  'рис',
#  'рис',
#  'рис',
#  'март',
#  'март',
#  'ризотто',
#  'томатный',
#  'рыбный',
#  'событие',
#  'событие',
#  'суп-пюре',
#  'чеснок',
#  'navex',
#  'китч',
#  'там',
#  'там',
#  'там',
#  'тихий',
#  'посиделки',
#  'шашлык',
#  'шашлык',
#  'шашлык',
#  '380',
#  '380',
#  'кафе',
#  'кафе',
#  'новый',
#  'новый',
#  'новый',
#  'удача',
#  'гостеприимный',
#  '990р',
#  'омлет',
#  'по-баварски',
#  '250р',
#  '5л',
#  'дружественный',
#  'стоимость',
#  'vip',
#  'музыкальный',
#  'почитать',
#  'возникнуть',
#  'сайт',
#  'паб',
#  'паб',
#  'паб',
#  'конечно',
#  'конечно',
#  'освежать',
#  'положиться',
#  'очаровательный',
#  'виктория',
#  'дитая',
#  'традиция',
#  'данные',
#  'виктория',
#  'очаровательный',
#  'годовщина',
#  'январь',
#  'шарик',
#  'апрель',
#  'предоставить',
#  'помидор',
#  'супруг',
#  'супруг',
#  'вцелое',
#  'вцелое',
#  'помидор',
#  'средневековый',
#  'приблизительно',
#  'паберти',
#  'приблизительно',
#  'паберти',
#  'средневековый',
#  'демократичный',
#  'сергей',
#  'сергей',
#  'сергей',
#  'кафе',
#  'кафе',
#  'чердак',
#  'фондю',
#  'откуда',
#  'фрикаделька',
#  'девушка-официант',
#  'качественный',
#  'либо',
#  'либо',
#  'восхитительный',
#  'по-домашнему',
#  'разумный',
#  'чистота',
#  'число',
#  'девочка',
#  'потанцевать',
#  'послушать',
#  'приём',
#  'местный',
#  'еле',
#  'многие',
#  'здесь',
#  'здесь',
#  'здесь',
#  'здесь',
#  'стена',
#  'стена',
#  'предупредить',
#  'предупредить',
#  'год',
#  'год',
#  'год',
#  'ощущение',
#  'ведущий',
#  'рекомендация',
#  '12',
#  'желать',
#  'среднее',
#  'стенка',
#  'стенка',
#  'праздник',
#  'праздник',
#  'что-то',
#  'что-то',
#  'хлеб',
#  'хлеб',
#  'её',
#  'её',
#  'спутник',
#  'пожалуй',
#  'отличный',
#  'отличный',
#  'гостиница',
#  'гостиница',
#  'пиво',
#  'пиво',
#  'пиво',
#  'пиво',
#  'любить',
#  'любить',
#  'чебурек',
#  'чебурек',
#  'чебурек',
#  '21',
#  '21',
#  'селёдка',
#  'усесться',
#  'нарезка',
#  'периодический',
#  'зря',
#  'хугарден',
#  'знакомый',
#  'p',
#  's',
#  'чувствоваться',
#  'спокойно',
#  '2013',
#  '0',
#  '0',
#  'глинтвейн',
#  'морепрдукт',
#  'корочка',
#  'сервировать',
#  'заполненность',
#  'сгладить',
#  'полента',
#  'ненавязичий',
#  'посититель',
#  'шикарный',
#  'семья',
#  'семья',
#  'простой',
#  'трапеза',
#  'расстроить',
#  'хватать',
#  'хватать',
#  'огромный',
#  'огромный',
#  '2014',
#  '13',
#  'прежде',
#  'холодный',
#  'скоро',
#  'накрыть',
#  'понедельник',
#  'советовать',
#  'советовать',
#  'торжество',
#  'торжество',
#  'торжество',
#  'свежевыжать',
#  'свежевыжать',
#  'январь',
#  'свежевыжать',
#  'здравствуйте',
#  'внутри',
#  'пообедать',
#  'пообедать',
#  'паста',
#  'паста',
#  'паста',
#  'паста',
#  'намного',
#  'кофе',
#  'кофе',
#  'чай-',
#  'лицензия',
#  'маки',
#  'клуб',
#  'америка',
#  'наладиться',
#  'медовуха',
#  'твинс',
#  'салат-хорошо',
#  'поиинтересоваться',
#  'хавронья',
#  'далековато',
#  'радость',
#  'америка-',
#  'тёмный',
#  'подозвать',
#  'оливка',
#  'подозвать',
#  'оливка',
#  'острый',
#  'уют',
#  'острый',
#  'тепло',
#  'шеф',
#  'общение',
#  'мороженое',
#  'мороженое',
#  'гриб',
#  'гриб',
#  'чтоб',
#  'чтоб',
#  'суша-бар',
#  '40-50',
#  'пена',
#  'пузырик',
#  'васаби',
#  'выбирать',
#  'выбирать',
#  'выбирать',
#  'дважды',
#  'впрочем',
#  'задержка',
#  'отдельный',
#  'отдельный',
#  'отдельный',
#  '15',
#  '15',
#  '15',
#  'кафе',
#  'кафе',
#  '…',
#  '…',
#  '…',
#  'некурящий',
#  'некурящий',
#  'некурящий',
#  'приятно',
#  'приятно',
#  'приятно',
#  'после',
#  'после',
#  'после',
#  'после',
#  'китайский',
#  'китайский',
#  'оформление',
#  'март',
#  'чудесный',
#  'сергей',
#  'сытно',
#  'воспоминание',
#  'настолько',
#  'настолько',
#  'разный',
#  'соус',
#  'соус',
#  'соус',
#  'розовый',
#  'розовый',
#  'согласный',
#  'шампанский',
#  'чудесно',
#  'оценить',
#  'шампанский',
#  'бифштекс',
#  'несомненно',
#  'бифштекс',
#  'несомненно',
#  'процветание',
#  'тихо',
#  'помогать',
#  'тёплый',
#  'никто',
#  'никто',
#  'паста',
#  'паста',
#  'паста',
#  'паста',
#  'скажешь-',
#  'инцидент',
#  'плова-',
#  'улябаяться',
#  'человеческий',
#  'чёрный',
#  'плотный',
#  'боьша',
#  'намотать',
#  'никогда',
#  'никогда',
#  'барный',
#  'никогда',
#  'барный',
#  'барный',
#  'превосходно',
#  'амигос',
#  'трес',
#  'амигос',
#  'трес',
#  '0',
#  'оттуда',
#  '220р',
#  'чем',
#  'чем',
#  'побывать',
#  'ожидать',
#  'приехать',
#  'чек',
#  'кое-что',
#  'кое-что',
#  'шаверма',
#  'шаверма',
#  'выразить',
#  'повезти',
#  'соотношение',
#  '6',
#  'идеальный',
#  'др',
#  'желать',
#  'течение',
#  'р',
#  'р',
#  'р',
#  'умеренный',
#  'невкусный',
#  'пицца',
#  'пицца',
#  'пицца',
#  'внизу',
#  'ура',
#  'закрываться',
#  'хватить',
#  'еле',
#  'внизу',
#  'где',
#  'где',
#  'карбонар',
#  'томатный',
#  'томатный',
#  'оба',
#  'удачно',
#  'карбонар',
#  'бронировать',
#  'бронировать',
#  'японский',
#  'японский',
#  'японский',
#  'японский',
#  'кальять',
#  'кальять',
#  'неудобно',
#  'усомниться',
#  'свежесть',
#  'любезный',
#  'любезный',
#  'фотография',
#  'фотография',
#  'ребёнок',
#  'ребёнок',
#  'подходить',
#  'подходить',
#  'подходить',
#  'оригинальный',
#  'отменный',
#  'соотношение',
#  'создавать',
#  'примерно',
#  'потрясать',
#  'вообщий',
#  'потрясать',
#  'ответить',
#  'симпатичный',
#  'коллектив',
#  'зона',
#  'гостеприимный',
#  'сказаться',
#  'екатерина',
#  'угорь',
#  'спагетти',
#  'крупный',
#  'художник',
#  'восстание',
#  'мидзук',
#  'жаловаться',
#  'основываться',
#  'водить',
#  'поблизости',
#  'парковаться',
#  'например',
#  'вдвоём',
#  'например',
#  'вдвоём',
#  'котлетка',
#  'хачапури',
#  'котлетка',
#  'хачапури',
#  'небольшой',
#  'небольшой',
#  'пойти',
#  'резко',
#  'получать',
#  'вытереть',
#  'длительный',
#  'нарадоваться',
#  'называть',
#  'всежа',
#  'сильно',
#  'сильно',
#  'сей',
#  'во-первых',
#  'пепельница',
#  'где-то',
#  'где-то',
#  'произвести',
#  'произвести',
#  'десерт',
#  'десерт',
#  'гр',
#  'гр',
#  'радушный',
#  'радушный',
#  'плюс',
#  'плюс',
#  'воля',
#  'воля',
#  'рыбка',
#  'корзина',
#  'рыбка',
#  'корзина',
#  'подготовить',
#  'март',
#  'март',
#  'дача',
#  'дача',
#  'недовольный',
#  'сотрудник',
#  'шикарный',
#  'похвала',
#  'здравствуйте',
#  'быстрый',
#  'мероприятие',
#  'мероприятие',
#  'посетитель',
#  'посетитель',
#  'праздновать',
#  'бар',
#  'бар',
#  'посетить',
#  'посетить',
#  'лаваш',
#  'лаваш',
#  'каминный',
#  'каминный',
#  'мина',
#  'мина',
#  'готовить',
#  'готовить',
#  'суп',
#  'суп',
#  'суп',
#  'суп',
#  'водка',
#  'основный',
#  'наоборот',
#  'многие',
#  'домой',
#  'радушный',
#  'греческий',
#  'оставлять',
#  'оставлять',
#  'основное',
#  'пообедать',
#  'исключение',
#  'перекусить',
#  'прекрасный',
#  'прекрасный',
#  'ребёнок',
#  'давно',
#  'давно',
#  'ребёнок',
#  'сорок',
#  'реальный',
#  'инегридиент',
#  'собиреться',
#  'суперски',
#  'кирочный',
#  'петербург',
#  '47',
#  'украшение',
#  'свободно',
#  'профессионально',
#  'благодарить',
#  'естественный',
#  'присутствие',
#  'фаворит',
#  'иван',
#  'петербург',
#  'ингридиент',
#  'симпатичный',
#  'месяц',
#  'пить',
#  'ощущение',
#  'пить',
#  'бы',
#  'бы',
#  'картофель',
#  'картофель',
#  'картофель',
#  '&',
#  '&',
#  'бывать',
#  'бывать',
#  'паб',
#  'паб',
#  'паб',
#  'возможность',
#  'возможность',
#  'недостаток',
#  'уносить',
#  'выпилить',
#  'ароматный',
#  'рассказывать',
#  'базилик',
#  'предел',
#  'милый',
#  'домашний',
#  'если',
#  'если',
#  'оставлять',
#  'особенно',
#  'особенно',
#  'полностью',
#  'мария',
#  'важный',
#  'важный',
#  'ужинать',
#  'подавать',
#  'русский',
#  ...]

# %%
with open('tfidf_data.txt', 'w') as f:
    f.write (' '.join(rare_words))

# %% [markdown]
# Скачиваем список мебели (поможет определять индикаторы аспекта Interior:

# %%
with open('furnit_list.txt', encoding = 'utf-8') as file:
    f = file.readlines()
    furniture_list = []
    for line in f:
        line = line.rstrip('\r\n').lower()
        furniture_list.append(line)
furniture_list[0:10]#список мебели, может пригодиться для аспекта Interior
# Out:
# ['банкетка',
#  'бар',
#  'бержер',
#  'библиотека',
#  'бинбэг',
#  'буфет',
#  'буфетница',
#  'бюро',
#  'верстак',
#  'вешалка']

# %% [markdown]
# Список блюд, пригодится при определении аспекта Food

# %%
with open('dishes_list_from_wiki.txt', encoding = 'utf-8') as file2:
    f2 = file2.readlines()
    dishes_list = []
    for line in f2:
        line = line.rstrip('\r\n').lower()
        dishes_list.append(line)
dishes_list[0:10] #список блюд (с Википедии)
# Out:
# ['абнабат',
#  'абон',
#  'авголемоно',
#  'агуапанела',
#  'аджапсандали',
#  'аджика',
#  'адобо',
#  'азу',
#  'айвар',
#  'айвовый мармелад']

# %% [markdown]
# Как в бейзлайне, аспектные слова с частотными тональными ярлыками

# %%
counted_sent_for_mention = get_mention_category(train_asp, 'sentiment')
counted_sent_for_mention
# Out:
# {'интерьер': 'positive',
#  'ресторан': 'positive',
#  'обслуживание': 'positive',
#  'место': 'positive',
#  'кухня': 'positive',
#  'официант': 'positive',
#  'заведение': 'positive',
#  'персонал': 'positive',
#  'блюдо': 'positive',
#  'еда': 'positive',
#  'цена': 'positive',
#  'порция': 'positive',
#  'атмосфера': 'positive',
#  'обстановка': 'positive',
#  'музыка': 'positive',
#  'меню': 'positive',
#  'встретить': 'positive',
#  'официантка': 'positive',
#  'девушка': 'positive',
#  'обслуживать': 'positive',
#  'администратор': 'positive',
#  'пиво': 'positive',
#  'салат': 'positive',
#  'зал': 'positive',
#  'десерт': 'positive',
#  'напиток': 'neutral',
#  'ждать': 'negative',
#  'кафе': 'positive',
#  'вечер': 'positive',
#  'поесть': 'positive',
#  'сервис': 'positive',
#  'горячий': 'neutral',
#  'живой музыка': 'positive',
#  'молодой человек': 'positive',
#  'приготовить': 'positive',
#  'стол': 'positive',
#  'столик': 'positive',
#  'паста': 'positive',
#  'провести время': 'positive',
#  'заказ': 'positive',
#  'скидка': 'positive',
#  'помочь': 'positive',
#  'диванчик': 'positive',
#  'суп': 'positive',
#  'предложить': 'positive',
#  'обслуживающий персонал': 'positive',
#  'заказать': 'neutral',
#  'заказать столик': 'neutral',
#  'проводить': 'positive',
#  'вино': 'neutral',
#  'кальян': 'positive',
#  'мясо': 'positive',
#  'соус': 'negative',
#  'закуска': 'positive',
#  'ролл': 'positive',
#  'шашлык': 'positive',
#  'готовить': 'positive',
#  'оформить': 'positive',
#  'чай': 'neutral',
#  'поужинать': 'neutral',
#  'шеф-повар': 'positive',
#  'диван': 'positive',
#  'съесть': 'neutral',
#  'счёт': 'neutral',
#  'принести': 'positive',
#  'рыба': 'positive',
#  'принести меню': 'positive',
#  'рассказать': 'positive',
#  'торт': 'positive',
#  'выпить': 'neutral',
#  'повар': 'positive',
#  'вкус': 'positive',
#  'местечко': 'positive',
#  'ресторанчик': 'neutral',
#  'стейк': 'positive',
#  'человек': 'positive',
#  'коктейль': 'positive',
#  'мороженое': 'positive',
#  'покушать': 'neutral',
#  'чаевой': 'negative',
#  'алкоголь': 'neutral',
#  'отдохнуть': 'positive',
#  'приносить': 'positive',
#  'свет': 'positive',
#  'улыбаться': 'positive',
#  'пицца': 'neutral',
#  'заказ принять': 'positive',
#  'кофе': 'neutral',
#  'бармен': 'positive',
#  'обслужить': 'positive',
#  'чебурек': 'neutral',
#  'аппетит': 'neutral',
#  'овощ': 'positive',
#  'нельсон паб': 'positive',
#  'детский комната': 'positive',
#  'бар': 'positive',
#  'работать': 'positive',
#  'тирамис': 'positive',
#  'телятина': 'positive',
#  'радио': 'positive',
#  'свеча': 'positive',
#  'горячее': 'neutral',
#  'ведущий': 'positive',
#  'сушить': 'positive',
#  'столик заказать': 'neutral',
#  'девушка официантка': 'positive',
#  'ребята': 'positive',
#  'место для танец': 'positive',
#  'мебель': 'positive',
#  'кушать': 'positive',
#  'потанцевать': 'positive',
#  'попробовать': 'positive',
#  'впечатление': 'positive',
#  'ценник': 'negative',
#  'паб': 'positive',
#  'посадить': 'positive',
#  'подходить': 'positive',
#  'встречать': 'positive',
#  'посещение': 'positive',
#  'заказ принести': 'positive',
#  'пообедать': 'neutral',
#  'посуда': 'positive',
#  'посоветовать': 'positive',
#  'сотрудник': 'positive',
#  'выбор алкоголь': 'positive',
#  'прибор': 'positive',
#  'вид из окно': 'positive',
#  'управлять': 'negative',
#  'праздник': 'positive',
#  'супчик': 'positive',
#  'выбор блюдо': 'positive',
#  'заказывать': 'neutral',
#  'салатик': 'neutral',
#  'салат цезарь': 'positive',
#  'котлетка': 'positive',
#  'курица': 'positive',
#  'блюдо из мясо': 'positive',
#  'заказывать столик': 'neutral',
#  'соотношение цена качество': 'positive',
#  'салями': 'neutral',
#  'вечером': 'positive',
#  'сок': 'positive',
#  'бизнес-ланч': 'neutral',
#  'кальять зал': 'positive',
#  'здороваться': 'positive',
#  'каминный зал': 'positive',
#  'качество блюдо': 'positive',
#  'качество приготовление': 'positive',
#  'свинин': 'positive',
#  'занавесочка': 'positive',
#  'зал для некурящий': 'positive',
#  'китайский кухня': 'positive',
#  'зал для курящий': 'neutral',
#  'соотношение цена и качество': 'positive',
#  'стейк из лосось': 'positive',
#  'харбин на приморский': 'negative',
#  'барный стойка': 'positive',
#  'оливка': 'neutral',
#  'организовать': 'positive',
#  'освещение': 'positive',
#  'предупредить': 'positive',
#  'отдать': 'positive',
#  'шеф повар': 'positive',
#  'отношение': 'positive',
#  'администрация': 'positive',
#  'оформление блюдо': 'positive',
#  'оформление зал': 'positive',
#  'провести вечер': 'positive',
#  'палочка': 'negative',
#  'попить': 'positive',
#  'помещение': 'negative',
#  'первый зал': 'positive',
#  'перекусить': 'neutral',
#  'подушка': 'positive',
#  'подсказать': 'positive',
#  'пивоварня': 'positive',
#  'подача блюдо': 'positive',
#  'подать меню': 'positive',
#  'пить': 'positive',
#  'подаваться': 'positive',
#  'принять заказ': 'neutral',
#  'чек': 'negative',
#  'рассказывать': 'positive',
#  'лосось': 'positive',
#  'рис': 'negative',
#  'макароны': 'negative',
#  'менеджер': 'neutral',
#  'ресторан roll & roll': 'positive',
#  'баклажан': 'positive',
#  'мужчина': 'positive',
#  'размер порция': 'positive',
#  'мясной': 'positive',
#  'мясной блюдо': 'positive',
#  'шампанский': 'positive',
#  'наесться': 'positive',
#  'арагви': 'positive',
#  'продукт': 'positive',
#  'программа': 'positive',
#  'провожать': 'positive',
#  'проводить к столик': 'positive',
#  'проводить к стол': 'neutral',
#  'проводить до столик': 'positive',
#  'разнообразие': 'positive',
#  'свадебный зал': 'positive',
#  'токио': 'positive',
#  'дача': 'neutral',
#  'встреча': 'positive',
#  'дизайн': 'positive',
#  'филадельфия': 'positive',
#  'тарелка': 'positive',
#  'тарелка к пиво': 'neutral',
#  'тортик': 'positive',
#  'два палочка': 'positive',
#  'говядина': 'neutral',
#  'второй блюдо': 'neutral',
#  'второй этаж': 'positive',
#  'устрица': 'neutral',
#  'бронировать столик': 'neutral',
#  'ужин': 'positive',
#  'ужинать': 'positive',
#  'сыр': 'positive',
#  'деньга': 'positive',
#  'украсить': 'positive',
#  'декор': 'positive',
#  'убираться': 'positive',
#  'детский меню': 'positive',
#  'уносить': 'positive',
#  'упаковать': 'positive',
#  'хлеб': 'neutral',
#  'десерт тирамис': 'positive',
#  'танец': 'positive',
#  'выносить': 'negative',
#  'телевизор': 'positive',
#  'горячий блюдо': 'positive',
#  'стул': 'negative',
#  'тесто': 'positive',
#  'виски': 'neutral',
#  'цезарь': 'both',
#  'винный карта': 'positive',
#  'есть': 'positive',
#  'визит': 'positive',
#  'готовиться': 'negative',
#  'фрукт': 'negative',
#  'проводить до наш столик': 'neutral',
#  'провести до столик': 'positive',
#  'провести там время': 'positive',
#  'шатёр': 'positive',
#  'проводить до место': 'neutral',
#  'тунец': 'positive',
#  'проводить за столик': 'positive',
#  'тунец с овощ гриль': 'neutral',
#  'ресторан la fabrik': 'positive',
#  'тёплый мексиканский салат': 'positive',
#  'томатный суп': 'neutral',
#  'тёплый салат из говядина': 'positive',
#  'убирать': 'positive',
#  'тёртый сыр': 'neutral',
#  'хлебный корзина': 'positive',
#  'приправить': 'negative',
#  'приём': 'negative',
#  'шашлык из курица': 'positive',
#  'угощение': 'positive',
#  'хозяин': 'neutral',
#  'чердак художник': 'positive',
#  'чипсы': 'positive',
#  'шашлык из куриный грудка': 'positive',
#  'угорь': 'positive',
#  'шашлык из баранина на кость и мякоть': 'neutral',
#  'уголок': 'positive',
#  'ресторан « кирочный двор »': 'neutral',
#  'прожарить': 'positive',
#  'томатный паста': 'negative',
#  'туалет с аквариум': 'positive',
#  'разрешать': 'positive',
#  'прожарка': 'positive',
#  'равиоли с трюфель и рикоттой': 'positive',
#  'трапеза итальянский кухня': 'positive',
#  'рататуй': 'positive',
#  'равиолли с гриб': 'positive',
#  'рагу': 'positive',
#  'развлекательный программа': 'positive',
#  'развлекательный программа ресторан': 'positive',
#  'шаверма': 'negative',
#  'хлебный козинка': 'neutral',
#  'раздеть-проводить': 'positive',
#  'разливный пиво': 'positive',
#  'шаверма с курица': 'negative',
#  'торт тирамис на десерт': 'positive',
#  'разложить прибор': 'positive',
#  'торт из шоколад': 'positive',
#  'расположиться': 'positive',
#  'расположить': 'positive',
#  'траттория чили пицца': 'positive',
#  'чукк салат': 'positive',
#  'чистота скатерть': 'both',
#  'результат вместе с чаевой': 'neutral',
#  'разнообразие в меню': 'positive',
#  'профессионал': 'positive',
#  'прощаться': 'positive',
#  'туалет': 'neutral',
#  'трефо': 'positive',
#  'проём окно': 'negative',
#  'публика': 'positive',
#  'пустой помещение': 'both',
#  'пшеничный и ячменный пиво': 'positive',
#  'рекомендовать': 'positive',
#  'пюре': 'both',
#  'трес амигос': 'positive',
#  'работа': 'positive',
#  'работа она выполнять': 'positive',
#  'тревелс': 'positive',
#  'пропитка': 'positive',
#  'стрейк нью-йорк': 'positive',
#  'фокачча с прованский трава и сыр пармезан': 'neutral',
#  'показывать': 'positive',
#  'форель запечь с овощ': 'positive',
#  'пол порция': 'neutral',
#  'фонтан в центр зал': 'negative',
#  'полента': 'positive',
#  'фондю': 'positive',
#  'полумрак': 'positive',
#  'полусухой': 'positive',
#  'штора': 'negative',
#  'помидор': 'positive',
#  'помогать': 'positive',
#  'шоу программа': 'positive',
#  'помочь с выбор': 'positive',
#  'фиш & чипс': 'positive',
#  'шоу': 'positive',
#  'фирменный блюдо': 'positive',
#  'шоколадный шкатулка': 'positive',
#  'попилить': 'positive',
#  'шпинат с голубой сыр под фантастический заправка': 'positive',
#  'показать': 'positive',
#  'филе норвежский лосось с овощ и креветка': 'positive',
#  'подойти': 'both',
#  'японский кухня': 'neutral',
#  'повор': 'positive',
#  'подать': 'negative',
#  'фуа-грой': 'positive',
#  'хачапури': 'neutral',
#  'подача': 'both',
#  'подождать': 'neutral',
#  'поиинтересоваться': 'positive',
#  'японский и итальянский кухня': 'positive',
#  'яблочный пирог': 'positive',
#  'фроузный парфе': 'positive',
#  'подоконник': 'positive',
#  'хачапури по-аджарски': 'positive',
#  'франческо': 'positive',
#  'французский кухня': 'positive',
#  'французский красный сухой вино': 'positive',
#  'эспрессо': 'neutral',
#  'поприветствовать': 'positive',
#  'принести специя': 'positive',
#  'предоставить': 'positive',
#  'управлять ресторан': 'positive',
#  'предварительный резервация': 'neutral',
#  'предлагать': 'positive',
#  'предлагать попробовать': 'positive',
#  'шеф': 'positive',
#  'предложить меню': 'neutral',
#  'предложить напиток': 'neutral',
#  'предложить присесть': 'positive',
#  'предложить сесть': 'positive',
#  'предложить столик': 'positive',
#  'улитка': 'positive',
#  'появиться': 'positive',
#  'приветливый': 'positive',
#  'украшение зал': 'positive',
#  'ресторан волна': 'neutral',
#  'швейцар': 'positive',
#  'приготовление': 'neutral',
#  'шашлык ягнёнок': 'positive',
#  'шашлык из свинин': 'positive',
#  'шашлык из лосось': 'negative',
#  'принести мы заказ': 'positive',
#  'усадить': 'positive',
#  'поработать': 'negative',
#  'шницель': 'positive',
#  'порекомендовать': 'positive',
#  'фантанчик': 'positive',
#  'шоколадный фонтан': 'positive',
#  'уютный': 'positive',
#  'уют': 'positive',
#  'порция салат': 'positive',
#  'хачапури с сыр': 'positive',
#  'хинкали': 'positive',
#  'посадить за столик': 'positive',
#  'утиный грудка гриль с фрукт': 'positive',
#  'ухо': 'positive',
#  'шеф-повар ресторан': 'neutral',
#  'посетитель vip-зал': 'negative',
#  'утка по-пекински': 'positive',
#  'посидеть': 'positive',
#  'послевкусие': 'positive',
#  'утка в апельсиновый соус': 'positive',
#  'утка': 'negative',
#  'приглашать': 'positive',
#  'ресторан палкин': 'positive',
#  'следить за стол': 'positive',
#  'слушать': 'negative',
#  'смотреть за посетитель': 'positive',
#  'смотреть за стол': 'positive',
#  'смузи злаковый': 'neutral',
#  'смузи овощной': 'neutral',
#  'собеседник': 'positive',
#  'собрать': 'positive',
#  'совет': 'positive',
#  'советовать': 'positive',
#  'счёт мы принести': 'positive',
#  'соление': 'positive',
#  'солёный': 'negative',
#  'солёный гриб': 'negative',
#  'цвет': 'positive',
#  'цветовой решение': 'positive',
#  'сорбета': 'neutral',
#  'состав десерт': 'neutral',
#  'суша-бар': 'positive',
#  'сотрудник данный заведение': 'positive',
#  'сотрудник ресторан': 'positive',
#  'чаемый': 'neutral',
#  'чаемый с пирожное': 'positive',
#  'хочухарчо': 'neutral',
#  'соус из петрушка': 'positive',
#  'скульптура': 'positive',
#  'свинина в кисло-сладкий соус': 'neutral',
#  'свинина по-пекински': 'neutral',
#  'свинина с моцарелла и гриб': 'positive',
#  'свиной рулька': 'negative',
#  'свободный место': 'negative',
#  'свободный столик': 'both',
#  'чай с лимон и чабрец': 'neutral',
#  'чай с десерт': 'neutral',
#  'холодный закуска': 'neutral',
#  'сделать заказ': 'positive',
#  'сельдь под шуба … с краб': 'neutral',
#  'селёдка': 'positive',
#  'сервировать': 'positive',
#  'сервировка': 'positive',
#  'сервировка блюдо': 'positive',
#  'чай по восточный с инжирный варение': 'positive',
#  'сетевой заведение японский кухня': 'negative',
#  'скатерть': 'positive',
#  'хостёс': 'negative',
#  'скидочный карта': 'positive',
#  'скорость': 'positive',
#  'суп-харчо': 'positive',
#  'соус к мясо и картофель': 'neutral',
#  'ресторан гламур': 'neutral',
#  'стена': 'negative',
#  'стоимость ужин': 'negative',
#  'цена на кальян': 'negative',
#  'цена на вино': 'negative',
#  'судак с овощ и рис': 'positive',
#  'судак': 'neutral',
#  'стол для рисование': 'positive',
#  'стол забронировать': 'neutral',
#  'стульчик для кормление': 'positive',
#  'стол обслуживать': 'positive',
#  'цезарь-салат': 'neutral',
#  'цезарь с лосось': 'positive',
#  'цезарь с креветка': 'negative',
#  'цезарь с курица': 'negative',
#  'столик забронировать': 'neutral',
#  'столик не заказывать': 'neutral',
#  'стейк-хаус': 'negative',
#  'соус тара-тара': 'positive',
#  'спагетти': 'positive',
#  'суп-пюре из белый гриб': 'positive',
#  'спагетти карбонар': 'neutral',
#  'спагетти с фрикаделька': 'positive',
#  'спиртной напиток': 'positive',
#  'спокойный': 'positive',
#  'суп чанахи': 'positive',
#  'спрашивать': 'positive',
#  'срок ожидание': 'negative',
#  'суп с норвежский лосось': 'neutral',
#  'ценовой категория': 'neutral',
#  'суп из печёный чеснок': 'positive',
#  'стейк из говядина с шпинат': 'positive',
#  'суп из морепрдукт': 'positive',
#  'стейк из мраморный говядина': 'both',
#  'стейк из тунец': 'negative',
#  'стейк рибай': 'positive',
#  'суп из два рыба': 'positive',
#  'цветочный композиция': 'neutral',
#  'стейк с соус из белый гриб': 'positive',
#  'свинина': 'positive',
#  'тбилисо': 'positive',
#  'ролл запечь на уголь': 'positive',
#  'ролл на гриль': 'positive',
#  'ролл филадельфияй': 'neutral',
#  'рубить котлетка из лосось и судак с голландский соус и белый спаржа': 'positive',
#  'руккола с креветка': 'neutral',
#  'руководство ресторан': 'positive',
#  'рулет из лосось с зелёный спаржа': 'neutral',
#  'рулетик с гриб': 'positive',
#  'тарелка фрукт': 'positive',
#  'тарелка убираться': 'positive',
#  'рыба-стейк из форель': 'positive',
#  'чебурек с сыр сулугуни и зелень': 'positive',
#  'рыбка': 'neutral',
#  'холодное закуска': 'positive',
#  'танцполый': 'positive',
#  'тамада': 'neutral',
#  'чаплин-холл': 'neutral',
#  'чай с чабрец': 'positive',
#  'салат греческий': 'negative',
#  'салат грибной': 'positive',
#  'салат из лисичка с кроличий печень': 'neutral',
#  'ролл без рис': 'positive',
#  'холодное напиток': 'neutral',
#  'рис с курица': 'positive',
#  'ресторан крапива': 'neutral',
#  'ресторан мисо': 'positive',
#  'тирам': 'positive',
#  'ресторан на приморский': 'negative',
#  'тиммерманс': 'positive',
#  'ресторан оливье': 'neutral',
#  'столовая': 'negative',
#  'ресторан русский китч': 'positive',
#  'ресторан трес амигос': 'positive',
#  'ресторан фаворит': 'neutral',
#  'тест': 'negative',
#  'ресторан харбин на академический': 'neutral',
#  'ресторан харбин на приморский': 'both',
#  'ресторан эскалибур': 'neutral',
#  'терраса': 'positive',
#  'рибай': 'positive',
#  'ризотто с белый гриб': 'neutral',
#  'ризотто с спраж и горгонзола': 'neutral',
#  'твинс': 'positive',
#  'салат из лосось': 'positive',
#  'салат из морепродукт': 'positive',
#  'салат из руккола с печёный картофель': 'neutral',
#  'салат из тунец': 'neutral',
#  'сырный тарелка': 'negative',
#  'салат цезарь с креветка': 'positive',
#  'сырный палочка': 'neutral',
#  'салатик оливье': 'neutral',
#  'сан': 'neutral',
#  'санторинить': 'neutral',
#  'сануть': 'positive',
#  'саперави': 'neutral',
#  'сацивить из баклажан': 'positive',
#  'сырный корочка и базилик': 'positive',
#  'свежевыжать сок': 'neutral',
#  'сырный и мясной тарелка': 'positive',
#  'сыр филадельфия': 'positive',
#  'свежесварить пиво': 'positive',
#  'свежий': 'neutral',
#  'свежий овощ': 'neutral',
#  'светлый зал': 'positive',
#  'салат салмона с лосось': 'both',
#  'салат с угорь': 'positive',
#  'салат с говядина': 'positive',
#  'салат из язык и морепродукт': 'neutral',
#  'салат кавказский': 'positive',
#  'салат лагуна': 'positive',
#  'салат на закуска': 'positive',
#  'салат от шеф-повар с курица': 'positive',
#  'салат пампелона': 'positive',
#  'салат розан': 'positive',
#  'салат с авокадо': 'both',
#  'салат с апельсин руккола и лосось': 'neutral',
#  'салат с домашний сыр': 'neutral',
#  'салат с тёплый куриный печень': 'neutral',
#  'салат с креветка': 'positive',
#  'таверна': 'positive',
#  'сытый хавронья из свинин': 'positive',
#  'салат с креветка и краб': 'negative',
#  'салат с куриный печень': 'positive',
#  'салат с лосось': 'positive',
#  'сырный шарик': 'positive',
#  'салат с лосось краб тунец': 'positive',
#  'салат с малосольный лосось': 'positive',
#  'салат с руккола и вяленый помидор': 'neutral',
#  '1450-1750р с человек': 'neutral',
#  'оставить 10 тысяча': 'neutral',
#  'по цена': 'neutral',
#  'девушка официант': 'neutral',
#  'девушко-официантка': 'positive',
#  'девушка-певица': 'positive',
#  'девушка-официантка': 'positive',
#  'девушка-официант': 'positive',
#  'девушка хостёс': 'positive',
#  'девушка мария': 'positive',
#  'дать': 'negative',
#  'девушка из гардероб': 'negative',
#  'девочки-официантка': 'positive',
#  'двор': 'positive',
#  'два этаж': 'neutral',
#  'дать меню': 'positive',
#  'декорирование': 'positive',
#  'декорированный': 'positive',
#  'деликатес': 'neutral',
#  'делфима бар': 'positive',
#  'депозит 5 тыс': 'positive',
#  'десерт с банан': 'positive',
#  'десерт семифреддый': 'positive',
#  'диванчик-купе': 'positive',
#  'директор': 'positive',
#  'дисконтный карта': 'positive',
#  'дитая': 'neutral',
#  'добавлять вино': 'positive',
#  'доедать': 'positive',
#  'домашний куриный супчик': 'positive',
#  'домашний лимонад': 'positive',
#  'домашний морс': 'positive',
#  'гардероб': 'both',
#  'главный зал': 'negative',
#  'гарнир': 'positive',
#  'гардеробщик': 'positive',
#  'гардеробный': 'positive',
#  'выслушать': 'positive',
#  'дамский комната': 'negative',
#  'выполнение заказ': 'positive',
#  'выпить пиво': 'neutral',
#  'выпилить': 'positive',
#  'выпивка': 'positive',
#  'глинтвейн': 'positive',
#  'глобус': 'negative',
#  'говядина по-дижонск': 'positive',
#  'голос солистка': 'positive',
#  'горячий полотенце': 'negative',
#  'гость': 'negative',
#  'гранд-кафе 21 верста': 'positive',
#  'гребешок': 'positive',
#  'гребешок с спаржа': 'neutral',
#  'грейпфрут': 'positive',
#  'гриб': 'positive',
#  'гроссенштрасса': 'positive',
#  'грузинский вино': 'negative',
#  'грузинский танцевальный коллектив': 'positive',
#  'домашний мороженое': 'positive',
#  'допинг': 'negative',
#  'площадь ресторан': 'negative',
#  'зала': 'negative',
#  'запечь баклажан': 'positive',
#  'запечь': 'positive',
#  'занавеска': 'positive',
#  'закуска к пиво': 'positive',
#  'зал для курящий и некурящий': 'positive',
#  'закусывать': 'positive',
#  'закусочка': 'positive',
#  'запечь картошка': 'positive',
#  'запечь сушить': 'positive',
#  'запечь сыр': 'negative',
#  'запечёный': 'neutral',
#  'запивать': 'positive',
#  'запоминать': 'positive',
#  'заправка': 'positive',
#  'зелень': 'neutral',
#  'зелень с овощ': 'positive',
#  'знать меню': 'positive',
#  'зона для курящий': 'positive',
#  'зонирование': 'positive',
#  'империя': 'positive',
#  'ингридиент': 'neutral',
#  'инегридиент': 'negative',
#  'интерьер зал': 'positive',
#  'закусок-крыло': 'positive',
#  'дорада с овощ': 'positive',
#  'еда приносить': 'negative',
#  'ждать ещё минута': 'negative',
#  'жарить крылышко': 'positive',
#  'жареный осьминог': 'positive',
#  'жареный камамбер': 'positive',
#  'жан-жак': 'neutral',
#  'европейский меню': 'positive',
#  'европейский кухня': 'positive',
#  'европейский и японский блюдо': 'positive',
#  'дуглас': 'neutral',
#  'драник с бекон': 'positive',
#  'доска с мелок': 'positive',
#  'дорогой': 'negative',
#  'ждать заказ': 'positive',
#  'жевать': 'negative',
#  'живопись': 'positive',
#  'забирать': 'negative',
#  'забронировать': 'positive',
#  'забронировать стол': 'neutral',
#  'завернуть с себя': 'positive',
#  'заказ быть выполнить': 'positive',
#  'заказ быть принять': 'negative',
#  'заказ столик': 'neutral',
#  'заказать заранее': 'neutral',
#  'заказать обычный столик': 'negative',
#  'заказать по купон': 'neutral',
#  'заказывать стол': 'positive',
#  'выпечка': 'positive',
#  'выпекать': 'positive',
#  'берест светлый': 'negative',
#  'белый вино': 'positive',
#  'бекон на хрустеть тост с помидор черри': 'positive',
#  'барный карта': 'positive',
#  'бараний ножка': 'positive',
#  'ассортимент ролл': 'both',
#  'банкетный меню': 'positive',
#  'банкетный зал': 'positive',
#  'банкет': 'positive',
#  'баклажан запечь с сыр': 'positive',
#  'базилик': 'neutral',
#  'бесплатно': 'positive',
#  'бесплатный': 'positive',
#  'бефстроганов с пюре': 'positive',
#  'бивштекс': 'positive',
#  'биза с сливка и фрукт': 'positive',
#  'бизнес ланч': 'positive',
#  'бизнес-ланча': 'positive',
#  'билл-хук': 'neutral',
#  'бифштекс': 'negative',
#  'блинчик с мясо': 'positive',
#  'блюдо восточный кухня': 'positive',
#  'блюдо европейский кухня': 'positive',
#  'блюдо и напиток выноситься': 'positive',
#  'блюдо из меню': 'negative',
#  'ассортимент блюдо': 'positive',
#  'вынести': 'positive',
#  'аквариум': 'neutral',
#  'азиатский такой кухня': 'neutral',
#  'администратор ирина': 'positive',
#  'администратор екатерина': 'positive',
#  'админ': 'negative',
#  'ассортимент бар': 'positive',
#  'vip зона': 'neutral',
#  'mon petit cafe': 'positive',
#  'le glamure': 'positive',
#  'da albertone': 'positive',
#  '2ом этаж': 'neutral',
#  '2 этаж': 'neutral',
#  'алкогольный коктейль': 'neutral',
#  'алкогольный напиток': 'positive',
#  'альмонд': 'positive',
#  'амадеуса': 'neutral',
#  'америка': 'both',
#  'америка маки': 'neutral',
#  'америкать': 'neutral',
#  'аниматор': 'positive',
#  'антураж': 'negative',
#  'апельсиновый сок': 'negative',
#  'апрель': 'neutral',
#  'асаха': 'positive',
#  'ассортимент': 'positive',
#  'блюдо из мясо на мангал': 'positive',
#  'блюдо из осьминог': 'positive',
#  'блюдо китайский кухня': 'negative',
#  'впечатление от паб': 'positive',
#  'второе': 'neutral',
#  'всё убирать': 'positive',
#  'вручить меню': 'neutral',
#  'времяпрепровождение': 'positive',
#  'впечатление от посещение': 'positive',
#  'блюдо на гриль': 'positive',
#  'восточный экспресс': 'positive',
#  'восточный салат': 'positive',
#  'вок': 'neutral',
#  'водка': 'positive',
#  'вода': 'positive',
#  'второй зал': 'positive',
#  'выбор': 'both',
#  'выбор алкогольный коктейль': 'positive',
#  'выбор вино': 'positive',
#  'выбор горячее': 'negative',
#  'выбор горячий блюдо': 'positive',
#  'выбор десерт': 'positive',
#  'выбор еда': 'negative',
#  'выбор закуска': 'positive',
#  'выбор коктейль': 'positive',
#  'выбор место': 'neutral',
#  'выбор пиво': 'positive',
#  'выбор по меню и напиток': 'positive',
#  'выбор салат': 'positive',
#  'выбрать': 'positive',
#  'внимание': 'positive',
#  'внешний вид зал': 'positive',
#  'владелец': 'positive',
#  'бутылка вино': 'positive',
#  'блюдо садж': 'positive',
#  'бокал': 'positive',
#  'бокал коньяк': 'neutral',
#  'бокал красный сухой вино': 'neutral',
#  'больший окно': 'negative',
#  'больший порция': 'positive',
#  'большой выбор': 'positive',
#  'борщ с копчёность': 'positive',
#  'бронирование столик': 'neutral',
#  'бронирование столик по телефон': 'neutral',
#  'бронировать': 'negative',
#  'бронировать стол': 'neutral',
#  'бронь столик': 'neutral',
#  'бульон с мясо': 'neutral',
#  'бытылочко вино': 'neutral',
#  'вкус блюдо': 'positive',
#  'вайнштефан светлый': 'positive',
#  'вареник': 'neutral',
#  'васаби': 'negative',
#  'вентиляция': 'positive',
#  'веранда': 'negative',
#  'верхний этаж': 'positive',
#  'вечер пройти': 'positive',
#  'винишко': 'neutral',
#  'вино красный домашний': 'neutral',
#  'вишня': 'positive',
#  'вишнёвый штрудель': 'positive',
#  'интерьер ресторан': 'positive',
#  'итальянский блюдо': 'positive',
#  'итальянский кухня': 'neutral',
#  'облицовка стена': 'positive',
#  'обтановка': 'positive',
#  'обстановка ресторан': 'positive',
#  'обстановка в ресторан': 'positive',
#  'обслуживающий': 'positive',
#  'обслуга': 'negative',
#  'обедать': 'positive',
#  'невский 166': 'neutral',
#  'няня': 'positive',
#  'нижний зал': 'neutral',
#  'нести заказ': 'negative',
#  'нести': 'negative',
#  'некурящий зал': 'positive',
#  'общий впечатление': 'positive',
#  'общий мнение': 'both',
#  'общий оценка ресторан': 'positive',
#  'объесться': 'positive',
#  'овощ на гриль': 'neutral',
#  'овощ с моцарелла': 'negative',
#  'овощной гарнир': 'positive',
#  'окно': 'positive',
#  'омлет по-баварски': 'neutral',
#  'оргазм': 'positive',
#  'организация работа': 'negative',
#  'основной зал': 'negative',
#  'основный блюдо': 'neutral',
#  'недорогой': 'positive',
#  'невский': 'positive',
#  'молочный и алкогольный коктейль': 'positive',
#  'мужчина из гардероб': 'positive',
#  'мясной сырный рыбный тарелка': 'positive',
#  'мясной стейк': 'negative',
#  'мясной нарезка': 'positive',
#  'музыкальный фон': 'positive',
#  'музыкальный коллектив': 'positive',
#  'небо': 'neutral',
#  'мраморный говядина': 'positive',
#  'морс из натуральный клюква': 'positive',
#  'морс': 'positive',
#  'мороженный': 'neutral',
#  'морковь': 'positive',
#  'мясной чипсы из говядина': 'positive',
#  'мясо и рыба гриль': 'positive',
#  'мясо на мангал': 'positive',
#  'мясо утка': 'neutral',
#  'на вкус': 'negative',
#  'набор блюдо': 'positive',
#  'найти': 'positive',
#  'накладывать': 'negative',
#  'накопительный скидка': 'positive',
#  'накрыть стол': 'positive',
#  'налить': 'positive',
#  'наполеон': 'negative',
#  'народ быть не очень много': 'positive',
#  'настойка': 'positive',
#  'настроение': 'negative',
#  'не курящий зал': 'positive',
#  'оставить': 'negative',
#  '1ом этаж': 'negative',
#  'острый': 'neutral',
#  'первый этаж': 'neutral',
#  'персонал ресторан': 'positive',
#  'персонал паберти': 'positive',
#  'перечный стейк': 'positive',
#  'пересесть': 'positive',
#  'перепробовать': 'positive',
#  'первый блюдо': 'neutral',
#  'осьминог': 'negative',
#  'пенна с утка': 'positive',
#  'пенна 4 сыр': 'neutral',
#  'паэлить с курица и кролик': 'neutral',
#  'паулайнер': 'positive',
#  'паста с лосось': 'positive',
#  'паста с креветка': 'neutral',
#  'перчик халапена': 'positive',
#  'песня': 'positive',
#  'петь': 'positive',
#  'печёный груша': 'positive',
#  'пивко': 'neutral',
#  'пивная тарелка': 'positive',
#  'пивной бар': 'positive',
#  'пиво хугарден': 'positive',
#  'пирожное': 'negative',
#  'пирожок к первый блюдо': 'neutral',
#  'пицца на тонкий тест': 'positive',
#  'плата': 'negative',
#  'плов': 'neutral',
#  'паста с гриб сливка и томатный паста': 'neutral',
#  'паста карбонар': 'neutral',
#  'паста 4 сыр': 'positive',
#  'официант-бармен': 'positive',
#  'отварный креветка': 'neutral',
#  'ответить': 'positive',
#  'ответить на мой вопрос': 'positive',
#  'отвечать': 'positive',
#  'отдельный зал': 'positive',
#  'открытый кухня': 'both',
#  'открыть': 'positive',
#  'открыть дверь': 'positive',
#  'отношение к клиент': 'positive',
#  'отношение к свой дело': 'positive',
#  'отношение официант': 'negative',
#  'отношение персонал': 'positive',
#  'офицантка': 'neutral',
#  'парковщик': 'positive',
#  'официатка': 'neutral',
#  'оформление стена': 'positive',
#  'охрана': 'neutral',
#  'охранник': 'neutral',
#  'очерёдность блюдо': 'positive',
#  'паб джон донна': 'neutral',
#  'паб метрополь': 'positive',
#  'паберти': 'neutral',
#  'палкин': 'neutral',
#  'палтус': 'negative',
#  'палтус запечь': 'positive',
#  'панакот': 'positive',
#  'панакот с клубничный пюре': 'positive',
#  'молочный улуна': 'neutral',
#  'молодой человек-администратор': 'negative',
#  'кол-в закуска': 'negative',
#  'комната': 'positive',
#  'кольцо кальмар в кляр': 'positive',
#  'колонка': 'negative',
#  'коллектив официант': 'positive',
#  'количество': 'positive',
#  'колечко лука': 'neutral',
#  'коктель': 'positive',
#  'клиент': 'negative',
#  'коктейльный напиток': 'neutral',
#  'кокосовый шота': 'positive',
#  'кокосовый суп с морепродукт': 'neutral',
#  'клубнчный десерт': 'positive',
#  'клубничный чай': 'neutral',
#  'клубничный суп': 'neutral',
#  'комната для караоке': 'neutral',
#  'комплимент': 'positive',
#  'комплимент от шеф-повар': 'positive',
#  'комплимент-апперетив': 'positive',
#  'компьютер': 'positive',
#  'кон-коронель': 'positive',
#  'кондитерский': 'neutral',
#  'корзина': 'positive',
#  'кормить': 'positive',
#  'королевский креветка с соус': 'positive',
#  'котлета с пюре': 'positive',
#  'котлетка из лосось и креветка': 'positive',
#  'котлетка из лосось с пюре': 'neutral',
#  'котлетка из телятина с пюре': 'neutral',
#  'кофе борджиа': 'positive',
#  'кофе капуччиный': 'positive',
#  'клубничный маргарита': 'positive',
#  'китайский ресторанчик': 'neutral',
#  'капреза': 'both',
#  'карпачо сибас': 'negative',
#  'кармашек с гриб и рыба': 'positive',
#  'карбонар': 'positive',
#  'караоке-программа': 'positive',
#  'караоке': 'positive',
#  'каракатица': 'positive',
#  'канадский ролл': 'neutral',
#  'китайский ресторан': 'positive',
#  'камин': 'positive',
#  'кальянщик': 'positive',
#  'кальмар': 'positive',
#  'итоговый сумма': 'negative',
#  'итальянский ресторан': 'positive',
#  'карпаччо': 'positive',
#  'карпаччо из говядина': 'positive',
#  'карпаччо из утиный грудка': 'positive',
#  'карта с скидка': 'positive',
#  'картина': 'positive',
#  'картофель айдахо': 'neutral',
#  'картофель фри': 'positive',
#  'кафе кон-коронель': 'neutral',
#  'кафе-бар': 'neutral',
#  'качество вино': 'positive',
#  'качество еда': 'negative',
#  'качество кухня': 'positive',
#  'качество мясо': 'positive',
#  'качество напиток': 'neutral',
#  'качество обслуживание': 'positive',
#  'кеталонский крем': 'positive',
#  'кофе-десерт': 'positive',
#  'крабовый суп': 'positive',
#  'крапива': 'positive',
#  'манговый мусса': 'neutral',
#  'медальон': 'both',
#  'масло': 'positive',
#  'марат': 'neutral',
#  'манта': 'negative',
#  ...}

# %% [markdown]
# Также для определения тональных слов использую список слов, размеченных с точки зрения тональности:

# %%
sentiment_vocab = pd.read_csv('kartaslovsent.csv', sep = ';')
sentiment_vocab
# Out:
#                term   tag  value   pstv   ngtv   neut  dunno  \
# 0            абажур  NEUT   0.08  0.185  0.037  0.580  0.198
# 1         аббатство  NEUT   0.10  0.192  0.038  0.578  0.192
# 2      аббревиатура  NEUT   0.08  0.196  0.000  0.630  0.174
# 3             абзац  NEUT   0.00  0.137  0.000  0.706  0.157
# 4         абиссинец  NEUT   0.28  0.151  0.113  0.245  0.491
# ...             ...   ...    ...    ...    ...    ...    ...
# 46122       ёмкость  NEUT   0.00  0.167  0.000  0.690  0.143
# 46123        ёрзать  NGTV  -0.54  0.050  0.446  0.397  0.107
# 46124      ёрничать  NGTV  -0.79  0.078  0.529  0.236  0.157
# 46125           ёрш  NEUT   0.16  0.224  0.072  0.576  0.128
# 46126         ёршик  NEUT   0.00  0.152  0.043  0.718  0.087
#
#        pstvNgtvDisagreementRatio
# 0                           0.00
# 1                           0.00
# 2                           0.00
# 3                           0.00
# 4                           0.19
# ...                          ...
# 46122                       0.00
# 46123                       0.00
# 46124                       0.00
# 46125                       0.00
# 46126                       0.00
#
# [46127 rows x 8 columns]

# %%
sentiment_vocab["tag"].value_counts()
# Out:
# NEUT    28049
# NGTV    11863
# PSTV     6215
# Name: tag, dtype: int64

# %%
with open ('kartaslovsent.csv', encoding = 'utf-8') as csvfile:
    f = csv.reader(csvfile, delimiter=';')
    sent_dict = {}
    for row in f:
        if row[1] == 'NEUT':
            sent_dict[row[0]] = 'neutral'
        elif row[1] == 'NGTV':
            sent_dict[row[0]] = 'negative'
        elif row[1] == 'PSTV':
            sent_dict[row[0]] = 'positive'

# %% [markdown]
# Появилась также идея выделить ключевые слова в каждом тексте, что могло бы помочь найти аспекты. Ниже видно, что 3-граммные ключевые слова довольно неплохо выделяют специфичные для отрасли слова и выражения. Их можно использовать для нахождения аспекта Whole и Service (слова более общей тематики, встречаются глаголы, которые могут характеризовать сервис).

# %%
from keybert import KeyBERT

# %%
kw_model = KeyBERT('clips/mfaq')
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\configuration_utils.py:363: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(

# %%
train_texts_list_1 = ' '.join(train_texts_list)
kbert_text1_1 = kw_model.extract_keywords(train_texts_list[0], keyphrase_ngram_range=(1, 3), stop_words=None)

# %%
kbert_text1_1
# Out:
# [('хороший интерьер', 0.9745),
#  ('любить заведение именно', 0.9743),
#  ('любить заведение', 0.9735),
#  ('который заказать понравиться', 0.9733),
#  ('план хороший интерьер', 0.9731)]

# %%
kbert_text1_2 = kw_model.extract_keywords(train_texts_list[1], keyphrase_ngram_range=(1, 3), stop_words=None)
kbert_text1_2
# Out:
# [('хороший блюдо кухня', 0.9779),
#  ('ресторан согласный многий', 0.9778),
#  ('посетить данный ресторан', 0.9774),
#  ('хороший блюдо', 0.9771),
#  ('мы хороший блюдо', 0.9768)]

# %% [markdown]
# ### Выделение аспекта и тональности для каждого аспекта

# %%
def keybert_extractor(text):
    kbert_text = kw_model.extract_keywords(text, keyphrase_ngram_range=(1, 3), stop_words=None)
    key_bert_list = []
    key_bert_list_tokens = []
    for elem in kbert_text:
        key_bert_list.append(elem[0])
        key_bert_list_tokens.extend(elem[0].split(' '))
    return key_bert_list, key_bert_list_tokens

# %% [markdown]
# Выделяем аспектные слова и выражения:

# %%
def cat_mentions_extractor(name_file):
    texts, ids, norm_texts, norm_tokenized_texts = [], [], [], []
    list_of_final_data = [] #будет хранить список для извлеченных аспектных слов/выражений в формате [id текста, аспект, слово, спан_нач, спан_кон, тональность]
    with open(name_file, encoding = 'utf-8') as f:
        for line in f:
            text_id, text = line.rstrip('\r\n').split('\t')
            texts.append(text) #необработанные отзывы списком
            ids.append(text_id) #id отзывов
            norm_texts.append(normalize_text(text)) #список токенизированных и лемматизированных текстов (каждый отзыв - строка)
            norm_tokenized_texts.append(normalize_text(text).split(' ')) #список токенизированных и лемматизированных текстов (каждый отзыв - список токенов)
    for review_not_split in norm_texts: #берем токенизированные отзывы (1 отзыв - 1 строка)
        key_bert_list, key_bert_list_tokens = keybert_extractor(review_not_split)
        review_check_list = []
        for mention in counted_cat_for_mention.keys():
            if mention in review_not_split:
                for elem in mention.split(' '):
                    if elem in dishes_list and elem in norm_tokenized_texts[norm_texts.index(review_not_split)]:
                        text_id = ids[norm_texts.index(review_not_split)] #получаем id отзыва
                        cat = 'Food' #аспект
                        word = mention #употребление
                        ind = norm_tokenized_texts[norm_texts.index(review_not_split)].index(elem) #индекс токена в предложении, добавляется временно в список с наименованиями аспектов
                        f =  ''.join(norm_tokenized_texts[norm_texts.index(review_not_split)][0:ind])
                        span_beg = len(f) #спан начала
                        span_end = span_beg + len(mention) #спан конца
                        ment_data = [ind, text_id,cat, word, span_beg, span_end]
                        list_of_final_data.append(ment_data)
                        review_check_list.extend(ment_data[3].split(' ')) #добавляем рассмотренное слово в словарь, чтобы не повторяться
                    elif elem in furniture_list and elem in norm_tokenized_texts[norm_texts.index(review_not_split)]:
                        text_id = ids[norm_texts.index(review_not_split)] 
                        cat = 'Interior' 
                        word = mention 
                        ind = norm_tokenized_texts[norm_texts.index(review_not_split)].index(elem)
                        f =  ''.join(norm_tokenized_texts[norm_texts.index(review_not_split)][0:ind])
                        span_beg = len(f) 
                        span_end = span_beg + len(mention)
                        ment_data = [ind, text_id,cat, word, span_beg, span_end]
                        review_check_list.extend(ment_data[3].split(' '))
                        list_of_final_data.append(ment_data)
                    elif elem in norm_tokenized_texts[norm_texts.index(review_not_split)]:
                        text_id = ids[norm_texts.index(review_not_split)] 
                        cat = counted_cat_for_mention[mention] 
                        word = mention 
                        ind = norm_tokenized_texts[norm_texts.index(review_not_split)].index(elem)
                        f =  ''.join(norm_tokenized_texts[norm_texts.index(review_not_split)][0:ind])
                        span_beg = len(f) 
                        span_end = span_beg + len(mention)
                        ment_data = [ind, text_id,cat, word, span_beg, span_end]
                        review_check_list.extend(ment_data[3].split(' '))
                        list_of_final_data.append(ment_data)
        for token in norm_tokenized_texts[norm_texts.index(review_not_split)]:
            if token not in review_check_list:
                if token in dishes_list:
                    text_id = ids[norm_texts.index(review_not_split)] 
                    cat = 'Food' 
                    word = token 
                    ind = norm_tokenized_texts[norm_texts.index(review_not_split)].index(token)
                    f =  ''.join(norm_tokenized_texts[norm_texts.index(review_not_split)][0:ind])
                    span_beg = len(f) 
                    span_end = span_beg + len(token)
                    ment_data = [ind, text_id,cat, word, span_beg, span_end]
                    review_check_list.extend(ment_data[3])
                    list_of_final_data.append(ment_data)
                elif token in furniture_list:
                    text_id = ids[norm_texts.index(review_not_split)] 
                    cat = 'Interior' 
                    word = token 
                    ind = norm_tokenized_texts[norm_texts.index(review_not_split)].index(token)
                    f =  ''.join(norm_tokenized_texts[norm_texts.index(review_not_split)][0:ind])
                    span_beg = len(f) 
                    span_end = span_beg + len(token)
                    ment_data = [ind, text_id,cat, word, span_beg, span_end]
                    review_check_list.extend(ment_data[3])
                    list_of_final_data.append(ment_data)
                elif token in rare_words: #список слов с самым большим tf*idf
                    if token.isdigit:
                        text_id = ids[norm_texts.index(review_not_split)] 
                        cat = 'Price' 
                        word = token 
                        ind = norm_tokenized_texts[norm_texts.index(review_not_split)].index(token)
                        f =  ''.join(norm_tokenized_texts[norm_texts.index(review_not_split)][0:ind])
                        span_beg = len(f) 
                        span_end = span_beg + len(token)
                        ment_data = [ind,text_id,cat, word, span_beg, span_end]
                        review_check_list.extend(ment_data[3])
                        list_of_final_data.append(ment_data)
                    elif 'NOUN' in m.parse(token)[0].tag:
                        text_id = ids[norm_texts.index(review_not_split)] 
                        cat = 'Whole' 
                        word = token 
                        ind = norm_tokenized_texts[norm_texts.index(review_not_split)].index(token)
                        f =  ''.join(norm_tokenized_texts[norm_texts.index(review_not_split)][0:ind])
                        span_beg = len(f) 
                        span_end = span_beg + len(token)
                        ment_data = [ind, text_id,cat, word, span_beg, span_end]
                        review_check_list.extend(ment_data[3])
                        list_of_final_data.append(ment_data)
                elif token in key_bert_list_tokens:
                    if 'NOUN' in m.parse(token)[0].tag:
                        text_id = ids[norm_texts.index(review_not_split)] 
                        cat = 'Whole' 
                        word = token 
                        ind = norm_tokenized_texts[norm_texts.index(review_not_split)].index(token)
                        f =  ''.join(norm_tokenized_texts[norm_texts.index(review_not_split)][0:ind])
                        span_beg = len(f) 
                        span_end = span_beg + len(token)
                        ment_data = [ind, text_id,cat, word, span_beg, span_end]
                        review_check_list.extend(ment_data[3])
                        list_of_final_data.append(ment_data)
                    elif 'VERB' in m.parse(token)[0].tag:
                        text_id = ids[norm_texts.index(review_not_split)] 
                        cat = 'Service' 
                        word = token 
                        ind = norm_tokenized_texts[norm_texts.index(review_not_split)].index(token)
                        f =  ''.join(norm_tokenized_texts[norm_texts.index(review_not_split)][0:ind])
                        span_beg = len(f) 
                        span_end = span_beg + len(token)
                        ment_data = [ind, text_id,cat, word, span_beg, span_end]
                        review_check_list.extend(ment_data[3])
                        list_of_final_data.append(ment_data)
    return texts, ids, norm_texts, norm_tokenized_texts, list_of_final_data

# %%
texts, ids, norm_texts, norm_tokenized_texts, list_of_final_data = cat_mentions_extractor('dev_reviews.txt')

# %%
list_of_final_data[0:20]
# Out:
# [[47, '37784', 'Service', 'обслуживание', 259, 271],
#  [5, '37784', 'Whole', 'заведение', 25, 34],
#  [18, '37784', 'Food', 'кухня', 97, 102],
#  [76, '37784', 'Whole', 'место', 435, 440],
#  [25, '37784', 'Food', 'блюдо', 135, 140],
#  [62, '37784', 'Service', 'персонал', 357, 365],
#  [30, '37784', 'Food', 'порция', 160, 166],
#  [13, '37784', 'Food', 'пиво', 74, 78],
#  [31, '37784', 'Food', 'салат', 166, 171],
#  [24, '37784', 'Food', 'горячий', 128, 135],
#  [26, '37784', 'Food', 'мясо', 140, 144],
#  [72, '37784', 'Interior', 'стол', 416, 420],
#  [65, '37784', 'Service', 'человек', 376, 383],
#  [31, '37784', 'Food', 'салат цезарь', 166, 178],
#  [32, '37784', 'Food', 'салат цезарь', 171, 183],
#  [24, '37784', 'Food', 'горячий блюдо', 128, 141],
#  [25, '37784', 'Food', 'горячий блюдо', 135, 148],
#  [42, '37784', 'Food', 'попробовать', 224, 235],
#  [19, '37784', 'Food', 'есть', 102, 106],
#  [32, '37784', 'Food', 'цезарь', 171, 177]]

# %% [markdown]
# Для каждого аспектного слова создан словарик в формате: номер слова в предложении (временно, для удобства, потом уберем), id текста, аспект, слово/выражение, спан начала, спан конца.
#
# Затем выделяем для каждого аспекта тональность (к списку для слова добавляем также определение тональности):

# %%
def sent_extractor(texts, ids, norm_texts, norm_tokenized_texts, list_of_final_data):
    sent_extracted_data = []
    for line in list_of_final_data:
        #line[0] - индекс слова в предложении отзыва
        #line[1] - id отзыва
        #line[2] - аспектная категория
        #line[3] - слово(сочетание)
        #line[4] - спан начала
        #line[5] - спан конца
        if line[0]>0 and 'ADJF' in m.parse(norm_tokenized_texts[ids.index(line[1])][line[0]-1])[0].tag:
            adj = norm_tokenized_texts[ids.index(line[1])][line[0]-1]
            if adj in sent_dict.keys():
                line.append(sent_dict[adj])
                sent_extracted_data.append(line)
        elif line[0]+1 < len(norm_tokenized_texts[ids.index(line[1])]) and 'NOUN' in m.parse(norm_tokenized_texts[ids.index(line[1])][line[0]+1])[0].tag:
            noun = norm_tokenized_texts[ids.index(line[1])][line[0]+1]
            if noun in sent_dict.keys():
                line.append(sent_dict[noun])
                sent_extracted_data.append(line)
        elif line[0]+1 < len(norm_tokenized_texts[ids.index(line[1])]) and 'VERB' in m.parse(norm_tokenized_texts[ids.index(line[1])][line[0]+1])[0].tag:
            verb = norm_tokenized_texts[ids.index(line[1])][line[0]+1]
            if verb in sent_dict.keys():
                line.append(sent_dict[verb])
                sent_extracted_data.append(line)
        elif line[3] in counted_sent_for_mention.keys():
            line.append(counted_sent_for_mention[line[3]])
            sent_extracted_data.append(line)
        elif line[3] in sent_dict.keys():
                line.append(sent_dict[line[3]])
                sent_extracted_data.append(line)
        else:
            line.append('neutral')
            sent_extracted_data.append(line)
    return sent_extracted_data

# %% [markdown]
# Получившийся список:

# %%
sent_extracted_data = sent_extractor(texts, ids, norm_texts, norm_tokenized_texts, list_of_final_data)
sent_extracted_data
# Out:
# [[47, '37784', 'Service', 'обслуживание', 259, 271, 'positive'],
#  [18, '37784', 'Food', 'кухня', 97, 102, 'positive'],
#  [76, '37784', 'Whole', 'место', 435, 440, 'positive'],
#  [25, '37784', 'Food', 'блюдо', 135, 140, 'neutral'],
#  [62, '37784', 'Service', 'персонал', 357, 365, 'positive'],
#  [30, '37784', 'Food', 'порция', 160, 166, 'neutral'],
#  [31, '37784', 'Food', 'салат', 166, 171, 'neutral'],
#  [24, '37784', 'Food', 'горячий', 128, 135, 'neutral'],
#  [26, '37784', 'Food', 'мясо', 140, 144, 'positive'],
#  [72, '37784', 'Interior', 'стол', 416, 420, 'positive'],
#  [65, '37784', 'Service', 'человек', 376, 383, 'positive'],
#  [31, '37784', 'Food', 'салат цезарь', 166, 178, 'neutral'],
#  [32, '37784', 'Food', 'салат цезарь', 171, 183, 'positive'],
#  [24, '37784', 'Food', 'горячий блюдо', 128, 141, 'neutral'],
#  [25, '37784', 'Food', 'горячий блюдо', 135, 148, 'neutral'],
#  [42, '37784', 'Food', 'попробовать', 224, 235, 'positive'],
#  [32, '37784', 'Food', 'цезарь', 171, 177, 'both'],
#  [9, '37784', 'Whole', 'вечером', 46, 53, 'positive'],
#  [16, '37784', 'Food', 'выбор', 90, 95, 'neutral'],
#  [75, '37784', 'Interior', 'уютный', 429, 435, 'neutral'],
#  [30, '37784', 'Food', 'порция салат', 160, 172, 'neutral'],
#  [31, '37784', 'Food', 'порция салат', 166, 178, 'neutral'],
#  [1, '37784', 'Service', 'совет', 2, 7, 'positive'],
#  [15, '37784', 'Food', 'большой выбор', 83, 96, 'neutral'],
#  [16, '37784', 'Food', 'большой выбор', 90, 103, 'neutral'],
#  [71, '37784', 'Service', 'бронировать', 405, 416, 'neutral'],
#  [71, '37784', 'Service', 'бронировать стол', 405, 421, 'neutral'],
#  [72, '37784', 'Interior', 'бронировать стол', 416, 432, 'neutral'],
#  [58, '37784', 'Whole', 'настроение', 331, 341, 'positive'],
#  [52, '37784', 'Food', 'количество', 290, 300, 'neutral'],
#  [2, '37784', 'Price', 'друг', 7, 11, 'positive'],
#  [3, '37784', 'Price', 'посетить', 11, 19, 'neutral'],
#  [11, '37784', 'Price', 'людно', 58, 63, 'neutral'],
#  [23, '37784', 'Price', 'порадовать', 118, 128, 'positive'],
#  [29, '37784', 'Price', 'огромный', 152, 160, 'neutral'],
#  [36, '37784', 'Price', 'главное', 196, 203, 'neutral'],
#  [55, '37784', 'Price', 'отлично', 309, 316, 'neutral'],
#  [56, '37784', 'Price', 'подарить', 316, 324, 'positive'],
#  [63, '37784', 'Price', 'говорить', 365, 373, 'neutral'],
#  [66, '37784', 'Price', 'бывать', 383, 389, 'neutral'],
#  [15, '35635', 'Whole', 'ресторан', 79, 87, 'positive'],
#  [26, '35635', 'Service', 'обслуживание', 127, 139, 'neutral'],
#  [80, '35635', 'Service', 'официант', 422, 430, 'positive'],
#  [24, '35635', 'Food', 'кухня', 121, 126, 'positive'],
#  [76, '35635', 'Food', 'меню', 403, 407, 'positive'],
#  [27, '35635', 'Interior', 'атмосфера', 139, 148, 'positive'],
#  [52, '35635', 'Service', 'встретить', 293, 302, 'positive'],
#  [90, '35635', 'Food', 'напиток', 460, 467, 'neutral'],
#  [110, '35635', 'Whole', 'вечер', 578, 583, 'positive'],
#  [136, '35635', 'Food', 'поесть', 706, 712, 'positive'],
#  [135, '35635', 'Service', 'заказ', 701, 706, 'positive'],
#  [87, '35635', 'Service', 'помочь', 448, 454, 'positive'],
#  [43, '35635', 'Whole', 'впечатление', 252, 263, 'positive'],
#  [69, '35635', 'Service', 'подойти', 364, 371, 'both'],
#  [48, '35635', 'Whole', 'вечером', 277, 284, 'positive'],
#  [39, '35635', 'Whole', 'визит', 222, 227, 'neutral'],
#  [75, '35635', 'Service', 'дать меню', 399, 408, 'neutral'],
#  [76, '35635', 'Service', 'дать меню', 403, 412, 'positive'],
#  [89, '35635', 'Food', 'выбор', 455, 460, 'neutral'],
#  [151, '35635', 'Service', 'работа', 777, 783, 'neutral'],
#  [134, '35635', 'Service', 'сделать заказ', 694, 707, 'neutral'],
#  [135, '35635', 'Service', 'сделать заказ', 701, 714, 'positive'],
#  [75, '35635', 'Service', 'дать', 399, 403, 'neutral'],
#  [29, '35635', 'Whole', 'настроение', 149, 159, 'negative'],
#  [0, '35635', 'Price', 'давно', 0, 5, 'neutral'],
#  [1, '35635', 'Price', 'хотеть', 5, 11, 'neutral'],
#  [8, '35635', 'Price', 'время', 36, 41, 'neutral'],
#  [12, '35635', 'Price', 'несколько', 59, 68, 'neutral'],
#  [13, '35635', 'Price', 'год', 68, 71, 'neutral'],
#  [18, '35635', 'Whole', 'водограй', 93, 101, 'neutral'],
#  [20, '35635', 'Price', 'всегда', 102, 108, 'neutral'],
#  [22, '35635', 'Price', 'нравиться', 111, 120, 'positive'],
#  [20, '35635', 'Price', 'всегда', 102, 108, 'neutral'],
#  [33, '35635', 'Price', 'чувствоваться', 174, 187, 'neutral'],
#  [50, '35635', 'Price', 'никто', 286, 291, 'neutral'],
#  [65, '35635', 'Price', 'минута', 353, 359, 'neutral'],
#  [70, '35635', 'Price', 'кто-то', 371, 377, 'neutral'],
#  [79, '35635', 'Price', 'ожидать', 415, 422, 'neutral'],
#  [92, '35635', 'Price', 'бы', 472, 474, 'neutral'],
#  [98, '35635', 'Price', 'ли', 518, 520, 'neutral'],
#  [102, '35635', 'Price', 'при', 536, 539, 'neutral'],
#  [103, '35635', 'Price', 'условие', 539, 546, 'neutral'],
#  [106, '35635', 'Price', 'высокий', 557, 564, 'neutral'],
#  [108, '35635', 'Price', 'ужас', 571, 575, 'negative'],
#  [122, '35635', 'Price', 'даже', 643, 647, 'neutral'],
#  [126, '35635', 'Price', 'отличие', 659, 666, 'neutral'],
#  [65, '35635', 'Price', 'минута', 353, 359, 'neutral'],
#  [141, '35635', 'Price', 'себя', 725, 729, 'neutral'],
#  [141, '35635', 'Price', 'себя', 725, 729, 'neutral'],
#  [161, '35635', 'Price', 'оказываться', 828, 839, 'neutral'],
#  [169, '35635', 'Price', 'вопрос', 862, 868, 'neutral'],
#  [196, '35635', 'Price', 'искать', 990, 996, 'neutral'],
#  [197, '35635', 'Price', 'новый', 996, 1001, 'positive'],
#  [159, '17999', 'Service', 'обслуживание', 774, 786, 'positive'],
#  [44, '17999', 'Service', 'официант', 234, 242, 'positive'],
#  [59, '17999', 'Food', 'кухня', 307, 312, 'positive'],
#  [26, '17999', 'Whole', 'место', 130, 135, 'positive'],
#  [61, '17999', 'Food', 'еда', 314, 317, 'positive'],
#  [46, '17999', 'Food', 'меню', 250, 254, 'positive'],
#  [36, '17999', 'Service', 'встретить', 190, 199, 'positive'],
#  [45, '17999', 'Service', 'принести', 242, 250, 'neutral'],
#  [41, '17999', 'Interior', 'столик', 221, 227, 'positive'],
#  [112, '17999', 'Price', 'счёт', 579, 583, 'neutral'],
#  [19, '17999', 'Food', 'сушить', 86, 92, 'positive'],
#  [45, '17999', 'Service', 'принести меню', 242, 255, 'neutral'],
#  [46, '17999', 'Service', 'принести меню', 250, 263, 'positive'],
#  [65, '17999', 'Service', 'заказ принять', 332, 345, 'positive'],
#  [102, '17999', 'Service', 'чаевой', 529, 535, 'negative'],
#  [38, '17999', 'Service', 'посадить', 205, 213, 'positive'],
#  [68, '17999', 'Food', 'сок', 356, 359, 'positive'],
#  [43, '17999', 'Interior', 'уголок', 228, 234, 'neutral'],
#  [15, '17999', 'Food', 'невский', 69, 76, 'positive'],
#  [1, '17999', 'Price', 'открыться', 5, 14, 'neutral'],
#  [5, '17999', 'Price', 'рядом', 31, 36, 'neutral'],
#  [20, '17999', 'Price', 'всегда', 92, 98, 'neutral'],
#  [21, '17999', 'Price', 'радовать', 98, 106, 'positive'],
#  [24, '17999', 'Price', 'время', 117, 122, 'neutral'],
#  [25, '17999', 'Price', 'выбирать', 122, 130, 'neutral'],
#  [30, '17999', 'Price', 'рождение', 153, 161, 'positive'],
#  [51, '17999', 'Price', 'минута', 271, 277, 'positive'],
#  [52, '17999', 'Price', 'подруга', 277, 284, 'positive'],
#  [77, '17999', 'Price', 'без', 396, 399, 'neutral'],
#  [94, '17999', 'Price', 'разный', 496, 502, 'neutral'],
#  [98, '17999', 'Price', 'или', 515, 518, 'neutral'],
#  [100, '17999', 'Price', 'кто', 519, 522, 'neutral'],
#  [130, '17999', 'Price', 'здесь', 645, 650, 'neutral'],
#  [149, '17999', 'Price', 'главное', 721, 728, 'neutral'],
#  [150, '17999', 'Price', 'довольно', 728, 736, 'neutral'],
#  [160, '17999', 'Price', 'оставлять', 786, 795, 'neutral'],
#  [161, '17999', 'Price', 'желать', 795, 801, 'neutral'],
#  [89, '22970', 'Service', 'обслуживание', 406, 418, 'positive'],
#  [4, '22970', 'Interior', 'интерьер', 21, 29, 'positive'],
#  [66, '22970', 'Service', 'официант', 312, 320, 'negative'],
#  [32, '22970', 'Food', 'кухня', 142, 147, 'positive'],
#  [60, '22970', 'Food', 'пиво', 285, 289, 'positive'],
#  [75, '22970', 'Interior', 'зал', 354, 357, 'positive'],
#  [43, '22970', 'Food', 'суп', 198, 201, 'neutral'],
#  [40, '22970', 'Food', 'съесть', 177, 183, 'neutral'],
#  [26, '22970', 'Food', 'кофе', 110, 114, 'neutral'],
#  [25, '22970', 'Food', 'выпить', 104, 110, 'neutral'],
#  [53, '22970', 'Food', 'пить', 244, 248, 'neutral'],
#  [91, '22970', 'Service', 'обслужить', 420, 429, 'positive'],
#  [27, '22970', 'Food', 'есть', 114, 118, 'positive'],
#  [12, '22970', 'Interior', 'вид из окно', 57, 68, 'positive'],
#  [13, '22970', 'Interior', 'вид из окно', 60, 71, 'neutral'],
#  [14, '22970', 'Interior', 'вид из окно', 62, 73, 'positive'],
#  [49, '22970', 'Service', 'подать', 223, 229, 'negative'],
#  [14, '22970', 'Interior', 'окно', 62, 66, 'positive'],
#  [3, '22970', 'Price', 'светло', 15, 21, 'neutral'],
#  [30, '22970', 'Price', 'поэтому', 128, 135, 'neutral'],
#  [31, '22970', 'Price', 'оценить', 135, 142, 'neutral'],
#  [34, '22970', 'Whole', 'достоинство', 149, 160, 'positive'],
#  [39, '22970', 'Food', 'я', 176, 177, 'neutral'],
#  [46, '22970', 'Price', 'булочка', 213, 220, 'positive'],
#  [55, '22970', 'Price', 'надеяться', 252, 261, 'positive'],
#  [61, '22970', 'Price', 'говорить', 289, 297, 'neutral'],
#  [63, '22970', 'Price', 'там', 300, 303, 'neutral'],
#  [67, '22970', 'Price', 'претензия', 320, 329, 'negative'],
#  [76, '22970', 'Price', 'мало', 357, 361, 'neutral'],
#  [63, '22970', 'Price', 'там', 300, 303, 'neutral'],
#  [92, '22970', 'Price', 'быстро', 429, 435, 'neutral'],
#  [8, '36407', 'Whole', 'ресторан', 41, 49, 'neutral'],
#  [14, '36407', 'Whole', 'место', 77, 82, 'positive'],
#  [134, '36407', 'Food', 'еда', 717, 720, 'positive'],
#  [141, '36407', 'Food', 'паста', 761, 766, 'positive'],
#  [85, '36407', 'Interior', 'столик', 478, 484, 'positive'],
#  [27, '36407', 'Food', 'поесть', 149, 155, 'positive'],
#  [138, '36407', 'Food', 'пицца', 745, 750, 'positive'],
#  [106, '36407', 'Food', 'закуска', 578, 585, 'positive'],
#  [108, '36407', 'Interior', 'стол', 587, 591, 'positive'],
#  [126, '36407', 'Service', 'человек', 685, 692, 'neutral'],
#  [28, '36407', 'Food', 'выпить', 155, 161, 'neutral'],
#  [71, '36407', 'Service', 'сотрудник', 384, 393, 'neutral'],
#  [17, '36407', 'Interior', 'детский комната', 91, 106, 'positive'],
#  [56, '36407', 'Interior', 'детский комната', 296, 311, 'neutral'],
#  [18, '36407', 'Whole', 'праздник', 98, 106, 'neutral'],
#  [146, '36407', 'Food', 'свинина', 792, 799, 'positive'],
#  [185, '36407', 'Food', 'есть', 965, 969, 'positive'],
#  [155, '36407', 'Food', 'лосось', 830, 836, 'positive'],
#  [119, '36407', 'Interior', 'украсить', 638, 646, 'positive'],
#  [148, '36407', 'Food', 'гриб', 800, 804, 'positive'],
#  [122, '36407', 'Price', 'бесплатно', 653, 662, 'neutral'],
#  [58, '36407', 'Service', 'няня', 316, 320, 'positive'],
#  [56, '36407', 'Interior', 'комната', 296, 303, 'neutral'],
#  [4, '36407', 'Price', 'март', 25, 29, 'neutral'],
#  [5, '36407', 'Price', 'отмечать', 29, 37, 'neutral'],
#  [10, '36407', 'Price', 'рождение', 53, 61, 'positive'],
#  [11, '36407', 'Price', 'сын', 61, 64, 'positive'],
#  [13, '36407', 'Price', 'выбирать', 69, 77, 'neutral'],
#  [15, '36407', 'Price', 'потому', 82, 88, 'neutral'],
#  [20, '36407', 'Price', 'вы', 109, 111, 'neutral'],
#  [24, '36407', 'Price', 'хотеть', 127, 133, 'neutral'],
#  [35, '36407', 'Price', 'ребёнок', 184, 191, 'neutral'],
#  [36, '36407', 'Price', 'конечно', 191, 198, 'neutral'],
#  [46, '36407', 'Price', 'разный', 240, 246, 'neutral'],
#  [48, '36407', 'Price', 'кто', 253, 256, 'neutral'],
#  [50, '36407', 'Price', 'интересно', 259, 268, 'neutral'],
#  [54, '36407', 'Price', 'чудесный', 281, 289, 'positive'],
#  [57, '36407', 'Price', 'замечательный', 303, 316, 'positive'],
#  [35, '36407', 'Price', 'ребёнок', 184, 191, 'neutral'],
#  [61, '36407', 'Price', 'при', 330, 333, 'neutral'],
#  [63, '36407', 'Price', 'что-то', 337, 343, 'neutral'],
#  [63, '36407', 'Price', 'что-то', 337, 343, 'neutral'],
#  [73, '36407', 'Price', 'молодец', 399, 406, 'positive'],
#  [74, '36407', 'Price', 'весь', 406, 410, 'neutral'],
#  [78, '36407', 'Price', 'себя', 431, 435, 'neutral'],
#  [82, '36407', 'Price', 'несколько', 451, 460, 'neutral'],
#  [13, '36407', 'Price', 'выбирать', 69, 77, 'neutral'],
#  [90, '36407', 'Price', 'говорить', 503, 511, 'neutral'],
#  [109, '36407', 'Price', 'поставить', 591, 600, 'neutral'],
#  [117, '36407', 'Price', 'даже', 629, 633, 'neutral'],
#  [118, '36407', 'Price', 'шарик', 633, 638, 'neutral'],
#  [129, '36407', 'Price', 'никто', 699, 704, 'neutral'],
#  [48, '36407', 'Price', 'кто', 253, 256, 'neutral'],
#  [35, '36407', 'Price', 'ребёнок', 184, 191, 'neutral'],
#  [139, '36407', 'Price', 'друг', 750, 754, 'positive'],
#  [158, '36407', 'Price', 'сытно', 843, 848, 'neutral'],
#  [170, '36407', 'Price', 'голова', 886, 892, 'neutral'],
#  [173, '36407', 'Price', 'чем', 895, 898, 'neutral'],
#  [35, '36407', 'Price', 'ребёнок', 184, 191, 'neutral'],
#  [139, '36407', 'Price', 'друг', 750, 754, 'positive'],
#  [64, '16714', 'Interior', 'интерьер', 384, 392, 'positive'],
#  [57, '16714', 'Service', 'официант', 334, 342, 'positive'],
#  [17, '16714', 'Food', 'кухня', 95, 100, 'positive'],
#  [102, '16714', 'Service', 'девушка', 591, 598, 'positive'],
#  [92, '16714', 'Service', 'администратор', 537, 550, 'positive'],
#  [53, '16714', 'Service', 'сервис', 300, 306, 'positive'],
#  [7, '16714', 'Interior', 'столик', 28, 34, 'positive'],
#  [20, '16714', 'Food', 'шашлык', 108, 114, 'positive'],
#  [56, '16714', 'Whole', 'впечатление', 323, 334, 'positive'],
#  [93, '16714', 'Service', 'работать', 550, 558, 'positive'],
#  [30, '16714', 'Food', 'овощ', 172, 176, 'positive'],
#  [10, '16714', 'Whole', 'праздник', 49, 57, 'positive'],
#  [15, '16714', 'Food', 'попробовать', 77, 88, 'positive'],
#  [7, '16714', 'Interior', 'заказывать столик', 28, 45, 'neutral'],
#  [30, '16714', 'Food', 'овощ на гриль', 172, 185, 'neutral'],
#  [11, '16714', 'Food', 'овощ на гриль', 57, 70, 'positive'],
#  [12, '16714', 'Price', 'воскресение', 59, 70, 'positive'],
#  [16, '16714', 'Price', 'немного', 88, 95, 'neutral'],
#  [16, '16714', 'Price', 'немного', 88, 95, 'neutral'],
#  [52, '16714', 'Price', 'достойный', 291, 300, 'neutral'],
#  [54, '16714', 'Price', 'оставлять', 306, 315, 'neutral'],
#  [68, '16714', 'Price', 'оценить', 404, 411, 'neutral'],
#  [73, '16714', 'Price', 'более', 424, 429, 'neutral'],
#  [79, '16714', 'Price', 'обед', 452, 456, 'positive'],
#  [73, '16714', 'Price', 'более', 424, 429, 'neutral'],
#  [88, '16714', 'Price', 'особенно', 498, 506, 'positive'],
#  [90, '16714', 'Price', 'выразить', 514, 522, 'positive'],
#  [100, '16714', 'Price', 'запомнить', 579, 588, 'neutral'],
#  [111, '16714', 'Price', 'выше', 651, 655, 'neutral'],
#  [16, '5648', 'Service', 'официант', 89, 97, 'positive'],
#  [55, '5648', 'Whole', 'заведение', 286, 295, 'positive'],
#  [1, '5648', 'Service', 'персонал', 7, 15, 'negative'],
#  [14, '5648', 'Service', 'обслуживать', 73, 84, 'positive'],
#  [77, '5648', 'Service', 'сервис', 399, 405, 'positive'],
#  [65, '5648', 'Service', 'заказ', 330, 335, 'positive'],
#  [20, '5648', 'Service', 'приносить', 113, 122, 'positive'],
#  [86, '5648', 'Service', 'человек', 445, 452, 'positive'],
#  [81, '5648', 'Service', 'ребята', 420, 426, 'neutral'],
#  [24, '5648', 'Service', 'заказывать', 129, 139, 'neutral'],
#  [3, '5648', 'Food', 'невский', 17, 24, 'positive'],
#  [10, '5648', 'Interior', 'окно', 51, 55, 'positive'],
#  [85, '5648', 'Food', 'кормить', 438, 445, 'neutral'],
#  [48, '5648', 'Service', 'клиент', 261, 267, 'negative'],
#  [6, '5648', 'Price', 'особенно', 32, 40, 'neutral'],
#  [7, '5648', 'Price', 'если', 40, 44, 'neutral'],
#  [11, '5648', 'Price', 'некурящий', 55, 64, 'positive'],
#  [12, '5648', 'Price', 'там', 64, 67, 'positive'],
#  [13, '5648', 'Price', 'всегда', 67, 73, 'neutral'],
#  [15, '5648', 'Price', 'новый', 84, 89, 'neutral'],
#  [18, '5648', 'Price', 'знающий', 102, 109, 'neutral'],
#  [13, '5648', 'Price', 'всегда', 67, 73, 'neutral'],
#  [13, '5648', 'Price', 'всегда', 67, 73, 'neutral'],
#  [49, '5648', 'Price', 'после', 267, 272, 'neutral'],
#  [50, '5648', 'Price', '2', 272, 273, 'neutral'],
#  [51, '5648', 'Price', 'месяц', 273, 278, 'positive'],
#  [52, '5648', 'Price', 'обед', 278, 282, 'positive'],
#  [52, '5648', 'Price', 'обед', 278, 282, 'positive'],
#  [62, '5648', 'Price', 'через', 317, 322, 'neutral'],
#  [49, '5648', 'Price', 'после', 267, 272, 'neutral'],
#  [66, '5648', 'Price', 'естественно', 335, 346, 'neutral'],
#  [67, '5648', 'Price', 'весь', 346, 350, 'neutral'],
#  [71, '5648', 'Price', 'желание', 366, 373, 'positive'],
#  [73, '5648', 'Price', 'сюда', 381, 385, 'neutral'],
#  [7, '5648', 'Price', 'если', 40, 44, 'neutral'],
#  [83, '5648', 'Price', 'вы', 430, 432, 'neutral'],
#  [84, '5648', 'Price', 'сложно', 432, 438, 'neutral'],
#  [52, '5648', 'Price', 'обед', 278, 282, 'positive'],
#  [91, '5648', 'Price', 'делать', 469, 475, 'neutral'],
#  [4, '37975', 'Whole', 'ресторан', 22, 30, 'positive'],
#  [35, '37975', 'Interior', 'интерьер', 176, 184, 'positive'],
#  [152, '37975', 'Whole', 'заведение', 810, 819, 'positive'],
#  [79, '37975', 'Food', 'блюдо', 415, 420, 'positive'],
#  [45, '37975', 'Service', 'персонал', 251, 259, 'positive'],
#  [67, '37975', 'Food', 'меню', 366, 370, 'neutral'],
#  [37, '37975', 'Interior', 'атмосфера', 193, 202, 'positive'],
#  [118, '37975', 'Service', 'обслуживать', 631, 642, 'positive'],
#  [59, '37975', 'Food', 'напиток', 320, 327, 'positive'],
#  [76, '37975', 'Interior', 'столик', 407, 413, 'positive'],
#  [72, '37975', 'Service', 'помочь', 383, 389, 'positive'],
#  [57, '37975', 'Service', 'приносить', 307, 316, 'positive'],
#  [17, '37975', 'Service', 'человек', 73, 80, 'positive'],
#  [65, '37975', 'Food', 'фрукт', 352, 357, 'negative'],
#  [68, '37975', 'Food', 'есть', 370, 374, 'positive'],
#  [123, '37975', 'Service', 'подать', 658, 664, 'negative'],
#  [70, '37975', 'Food', 'выбор', 376, 381, 'both'],
#  [95, '37975', 'Service', 'упаковать', 491, 500, 'positive'],
#  [36, '37975', 'Interior', 'спокойный', 184, 193, 'neutral'],
#  [20, '37975', 'Service', 'гость', 89, 94, 'negative'],
#  [14, '37975', 'Whole', 'банкет', 64, 70, 'neutral'],
#  [66, '37975', 'Food', 'банкетный меню', 357, 371, 'neutral'],
#  [67, '37975', 'Food', 'банкетный меню', 366, 380, 'neutral'],
#  [79, '37975', 'Food', 'блюдо из меню', 415, 428, 'negative'],
#  [80, '37975', 'Food', 'блюдо из меню', 420, 433, 'neutral'],
#  [67, '37975', 'Food', 'блюдо из меню', 366, 379, 'neutral'],
#  [45, '37975', 'Service', 'персонал ресторан', 251, 268, 'positive'],
#  [4, '37975', 'Service', 'персонал ресторан', 22, 39, 'positive'],
#  [143, '37975', 'Service', 'клиент', 762, 768, 'neutral'],
#  [0, '37975', 'Price', 'праздновать', 0, 11, 'positive'],
#  [1, '37975', 'Price', 'свадьба', 11, 18, 'positive'],
#  [8, '37975', 'Price', 'г', 41, 42, 'neutral'],
#  [13, '37975', 'Price', 'небольшой', 55, 64, 'positive'],
#  [16, '37975', 'Price', '6', 72, 73, 'neutral'],
#  [19, '37975', 'Price', 'качество', 81, 89, 'neutral'],
#  [33, '37975', 'Price', 'приехать', 160, 168, 'neutral'],
#  [42, '37975', 'Price', 'обходительный', 229, 242, 'positive'],
#  [13, '37975', 'Price', 'небольшой', 55, 64, 'positive'],
#  [53, '37975', 'Price', 'число', 286, 291, 'neutral'],
#  [56, '37975', 'Price', 'разрешить', 298, 307, 'positive'],
#  [60, '37975', 'Price', 'без', 327, 330, 'neutral'],
#  [90, '37975', 'Price', 'забрать', 471, 478, 'neutral'],
#  [91, '37975', 'Price', 'домой', 478, 483, 'neutral'],
#  [103, '37975', 'Price', 'вообщий', 538, 545, 'neutral'],
#  [116, '37975', 'Price', 'сергей', 623, 629, 'neutral'],
#  [125, '37975', 'Price', 'время', 665, 670, 'neutral'],
#  [134, '37975', 'Price', 'весь', 710, 714, 'neutral'],
#  [137, '37975', 'Price', 'желать', 730, 736, 'neutral'],
#  [138, '37975', 'Price', 'вы', 736, 738, 'positive'],
#  [140, '37975', 'Price', 'процветание', 743, 754, 'positive'],
#  [149, '37975', 'Price', 'посетить', 786, 794, 'neutral'],
#  [151, '37975', 'Price', 'замечательный', 797, 810, 'neutral'],
#  [18, '9662', 'Whole', 'ресторан', 100, 108, 'neutral'],
#  [54, '9662', 'Service', 'обслуживание', 330, 342, 'negative'],
#  [26, '9662', 'Interior', 'интерьер', 150, 158, 'positive'],
#  [72, '9662', 'Food', 'блюдо', 421, 426, 'positive'],
#  [46, '9662', 'Price', 'цена', 280, 284, 'positive'],
#  [39, '9662', 'Food', 'меню', 240, 244, 'positive'],
#  [34, '9662', 'Interior', 'музыка', 213, 219, 'positive'],
#  [62, '9662', 'Service', 'обслуживать', 362, 373, 'positive'],
#  [75, '9662', 'Food', 'напиток', 443, 450, 'neutral'],
#  [76, '9662', 'Service', 'принести', 450, 458, 'positive'],
#  [7, '9662', 'Interior', 'столик', 34, 40, 'positive'],
#  [65, '9662', 'Service', 'молодой человек', 386, 401, 'positive'],
#  [4, '9662', 'Service', 'молодой человек', 18, 33, 'positive'],
#  [80, '9662', 'Service', 'заказ', 470, 475, 'positive'],
#  [83, '9662', 'Whole', 'провести время', 484, 498, 'neutral'],
#  [84, '9662', 'Whole', 'провести время', 492, 506, 'positive'],
#  [4, '9662', 'Service', 'человек', 18, 25, 'positive'],
#  [45, '9662', 'Price', 'по цена', 278, 285, 'positive'],
#  [46, '9662', 'Price', 'по цена', 280, 287, 'neutral'],
#  [47, '9662', 'Food', 'готовиться', 284, 294, 'negative'],
#  [8, '9662', 'Service', 'бронировать', 40, 51, 'negative'],
#  [1, '9662', 'Price', 'вчера', 4, 9, 'neutral'],
#  [3, '9662', 'Price', '6', 17, 18, 'neutral'],
#  [12, '9662', 'Price', 'всегда', 67, 73, 'neutral'],
#  [13, '9662', 'Price', 'стоить', 73, 79, 'neutral'],
#  [14, '9662', 'Price', 'делать', 79, 85, 'neutral'],
#  [28, '9662', 'Price', 'абсолютно', 166, 175, 'positive'],
#  [31, '9662', 'Price', 'высокий', 193, 200, 'positive'],
#  [35, '9662', 'Price', 'тихий', 219, 224, 'neutral'],
#  [40, '9662', 'Price', 'интересный', 244, 254, 'positive'],
#  [49, '9662', 'Price', 'быстро', 299, 305, 'neutral'],
#  [53, '9662', 'Price', 'плохой', 324, 330, 'neutral'],
#  [73, '9662', 'Price', 'меняться', 426, 434, 'neutral'],
#  [78, '9662', 'Price', 'же', 463, 465, 'neutral'],
#  [79, '9662', 'Price', 'после', 465, 470, 'neutral'],
#  [82, '9662', 'Price', 'отлично', 477, 484, 'neutral'],
#  [86, '9662', 'Price', 'удовольствие', 498, 510, 'positive'],
#  [30, '10625', 'Whole', 'ресторан', 165, 173, 'positive'],
#  [72, '10625', 'Interior', 'интерьер', 381, 389, 'positive'],
#  [157, '10625', 'Whole', 'место', 809, 814, 'positive'],
#  [163, '10625', 'Food', 'блюдо', 859, 864, 'neutral'],
#  [98, '10625', 'Service', 'официантка', 509, 519, 'positive'],
#  [117, '10625', 'Food', 'салат', 611, 616, 'neutral'],
#  [96, '10625', 'Service', 'сервис', 501, 507, 'positive'],
#  [48, '10625', 'Interior', 'зал', 263, 266, 'neutral'],
#  [5, '10625', 'Whole', 'кафе', 32, 36, 'positive'],
#  [24, '10625', 'Whole', 'вечер', 128, 133, 'positive'],
#  [34, '10625', 'Service', 'принести', 191, 199, 'positive'],
#  [54, '10625', 'Interior', 'столик', 287, 293, 'positive'],
#  [121, '10625', 'Food', 'соус', 632, 636, 'negative'],
#  [108, '10625', 'Service', 'заказ', 565, 570, 'positive'],
#  [27, '10625', 'Service', 'предложить', 142, 152, 'positive'],
#  [76, '10625', 'Food', 'вкус', 406, 410, 'positive'],
#  [9, '10625', 'Food', 'кофе', 52, 56, 'neutral'],
#  [125, '10625', 'Service', 'повар', 652, 657, 'positive'],
#  [117, '10625', 'Food', 'салат цезарь', 611, 623, 'neutral'],
#  [118, '10625', 'Food', 'салат цезарь', 616, 628, 'positive'],
#  [85, '10625', 'Service', 'подходить', 444, 453, 'neutral'],
#  [8, '10625', 'Food', 'попить', 46, 52, 'neutral'],
#  [160, '10625', 'Food', 'попробовать', 830, 841, 'positive'],
#  [118, '10625', 'Food', 'цезарь', 616, 622, 'both'],
#  [69, '10625', 'Service', 'заказывать', 358, 368, 'neutral'],
#  [11, '10625', 'Food', 'пирожное', 57, 65, 'negative'],
#  [1, '10625', 'Whole', 'вечером', 9, 16, 'neutral'],
#  [74, '10625', 'Service', 'сделать заказ', 398, 411, 'positive'],
#  [108, '10625', 'Service', 'сделать заказ', 565, 578, 'positive'],
#  [73, '10625', 'Interior', 'спокойный', 389, 398, 'positive'],
#  [135, '10625', 'Food', 'готовиться', 702, 712, 'negative'],
#  [162, '10625', 'Food', 'итальянский блюдо', 848, 865, 'neutral'],
#  [163, '10625', 'Food', 'итальянский блюдо', 859, 876, 'neutral'],
#  [162, '10625', 'Whole', 'итальянский ресторан', 848, 868, 'neutral'],
#  [30, '10625', 'Whole', 'итальянский ресторан', 165, 185, 'positive'],
#  [64, '10625', 'Interior', 'вентиляция', 330, 340, 'positive'],
#  [52, '10625', 'Service', 'найти', 276, 281, 'positive'],
#  [13, '10625', 'Price', 'без', 69, 72, 'neutral'],
#  [20, '10625', 'Price', 'закрываться', 105, 116, 'neutral'],
#  [21, '10625', 'Price', 'ровно', 116, 121, 'neutral'],
#  [56, '10625', 'Price', 'курящий', 296, 303, 'neutral'],
#  [59, '10625', 'Price', 'сильно', 308, 314, 'neutral'],
#  [13, '10625', 'Price', 'без', 69, 72, 'neutral'],
#  [88, '10625', 'Price', 'чем', 464, 467, 'neutral'],
#  [93, '10625', 'Price', 'вдвоём', 484, 490, 'neutral'],
#  [95, '10625', 'Price', 'касаться', 493, 501, 'neutral'],
#  [106, '10625', 'Price', 'чтоб', 554, 558, 'neutral'],
#  [13, '10625', 'Price', 'без', 69, 72, 'neutral'],
#  [131, '10625', 'Price', 'лишь', 684, 688, 'neutral'],
#  [132, '10625', 'Food', 'майонез', 688, 695, 'neutral'],
#  [137, '10625', 'Price', 'одинаковый', 717, 727, 'neutral'],
#  [139, '10625', 'Price', 'весь', 730, 734, 'neutral'],
#  [141, '10625', 'Price', 'через', 740, 745, 'neutral'],
#  [144, '10625', 'Price', 'снова', 760, 765, 'neutral'],
#  [151, '10625', 'Price', 'вид', 791, 794, 'positive'],
#  [144, '10625', 'Price', 'снова', 760, 765, 'neutral'],
#  [164, '10625', 'Price', 'давно', 864, 869, 'neutral'],
#  [166, '10625', 'Price', 'хотеть', 872, 878, 'neutral'],
#  [171, '10625', 'Price', 'себя', 891, 895, 'neutral'],
#  [175, '10625', 'Price', 'вдруг', 921, 926, 'neutral'],
#  [178, '10625', 'Price', 'именно', 940, 946, 'neutral'],
#  [4, '2692', 'Whole', 'ресторан', 15, 23, 'positive'],
#  [39, '2692', 'Service', 'обслуживание', 200, 212, 'positive'],
#  [27, '2692', 'Interior', 'интерьер', 130, 138, 'positive'],
#  [88, '2692', 'Service', 'официант', 421, 429, 'positive'],
#  [6, '2692', 'Food', 'кухня', 32, 37, 'neutral'],
#  [14, '2692', 'Whole', 'место', 68, 73, 'positive'],
#  [67, '2692', 'Food', 'еда', 351, 354, 'positive'],
#  [72, '2692', 'Interior', 'зал', 371, 374, 'positive'],
#  [85, '2692', 'Service', 'ждать', 409, 414, 'neutral'],
#  [128, '2692', 'Interior', 'столик', 621, 627, 'positive'],
#  [20, '2692', 'Food', 'поесть', 97, 103, 'positive'],
#  [105, '2692', 'Interior', 'стол', 500, 504, 'positive'],
#  [66, '2692', 'Food', 'качество еда', 343, 355, 'positive'],
#  [67, '2692', 'Food', 'качество еда', 351, 363, 'negative'],
#  [5, '2692', 'Food', 'китайский кухня', 23, 38, 'neutral'],
#  [6, '2692', 'Food', 'китайский кухня', 32, 47, 'neutral'],
#  [128, '2692', 'Interior', 'бронировать столик', 621, 639, 'neutral'],
#  [25, '2692', 'Price', 'дорогой', 114, 121, 'negative'],
#  [110, '2692', 'Service', 'вынести', 519, 526, 'positive'],
#  [105, '2692', 'Interior', 'бронировать стол', 500, 516, 'neutral'],
#  [57, '2692', 'Service', 'владелец', 296, 304, 'positive'],
#  [111, '2692', 'Food', 'первый блюдо', 526, 538, 'neutral'],
#  [1, '2692', 'Price', 'весь', 2, 6, 'neutral'],
#  [3, '2692', 'Food', 'я', 14, 15, 'neutral'],
#  [22, '2692', 'Price', 'вы', 106, 108, 'neutral'],
#  [22, '2692', 'Price', 'вы', 106, 108, 'neutral'],
#  [34, '2692', 'Price', 'отличный', 167, 175, 'neutral'],
#  [37, '2692', 'Price', 'быстрый', 181, 188, 'neutral'],
#  [38, '2692', 'Price', 'качественный', 188, 200, 'neutral'],
#  [41, '2692', 'Price', 'год', 214, 217, 'neutral'],
#  [41, '2692', 'Price', 'год', 214, 217, 'neutral'],
#  [46, '2692', 'Price', 'становиться', 231, 242, 'neutral'],
#  [47, '2692', 'Price', 'плохой', 242, 248, 'negative'],
#  [52, '2692', 'Price', 'радовать', 259, 267, 'positive'],
#  [63, '2692', 'Price', 'себя', 328, 332, 'neutral'],
#  [68, '2692', 'Price', 'более', 354, 359, 'neutral'],
#  [76, '2692', 'Price', 'бывать', 384, 390, 'neutral'],
#  [22, '2692', 'Price', 'вы', 106, 108, 'neutral'],
#  [87, '2692', 'Price', 'или', 418, 421, 'neutral'],
#  [95, '2692', 'Price', 'февраль', 459, 466, 'neutral'],
#  [115, '2692', 'Price', '15', 549, 551, 'neutral'],
#  [124, '2692', 'Price', 'минус', 589, 594, 'neutral'],
#  [24, '34889', 'Whole', 'ресторан', 137, 145, 'neutral'],
#  [56, '34889', 'Interior', 'интерьер', 344, 352, 'positive'],
#  [66, '34889', 'Service', 'официант', 397, 405, 'positive'],
#  [25, '34889', 'Food', 'кухня', 145, 150, 'positive'],
#  [117, '34889', 'Whole', 'место', 702, 707, 'positive'],
#  [65, '34889', 'Food', 'блюдо', 392, 397, 'neutral'],
#  [79, '34889', 'Food', 'еда', 482, 485, 'positive'],
#  [63, '34889', 'Food', 'меню', 376, 380, 'positive'],
#  [53, '34889', 'Interior', 'атмосфера', 317, 326, 'positive'],
#  [91, '34889', 'Interior', 'десерт', 555, 561, 'positive'],
#  [47, '34889', 'Service', 'девушка', 274, 281, 'neutral'],
#  [41, '34889', 'Interior', 'музыка', 237, 243, 'positive'],
#  [48, '34889', 'Service', 'администратор', 281, 294, 'positive'],
#  [58, '34889', 'Interior', 'столик', 359, 365, 'positive'],
#  [134, '34889', 'Food', 'приготовить', 792, 803, 'neutral'],
#  [19, '34889', 'Whole', 'ресторанчик', 94, 105, 'neutral'],
#  [62, '34889', 'Food', 'вкус', 372, 376, 'neutral'],
#  [20, '34889', 'Food', 'пообедать', 105, 114, 'neutral'],
#  [15, '34889', 'Whole', 'аппетит', 75, 82, 'neutral'],
#  [70, '34889', 'Service', 'посоветовать', 434, 446, 'positive'],
#  [64, '34889', 'Food', 'разнообразие', 380, 392, 'neutral'],
#  [46, '34889', 'Food', 'выбор', 269, 274, 'positive'],
#  [52, '34889', 'Interior', 'уютный', 311, 317, 'positive'],
#  [115, '34889', 'Service', 'рекомендовать', 686, 699, 'positive'],
#  [123, '34889', 'Whole', 'посидеть', 723, 731, 'positive'],
#  [136, '34889', 'Service', 'найти', 808, 813, 'positive'],
#  [2, '34889', 'Price', 'центр', 7, 12, 'neutral'],
#  [11, '34889', 'Price', 'редкий', 50, 56, 'positive'],
#  [12, '34889', 'Price', 'тёплый', 56, 62, 'neutral'],
#  [21, '34889', 'Price', 'давно', 114, 119, 'neutral'],
#  [23, '34889', 'Price', 'посетить', 129, 137, 'neutral'],
#  [29, '34889', 'Price', 'недалеко', 155, 163, 'neutral'],
#  [35, '34889', 'Price', 'лёгкий', 195, 201, 'neutral'],
#  [59, '34889', 'Price', 'чисто', 365, 370, 'neutral'],
#  [68, '34889', 'Price', 'назвать', 417, 424, 'positive'],
#  [76, '34889', 'Price', 'ваш', 466, 469, 'neutral'],
#  [81, '34889', 'Price', 'замечательный', 494, 507, 'positive'],
#  [82, '34889', 'Price', 'быстро', 507, 513, 'positive'],
#  [83, '34889', 'Price', 'сытно', 513, 518, 'neutral'],
#  [90, '34889', 'Price', 'потрясать', 546, 555, 'positive'],
#  [109, '34889', 'Price', 'каждый', 655, 661, 'neutral'],
#  [112, '34889', 'Price', 'оценить', 670, 677, 'neutral'],
#  [118, '34889', 'Price', 'тем', 707, 710, 'neutral'],
#  [119, '34889', 'Price', 'кто', 710, 713, 'neutral'],
#  [120, '34889', 'Price', 'хотеть', 713, 719, 'neutral'],
#  [121, '34889', 'Price', 'бы', 719, 721, 'neutral'],
#  [129, '34889', 'Price', 'удовольствие', 759, 771, 'positive'],
#  [133, '34889', 'Price', 'качественно', 781, 792, 'neutral'],
#  [137, '34889', 'Price', 'минус', 813, 818, 'neutral'],
#  [138, '34889', 'Price', 'всегда', 818, 824, 'neutral'],
#  [141, '34889', 'Price', 'любой', 830, 835, 'neutral'],
#  [121, '34889', 'Price', 'бы', 719, 721, 'neutral'],
#  [150, '34889', 'Price', 'зависеть', 863, 871, 'negative'],
#  [163, '34889', 'Price', 'себя', 920, 924, 'neutral'],
#  [137, '34889', 'Price', 'минус', 813, 818, 'neutral'],
#  [167, '34889', 'Price', 'здесь', 941, 946, 'neutral'],
#  [169, '34889', 'Price', 'отличный', 956, 964, 'neutral'],
#  [3, '11421', 'Whole', 'ресторан', 8, 16, 'positive'],
#  [19, '11421', 'Service', 'обслуживание', 86, 98, 'positive'],
#  [45, '11421', 'Food', 'кухня', 235, 240, 'positive'],
#  [39, '11421', 'Food', 'блюдо', 211, 216, 'positive'],
#  [29, '11421', 'Food', 'меню', 155, 159, 'positive'],
#  [59, '11421', 'Interior', 'музыка', 314, 320, 'positive'],
#  [35, '11421', 'Service', 'заказать', 179, 187, 'neutral'],
#  [12, '11421', 'Food', 'ужинать', 57, 64, 'positive'],
#  [38, '11421', 'Food', 'разнообразие', 199, 211, 'neutral'],
#  [27, '11421', 'Food', 'выбор', 149, 154, 'both'],
#  [16, '11421', 'Interior', '2 этаж', 73, 79, 'neutral'],
#  [17, '11421', 'Interior', '2 этаж', 74, 80, 'neutral'],
#  [8, '11421', 'Price', 'удовольствие', 32, 44, 'positive'],
#  [18, '11421', 'Price', 'отличный', 78, 86, 'neutral'],
#  [22, '11421', 'Price', 'быстро', 118, 124, 'neutral'],
#  [47, '11421', 'Price', 'никакой', 243, 250, 'negative'],
#  [55, '11421', 'Price', 'музыкант', 287, 295, 'positive'],
#  [18, '11421', 'Price', 'отличный', 78, 86, 'neutral'],
#  [8, '11421', 'Price', 'удовольствие', 32, 44, 'positive'],
#  [50, '38299', 'Interior', 'интерьер', 268, 276, 'positive'],
#  [74, '38299', 'Service', 'официант', 415, 423, 'positive'],
#  [11, '38299', 'Whole', 'заведение', 59, 68, 'positive'],
#  [88, '38299', 'Food', 'еда', 494, 497, 'positive'],
#  [128, '38299', 'Food', 'порция', 724, 730, 'neutral'],
#  [91, '38299', 'Food', 'салат', 506, 511, 'positive'],
#  [34, '38299', 'Interior', 'обстановка', 161, 171, 'positive'],
#  [40, '38299', 'Interior', 'зал', 213, 216, 'positive'],
#  [78, '38299', 'Service', 'ждать', 438, 443, 'negative'],
#  [115, '38299', 'Food', 'напиток', 629, 636, 'neutral'],
#  [141, '38299', 'Food', 'мясо', 794, 798, 'positive'],
#  [90, '38299', 'Service', 'заказать', 498, 506, 'neutral'],
#  [69, '38299', 'Service', 'молодой человек', 384, 399, 'positive'],
#  [83, '38299', 'Service', 'заказ', 464, 469, 'positive'],
#  [38, '38299', 'Interior', 'диванчик', 202, 210, 'positive'],
#  [69, '38299', 'Service', 'человек', 384, 391, 'positive'],
#  [118, '38299', 'Food', 'коктейль', 650, 658, 'positive'],
#  [110, '38299', 'Food', 'говядина', 608, 616, 'neutral'],
#  [135, '38299', 'Food', 'овощ', 764, 768, 'neutral'],
#  [82, '38299', 'Service', 'принять заказ', 457, 470, 'neutral'],
#  [83, '38299', 'Service', 'принять заказ', 464, 477, 'neutral'],
#  [94, '38299', 'Service', 'посоветовать', 518, 530, 'neutral'],
#  [59, '38299', 'Food', 'есть', 333, 337, 'positive'],
#  [80, '38299', 'Service', 'подойти', 449, 456, 'both'],
#  [125, '38299', 'Food', 'салатик', 700, 707, 'positive'],
#  [45, '38299', 'Service', 'отдать', 237, 243, 'positive'],
#  [33, '38299', 'Interior', 'уютный', 155, 161, 'neutral'],
#  [113, '38299', 'Food', 'стейк рибай', 622, 633, 'positive'],
#  [113, '38299', 'Food', 'рибай', 622, 627, 'positive'],
#  [91, '38299', 'Food', 'салат с говядина', 506, 522, 'positive'],
#  [62, '38299', 'Food', 'салат с говядина', 353, 369, 'neutral'],
#  [110, '38299', 'Food', 'салат с говядина', 608, 624, 'positive'],
#  [47, '38299', 'Service', 'гость', 252, 257, 'positive'],
#  [131, '38299', 'Food', 'заправка', 741, 749, 'positive'],
#  [128, '38299', 'Food', 'больший порция', 724, 738, 'neutral'],
#  [66, '38299', 'Interior', 'комната', 370, 377, 'positive'],
#  [5, '38299', 'Price', 'купон', 26, 31, 'positive'],
#  [140, '38299', 'Food', 'кусок', 789, 794, 'positive'],
#  [0, '38299', 'Price', 'случайно', 0, 8, 'neutral'],
#  [1, '38299', 'Price', 'увидеть', 8, 15, 'positive'],
#  [2, '38299', 'Price', 'акция', 15, 20, 'positive'],
#  [4, '38299', 'Price', 'сайт', 22, 26, 'neutral'],
#  [9, '38299', 'Price', 'посетить', 48, 56, 'neutral'],
#  [12, '38299', 'Price', 'жить', 68, 72, 'positive'],
#  [14, '38299', 'Price', 'московский', 74, 84, 'neutral'],
#  [23, '38299', 'Price', 'открыться', 104, 113, 'neutral'],
#  [27, '38299', 'Price', 'новый', 122, 127, 'neutral'],
#  [31, '38299', 'Price', 'зря', 147, 150, 'neutral'],
#  [44, '38299', 'Price', 'часть', 232, 237, 'neutral'],
#  [46, '38299', 'Price', 'некурящий', 243, 252, 'neutral'],
#  [49, '38299', 'Price', 'радовать', 260, 268, 'neutral'],
#  [60, '38299', 'Price', 'отдельный', 337, 346, 'neutral'],
#  [61, '38299', 'Price', 'детский', 346, 353, 'neutral'],
#  [79, '38299', 'Price', 'быстро', 443, 449, 'neutral'],
#  [86, '38299', 'Price', 'профессионально', 477, 492, 'neutral'],
#  [126, '38299', 'Price', 'достаточно', 707, 717, 'neutral'],
#  [130, '38299', 'Price', 'интересный', 731, 741, 'neutral'],
#  [150, '38299', 'Price', 'сытый', 847, 852, 'positive'],
#  [155, '38299', 'Price', 'вы', 869, 871, 'neutral'],
#  [156, '38299', 'Price', 'даже', 871, 875, 'neutral'],
#  [157, '38299', 'Price', 'без', 875, 878, 'neutral'],
#  [39, '10985', 'Interior', 'интерьер', 229, 237, 'neutral'],
#  [62, '10985', 'Whole', 'заведение', 357, 366, 'positive'],
#  [101, '10985', 'Food', 'кухня', 542, 547, 'neutral'],
#  [70, '10985', 'Whole', 'место', 394, 399, 'neutral'],
#  [88, '10985', 'Food', 'блюдо', 492, 497, 'positive'],
#  [130, '10985', 'Service', 'официантка', 701, 711, 'positive'],
#  [109, '10985', 'Food', 'порция', 592, 598, 'positive'],
#  [79, '10985', 'Food', 'меню', 439, 443, 'positive'],
#  [129, '10985', 'Service', 'сервис', 695, 701, 'neutral'],
#  [116, '10985', 'Food', 'горячий', 635, 642, 'neutral'],
#  [146, '10985', 'Service', 'ждать', 788, 793, 'negative'],
#  [114, '10985', 'Service', 'принести', 624, 632, 'positive'],
#  [156, '10985', 'Interior', 'столик', 825, 831, 'positive'],
#  [76, '10985', 'Service', 'заказать', 418, 426, 'neutral'],
#  [108, '10985', 'Food', 'закуска', 585, 592, 'neutral'],
#  [138, '10985', 'Service', 'заказ', 745, 750, 'positive'],
#  [144, '10985', 'Price', 'счёт', 776, 780, 'neutral'],
#  [46, '10985', 'Interior', 'стол', 265, 269, 'positive'],
#  [7, '10985', 'Whole', 'ресторанчик', 36, 47, 'neutral'],
#  [40, '10985', 'Interior', 'диванчик', 237, 245, 'positive'],
#  [160, '10985', 'Food', 'покушать', 840, 848, 'neutral'],
#  [104, '10985', 'Food', 'говядина', 563, 571, 'neutral'],
#  [118, '10985', 'Interior', 'посуда', 649, 655, 'positive'],
#  [105, '10985', 'Food', 'свинина', 571, 578, 'neutral'],
#  [33, '10985', 'Interior', 'второй этаж', 192, 203, 'neutral'],
#  [132, '10985', 'Service', 'здороваться', 713, 724, 'positive'],
#  [6, '10985', 'Food', 'китайский кухня', 27, 42, 'positive'],
#  [101, '10985', 'Food', 'китайский кухня', 542, 557, 'neutral'],
#  [120, '10985', 'Food', 'сервировка', 656, 666, 'neutral'],
#  [44, '10985', 'Service', 'скатерть', 255, 263, 'positive'],
#  [50, '10985', 'Interior', 'столовая', 278, 286, 'negative'],
#  [25, '10985', 'Interior', 'танцполый', 142, 151, 'positive'],
#  [175, '10985', 'Interior', 'антураж', 922, 929, 'neutral'],
#  [141, '10985', 'Service', 'вынести', 761, 768, 'positive'],
#  [13, '10985', 'Interior', 'первый этаж', 79, 90, 'neutral'],
#  [6, '10985', 'Whole', 'китайский ресторан', 27, 45, 'positive'],
#  [6, '10985', 'Whole', 'китайский ресторанчик', 27, 48, 'positive'],
#  [7, '10985', 'Whole', 'китайский ресторанчик', 36, 57, 'neutral'],
#  [53, '10985', 'Interior', 'люстра', 307, 313, 'positive'],
#  [1, '10985', 'Price', 'недалеко', 6, 14, 'neutral'],
#  [21, '10985', 'Price', 'внутри', 124, 130, 'neutral'],
#  [36, '10985', 'Price', 'приятно', 206, 213, 'neutral'],
#  [37, '10985', 'Price', 'удивить', 213, 220, 'positive'],
#  [48, '10985', 'Price', 'тип', 271, 274, 'neutral'],
#  [60, '10985', 'Price', 'никакой', 341, 348, 'neutral'],
#  [63, '10985', 'Price', 'неуютный', 366, 374, 'negative'],
#  [74, '10985', 'Price', 'сила', 408, 412, 'positive'],
#  [81, '10985', 'Price', 'порадовать', 445, 455, 'positive'],
#  [87, '10985', 'Price', 'состав', 486, 492, 'positive'],
#  [92, '10985', 'Price', 'картинка', 502, 510, 'neutral'],
#  [93, '10985', 'Price', 'даже', 510, 514, 'neutral'],
#  [102, '10985', 'Price', 'знакомый', 547, 555, 'neutral'],
#  [107, '10985', 'Price', 'пара', 581, 585, 'neutral'],
#  [117, '10985', 'Price', 'конечно', 642, 649, 'neutral'],
#  [123, '10985', 'Price', 'бы', 674, 676, 'neutral'],
#  [128, '10985', 'Price', 'повод', 690, 695, 'neutral'],
#  [142, '10985', 'Price', 'быстро', 768, 774, 'neutral'],
#  [147, '10985', 'Price', 'при', 793, 796, 'neutral'],
#  [153, '10985', 'Price', 'занятый', 813, 820, 'neutral'],
#  [154, '10985', 'Price', 'весь', 820, 824, 'neutral'],
#  [169, '10985', 'Price', 'любить', 883, 889, 'positive'],
#  [171, '10985', 'Price', 'же', 892, 894, 'neutral'],
#  [172, '10985', 'Price', 'чтоб', 894, 898, 'neutral'],
#  [62, '7154', 'Whole', 'место', 325, 330, 'positive'],
#  [21, '7154', 'Service', 'персонал', 106, 114, 'positive'],
#  [38, '7154', 'Food', 'салат', 201, 206, 'neutral'],
#  [53, '7154', 'Interior', 'музыка', 287, 293, 'positive'],
#  [33, '7154', 'Food', 'готовить', 161, 169, 'positive'],
#  [48, '7154', 'Food', 'есть', 251, 255, 'positive'],
#  [37, '7154', 'Food', 'мясной', 195, 201, 'neutral'],
#  [16, '7154', 'Whole', 'посидеть', 80, 88, 'positive'],
#  [63, '7154', 'Service', 'советовать', 330, 340, 'positive'],
#  [9, '7154', 'Whole', 'банкет', 44, 50, 'positive'],
#  [1, '7154', 'Price', 'нравиться', 5, 14, 'positive'],
#  [7, '7154', 'Price', 'там', 33, 36, 'neutral'],
#  [8, '7154', 'Price', 'отмечать', 36, 44, 'positive'],
#  [11, '7154', 'Price', 'разный', 51, 57, 'neutral'],
#  [23, '7154', 'Price', 'всегда', 119, 125, 'positive'],
#  [27, '7154', 'Price', 'ночью', 139, 144, 'neutral'],
#  [36, '7154', 'Price', 'любить', 189, 195, 'positive'],
#  [41, '7154', 'Price', 'конечно', 212, 219, 'neutral'],
#  [42, '7154', 'Price', 'же', 219, 221, 'neutral'],
#  [56, '7154', 'Price', '=', 302, 303, 'neutral'],
#  [57, '7154', 'Price', 'вообщий', 303, 310, 'neutral'],
#  [36, '7154', 'Price', 'любить', 189, 195, 'positive'],
#  [45, '10798', 'Food', 'кухня', 247, 252, 'neutral'],
#  [10, '10798', 'Whole', 'место', 55, 60, 'positive'],
#  [65, '10798', 'Price', 'цена', 352, 356, 'neutral'],
#  [71, '10798', 'Service', 'девушка', 382, 389, 'positive'],
#  [38, '10798', 'Interior', 'музыка', 213, 219, 'positive'],
#  [23, '10798', 'Interior', 'обстановка', 127, 137, 'positive'],
#  [69, '10798', 'Service', 'сервис', 368, 374, 'positive'],
#  [74, '10798', 'Service', 'принести', 400, 408, 'neutral'],
#  [3, '10798', 'Service', 'молодой человек', 12, 27, 'neutral'],
#  [4, '10798', 'Service', 'молодой человек', 19, 34, 'positive'],
#  [75, '10798', 'Service', 'заказ', 408, 413, 'positive'],
#  [18, '10798', 'Whole', 'провести время', 102, 116, 'neutral'],
#  [19, '10798', 'Whole', 'провести время', 110, 124, 'positive'],
#  [80, '10798', 'Food', 'алкоголь', 431, 439, 'neutral'],
#  [4, '10798', 'Service', 'человек', 19, 26, 'positive'],
#  [37, '10798', 'Interior', 'свет', 209, 213, 'positive'],
#  [28, '10798', 'Interior', 'свеча', 162, 167, 'positive'],
#  [44, '10798', 'Food', 'японский кухня', 239, 253, 'neutral'],
#  [45, '10798', 'Food', 'японский кухня', 247, 261, 'neutral'],
#  [22, '10798', 'Interior', 'уютный', 121, 127, 'neutral'],
#  [102, '10798', 'Service', 'советовать', 511, 521, 'positive'],
#  [54, '10798', 'Food', 'европейский кухня', 290, 307, 'neutral'],
#  [45, '10798', 'Food', 'европейский кухня', 247, 264, 'neutral'],
#  [30, '10798', 'Food', 'вода', 168, 172, 'positive'],
#  [75, '10798', 'Service', 'нести заказ', 408, 419, 'negative'],
#  [78, '10798', 'Food', 'коктель', 423, 430, 'positive'],
#  [35, '10798', 'Interior', 'кресло', 193, 199, 'positive'],
#  [12, '10798', 'Price', 'действительно', 64, 77, 'neutral'],
#  [13, '10798', 'Price', 'стоить', 77, 83, 'neutral'],
#  [15, '10798', 'Price', 'каждый', 88, 94, 'neutral'],
#  [17, '10798', 'Price', 'приятно', 95, 102, 'neutral'],
#  [21, '10798', 'Price', 'тихий', 116, 121, 'neutral'],
#  [26, '10798', 'Price', 'мило', 148, 152, 'neutral'],
#  [15, '10798', 'Price', 'каждый', 88, 94, 'neutral'],
#  [40, '10798', 'Price', 'даже', 225, 229, 'neutral'],
#  [51, '10798', 'Price', 'сложно', 270, 276, 'neutral'],
#  [63, '10798', 'Price', 'достаточно', 336, 346, 'neutral'],
#  [73, '10798', 'Price', 'быстро', 394, 400, 'neutral'],
#  [8, '32859', 'Whole', 'ресторан', 38, 46, 'positive'],
#  [103, '32859', 'Interior', 'интерьер', 540, 548, 'positive'],
#  [121, '32859', 'Service', 'официант', 643, 651, 'positive'],
#  [92, '32859', 'Interior', 'зал', 485, 488, 'neutral'],
#  [138, '32859', 'Whole', 'вечер', 734, 739, 'positive'],
#  [113, '32859', 'Interior', 'стол', 605, 609, 'positive'],
#  [120, '32859', 'Food', 'оформить', 635, 643, 'neutral'],
#  [69, '32859', 'Service', 'шеф-повар', 364, 373, 'positive'],
#  [148, '32859', 'Whole', 'праздник', 791, 799, 'positive'],
#  [65, '32859', 'Food', 'есть', 343, 347, 'positive'],
#  [33, '32859', 'Service', 'администрация', 178, 191, 'positive'],
#  [71, '32859', 'Service', 'заказывать', 375, 385, 'neutral'],
#  [137, '32859', 'Whole', 'провести вечер', 726, 740, 'neutral'],
#  [138, '32859', 'Whole', 'провести вечер', 734, 748, 'positive'],
#  [38, '32859', 'Service', 'отношение', 209, 218, 'positive'],
#  [43, '32859', 'Service', 'встреча', 230, 237, 'positive'],
#  [100, '32859', 'Interior', 'уютный', 518, 524, 'positive'],
#  [151, '32859', 'Service', 'рекомендовать', 805, 818, 'positive'],
#  [54, '32859', 'Service', 'совет', 294, 299, 'positive'],
#  [73, '32859', 'Food', 'судак', 386, 391, 'neutral'],
#  [52, '32859', 'Service', 'дать', 283, 287, 'negative'],
#  [47, '32859', 'Service', 'выслушать', 258, 267, 'positive'],
#  [38, '32859', 'Service', 'отношение к свой дело', 209, 230, 'positive'],
#  [39, '32859', 'Service', 'отношение к свой дело', 218, 239, 'positive'],
#  [40, '32859', 'Service', 'отношение к свой дело', 219, 240, 'neutral'],
#  [41, '32859', 'Service', 'отношение к свой дело', 223, 244, 'positive'],
#  [2, '32859', 'Price', 'отмечать', 9, 17, 'neutral'],
#  [4, '32859', 'Price', 'рождение', 21, 29, 'positive'],
#  [11, '32859', 'Price', 'выразить', 59, 67, 'neutral'],
#  [12, '32859', 'Price', 'огромный', 67, 75, 'positive'],
#  [13, '32859', 'Price', 'благодарность', 75, 88, 'neutral'],
#  [21, '32859', 'Price', 'мало', 117, 121, 'neutral'],
#  [22, '32859', 'Price', 'важный', 121, 127, 'neutral'],
#  [32, '32859', 'Price', 'поблагодарить', 165, 178, 'neutral'],
#  [35, '32859', 'Price', 'отличный', 193, 201, 'positive'],
#  [42, '32859', 'Price', 'при', 227, 230, 'neutral'],
#  [44, '32859', 'Price', 'всегда', 237, 243, 'neutral'],
#  [45, '32859', 'Price', 'дружелюбный', 243, 254, 'positive'],
#  [57, '32859', 'Price', 'бы', 306, 308, 'neutral'],
#  [61, '32859', 'Price', 'порадовать', 321, 331, 'positive'],
#  [79, '32859', 'Price', 'сказка', 423, 429, 'positive'],
#  [85, '32859', 'Price', 'весь', 451, 455, 'neutral'],
#  [104, '32859', 'Price', 'отдельный', 548, 557, 'neutral'],
#  [110, '32859', 'Price', 'прекрасный', 586, 596, 'positive'],
#  [45, '32859', 'Price', 'дружелюбный', 243, 254, 'positive'],
#  [124, '32859', 'Price', 'улыбчивый', 663, 672, 'positive'],
#  [126, '32859', 'Price', 'делать', 675, 681, 'neutral'],
#  [128, '32859', 'Price', 'время', 682, 687, 'neutral'],
#  [144, '32859', 'Price', 'вы', 767, 769, 'neutral'],
#  [12, '32859', 'Price', 'огромный', 67, 75, 'positive'],
#  [144, '32859', 'Price', 'вы', 767, 769, 'neutral'],
#  [85, '32859', 'Price', 'весь', 451, 455, 'neutral'],
#  [154, '32859', 'Price', 'друг', 826, 830, 'positive'],
#  [156, '32859', 'Price', 'знакомый', 831, 839, 'positive'],
#  [144, '32859', 'Price', 'вы', 767, 769, 'neutral'],
#  [160, '32859', 'Price', 'процветание', 847, 858, 'positive'],
#  [163, '32859', 'Price', 'виктория', 867, 875, 'positive'],
#  [96, '1269', 'Service', 'обслуживание', 526, 538, 'positive'],
#  [41, '1269', 'Interior', 'интерьер', 198, 206, 'positive'],
#  [48, '1269', 'Food', 'кухня', 242, 247, 'positive'],
#  [113, '1269', 'Food', 'блюдо', 622, 627, 'positive'],
#  [114, '1269', 'Food', 'напиток', 627, 634, 'neutral'],
#  [45, '1269', 'Interior', 'стол', 225, 229, 'positive'],
#  [58, '1269', 'Service', 'человек', 289, 296, 'positive'],
#  [5, '1269', 'Whole', 'впечатление', 30, 41, 'positive'],
#  [61, '1269', 'Service', 'работать', 308, 316, 'positive'],
#  [159, '1269', 'Whole', 'праздник', 843, 851, 'positive'],
#  [110, '1269', 'Interior', 'посуда', 601, 607, 'negative'],
#  [131, '1269', 'Service', 'отношение', 715, 724, 'positive'],
#  [108, '1269', 'Service', 'убираться', 586, 595, 'positive'],
#  [120, '1269', 'Service', 'приветливый', 658, 669, 'positive'],
#  [44, '1269', 'Food', 'сервировка', 215, 225, 'positive'],
#  [70, '1269', 'Whole', 'банкет', 357, 363, 'positive'],
#  [2, '1269', 'Price', 'хотеть', 10, 16, 'neutral'],
#  [7, '1269', 'Price', 'свадьба', 42, 49, 'positive'],
#  [14, '1269', 'Price', 'ваш', 85, 88, 'neutral'],
#  [19, '1269', 'Price', 'год', 108, 111, 'neutral'],
#  [21, '1269', 'Price', 'если', 116, 120, 'neutral'],
#  [37, '1269', 'Price', 'именно', 175, 181, 'neutral'],
#  [40, '1269', 'Price', 'замечательный', 185, 198, 'neutral'],
#  [69, '1269', 'Price', 'свадебный', 348, 357, 'positive'],
#  [76, '1269', 'Whole', 'александр', 393, 402, 'neutral'],
#  [79, '1269', 'Price', 'доброжелательный', 415, 431, 'positive'],
#  [80, '1269', 'Price', 'знающий', 431, 438, 'positive'],
#  [111, '1269', 'Price', 'появляться', 607, 617, 'neutral'],
#  [112, '1269', 'Price', 'новый', 617, 622, 'neutral'],
#  [121, '1269', 'Price', 'улыбка', 669, 675, 'positive'],
#  [123, '1269', 'Price', 'вы', 682, 684, 'neutral'],
#  [124, '1269', 'Price', 'огромный', 684, 692, 'neutral'],
#  [14, '1269', 'Price', 'ваш', 85, 88, 'neutral'],
#  [14, '1269', 'Price', 'ваш', 85, 88, 'neutral'],
#  [123, '1269', 'Price', 'вы', 682, 684, 'neutral'],
#  [148, '1269', 'Price', 'благодарность', 790, 803, 'positive'],
#  [163, '1269', 'Price', 'вместе', 863, 869, 'positive'],
#  [164, '1269', 'Price', 'устроить', 869, 877, 'neutral'],
#  [123, '1269', 'Price', 'вы', 682, 684, 'neutral'],
#  [124, '1269', 'Price', 'огромный', 684, 692, 'neutral'],
#  [123, '1269', 'Price', 'вы', 682, 684, 'neutral'],
#  [14, '1269', 'Price', 'ваш', 85, 88, 'neutral'],
#  [123, '1269', 'Price', 'вы', 682, 684, 'neutral'],
#  [179, '1269', 'Price', 'благодарный', 935, 946, 'neutral'],
#  [180, '1269', 'Price', 'посетитель', 946, 956, 'positive'],
#  [119, '37220', 'Whole', 'ресторан', 576, 584, 'neutral'],
#  [4, '37220', 'Interior', 'интерьер', 22, 30, 'positive'],
#  [0, '37220', 'Food', 'кухня', 0, 5, 'positive'],
#  [25, '37220', 'Service', 'официантка', 142, 152, 'positive'],
#  [21, '37220', 'Service', 'девушка', 114, 121, 'positive'],
#  [44, '37220', 'Interior', 'столик', 245, 251, 'neutral'],
#  [63, '37220', 'Interior', 'стол', 350, 354, 'neutral'],
#  [3, '37220', 'Service', 'повар', 17, 22, 'neutral'],
#  [24, '37220', 'Service', 'работать', 134, 142, 'neutral'],
#  [29, '37220', 'Service', 'менеджер', 165, 173, 'neutral'],
#  [13, '37220', 'Food', 'есть', 66, 70, 'neutral'],
#  [123, '37220', 'Whole', 'хозяин', 595, 601, 'neutral'],
#  [16, '37220', 'Service', 'гость', 88, 93, 'neutral'],
#  [48, '37220', 'Service', 'ответить', 269, 277, 'positive'],
#  [10, '37220', 'Price', 'более', 57, 62, 'neutral'],
#  [12, '37220', 'Price', 'год', 63, 66, 'neutral'],
#  [15, '37220', 'Price', 'постоянный', 78, 88, 'neutral'],
#  [33, '37220', 'Price', 'желание', 188, 195, 'positive'],
#  [37, '37220', 'Price', 'спросить', 211, 219, 'neutral'],
#  [39, '37220', 'Price', 'ли', 227, 229, 'neutral'],
#  [54, '37220', 'Price', 'именно', 299, 305, 'neutral'],
#  [68, '37220', 'Price', 'если', 372, 376, 'neutral'],
#  [71, '37220', 'Price', 'вы', 385, 387, 'neutral'],
#  [73, '37220', 'Price', 'здесь', 393, 398, 'neutral'],
#  [83, '37220', 'Price', 'там', 435, 438, 'neutral'],
#  [96, '37220', 'Price', 'после', 475, 480, 'neutral'],
#  [33, '37220', 'Price', 'желание', 188, 195, 'positive'],
#  [103, '37220', 'Price', 'ни', 508, 510, 'neutral'],
#  [105, '37220', 'Price', 'кто', 511, 514, 'neutral'],
#  [71, '37220', 'Price', 'вы', 385, 387, 'neutral'],
#  [113, '37220', 'Price', 'ваш', 557, 560, 'neutral'],
#  [71, '37220', 'Price', 'вы', 385, 387, 'neutral'],
#  [105, '37220', 'Price', 'кто', 511, 514, 'neutral'],
#  [73, '37220', 'Price', 'здесь', 393, 398, 'neutral'],
#  [105, '37220', 'Price', 'кто', 511, 514, 'neutral'],
#  [99, '6668', 'Whole', 'ресторан', 552, 560, 'positive'],
#  [71, '6668', 'Service', 'обслуживание', 403, 415, 'positive'],
#  [169, '6668', 'Service', 'официант', 893, 901, 'positive'],
#  [192, '6668', 'Service', 'персонал', 1005, 1013, 'neutral'],
#  [152, '6668', 'Food', 'порция', 822, 828, 'positive'],
#  [113, '6668', 'Food', 'салат', 614, 619, 'positive'],
#  [167, '6668', 'Interior', 'десерт', 883, 889, 'positive'],
#  [76, '6668', 'Service', 'обслуживать', 423, 434, 'positive'],
#  [70, '6668', 'Service', 'сервис', 397, 403, 'neutral'],
#  [120, '6668', 'Food', 'горячий', 648, 655, 'neutral'],
#  [119, '6668', 'Service', 'ждать', 643, 648, 'negative'],
#  [89, '6668', 'Food', 'вино', 509, 513, 'neutral'],
#  [92, '6668', 'Service', 'принести', 524, 532, 'positive'],
#  [104, '6668', 'Interior', 'столик', 576, 582, 'positive'],
#  [84, '6668', 'Service', 'заказ', 475, 480, 'positive'],
#  [112, '6668', 'Food', 'чай', 611, 614, 'neutral'],
#  [114, '6668', 'Food', 'готовить', 619, 627, 'neutral'],
#  [4, '6668', 'Whole', 'ресторанчик', 27, 38, 'positive'],
#  [82, '6668', 'Service', 'помочь', 468, 474, 'positive'],
#  [108, '6668', 'Service', 'человек', 589, 596, 'positive'],
#  [79, '6668', 'Service', 'встречать', 442, 451, 'positive'],
#  [111, '6668', 'Food', 'пить', 607, 611, 'neutral'],
#  [198, '6668', 'Food', 'ужин', 1045, 1049, 'neutral'],
#  [85, '6668', 'Service', 'посоветовать', 480, 492, 'positive'],
#  [134, '6668', 'Food', 'телятина', 731, 739, 'neutral'],
#  [180, '6668', 'Food', 'есть', 942, 946, 'neutral'],
#  [84, '6668', 'Service', 'заказ принести', 475, 489, 'positive'],
#  [92, '6668', 'Service', 'заказ принести', 524, 538, 'positive'],
#  [160, '6668', 'Food', 'наесться', 854, 862, 'positive'],
#  [6, '6668', 'Whole', 'вечером', 45, 52, 'neutral'],
#  [43, '6668', 'Service', 'работа', 254, 260, 'positive'],
#  [22, '6668', 'Service', 'показать', 135, 143, 'positive'],
#  [171, '6668', 'Service', 'советовать', 906, 916, 'positive'],
#  [25, '6668', 'Service', 'гость', 152, 157, 'positive'],
#  [38, '6668', 'Service', 'выбрать', 222, 229, 'positive'],
#  [88, '6668', 'Price', 'недорогой', 500, 509, 'neutral'],
#  [192, '6668', 'Service', 'персонал ресторан', 1005, 1022, 'neutral'],
#  [99, '6668', 'Service', 'персонал ресторан', 552, 569, 'positive'],
#  [14, '6668', 'Food', 'кормить', 83, 90, 'positive'],
#  [29, '6668', 'Interior', 'красота', 180, 187, 'positive'],
#  [1, '6668', 'Price', 'посетить', 2, 10, 'neutral'],
#  [12, '6668', 'Price', 'нигде', 76, 81, 'neutral'],
#  [18, '6668', 'Price', 'плохой', 113, 119, 'neutral'],
#  [21, '6668', 'Price', 'пытаться', 127, 135, 'neutral'],
#  [23, '6668', 'Price', 'приехать', 143, 151, 'neutral'],
#  [34, '6668', 'Price', 'ночь', 207, 211, 'neutral'],
#  [54, '6668', 'Price', 'повод', 306, 311, 'neutral'],
#  [34, '6668', 'Price', 'ночь', 207, 211, 'neutral'],
#  [69, '6668', 'Price', 'слово', 392, 397, 'neutral'],
#  [81, '6668', 'Price', 'по-домашнему', 456, 468, 'positive'],
#  [94, '6668', 'Price', 'быстро', 534, 540, 'neutral'],
#  [101, '6668', 'Price', 'занятый', 564, 571, 'neutral'],
#  [102, '6668', 'Price', 'весь', 571, 575, 'neutral'],
#  [106, '6668', 'Price', 'там', 583, 586, 'neutral'],
#  [109, '6668', 'Price', 'давно', 596, 601, 'neutral'],
#  [115, '6668', 'Price', 'минута', 627, 633, 'neutral'],
#  [117, '6668', 'Price', 'потом', 635, 640, 'neutral'],
#  [123, '6668', 'Price', 'время', 666, 671, 'neutral'],
#  [137, '6668', 'Food', 'буженина', 745, 753, 'neutral'],
#  [139, '6668', 'Price', 'гриль', 755, 760, 'neutral'],
#  [146, '6668', 'Price', 'довольно', 786, 794, 'neutral'],
#  [154, '6668', 'Price', 'огромный', 830, 838, 'neutral'],
#  [54, '6668', 'Price', 'повод', 306, 311, 'neutral'],
#  [187, '6668', 'Price', 'хотеть', 972, 978, 'neutral'],
#  [5, '18983', 'Whole', 'ресторан', 20, 28, 'positive'],
#  [61, '18983', 'Service', 'обслуживание', 285, 297, 'positive'],
#  [75, '18983', 'Interior', 'интерьер', 357, 365, 'positive'],
#  [65, '18983', 'Service', 'официант', 310, 318, 'positive'],
#  [102, '18983', 'Whole', 'заведение', 497, 506, 'positive'],
#  [110, '18983', 'Whole', 'место', 545, 550, 'positive'],
#  [10, '18983', 'Food', 'еда', 50, 53, 'positive'],
#  [46, '18983', 'Interior', 'десерт', 204, 210, 'positive'],
#  [82, '18983', 'Interior', 'музыка', 404, 410, 'positive'],
#  [74, '18983', 'Interior', 'обстановка', 347, 357, 'neutral'],
#  [24, '18983', 'Food', 'мясо', 122, 126, 'positive'],
#  [35, '18983', 'Food', 'соус', 153, 157, 'negative'],
#  [22, '18983', 'Food', 'рыба', 115, 119, 'positive'],
#  [28, '18983', 'Food', 'вкус', 135, 139, 'neutral'],
#  [50, '18983', 'Food', 'мороженое', 227, 236, 'positive'],
#  [7, '18983', 'Whole', 'впечатление', 29, 40, 'positive'],
#  [66, '18983', 'Food', 'есть', 318, 322, 'positive'],
#  [67, '18983', 'Service', 'приветливый', 322, 333, 'positive'],
#  [59, '18983', 'Food', 'приготовление', 271, 284, 'neutral'],
#  [109, '18983', 'Interior', 'свободный место', 536, 551, 'neutral'],
#  [110, '18983', 'Interior', 'свободный место', 545, 560, 'positive'],
#  [19, '18983', 'Whole', 'китайский ресторан', 95, 113, 'neutral'],
#  [5, '18983', 'Whole', 'китайский ресторан', 20, 38, 'positive'],
#  [0, '18983', 'Price', 'несколько', 0, 9, 'neutral'],
#  [11, '18983', 'Price', 'достаточно', 53, 63, 'neutral'],
#  [33, '18983', 'Price', 'тем', 148, 151, 'neutral'],
#  [34, '18983', 'Price', 'же', 151, 153, 'neutral'],
#  [37, '18983', 'Price', 'конечно', 160, 167, 'neutral'],
#  [47, '18983', 'Food', 'я', 210, 211, 'neutral'],
#  [56, '18983', 'Price', 'естественно', 255, 266, 'neutral'],
#  [60, '18983', 'Price', '2', 284, 285, 'neutral'],
#  [63, '18983', 'Price', 'зависеть', 300, 308, 'negative'],
#  [76, '18983', 'Price', 'довольно', 365, 373, 'neutral'],
#  [83, '18983', 'Price', 'слишком', 410, 417, 'negative'],
#  [88, '18983', 'Price', 'русский', 441, 448, 'neutral'],
#  [94, '18983', 'Price', 'плюс', 465, 469, 'neutral'],
#  [103, '18983', 'Price', 'всегда', 506, 512, 'neutral'],
#  [104, '18983', 'Price', 'мало', 512, 516, 'neutral'],
#  [103, '18983', 'Price', 'всегда', 506, 512, 'neutral'],
#  [13, '32856', 'Service', 'обслуживание', 77, 89, 'positive'],
#  [163, '32856', 'Whole', 'заведение', 862, 871, 'positive'],
#  [11, '32856', 'Food', 'кухня', 71, 76, 'positive'],
#  [119, '32856', 'Food', 'салат', 640, 645, 'positive'],
#  [137, '32856', 'Interior', 'десерт', 724, 730, 'positive'],
#  [84, '32856', 'Interior', 'обстановка', 440, 450, 'positive'],
#  [36, '32856', 'Interior', 'зал', 194, 197, 'neutral'],
#  [83, '32856', 'Service', 'заказ', 435, 440, 'neutral'],
#  [37, '32856', 'Interior', 'стол', 197, 201, 'positive'],
#  [77, '32856', 'Interior', 'диван', 414, 419, 'positive'],
#  [30, '32856', 'Food', 'покушать', 165, 173, 'neutral'],
#  [19, '32856', 'Service', 'встречать', 116, 125, 'positive'],
#  [103, '32856', 'Service', 'ребята', 553, 559, 'positive'],
#  [82, '32856', 'Service', 'принять заказ', 428, 441, 'neutral'],
#  [83, '32856', 'Service', 'принять заказ', 435, 448, 'neutral'],
#  [166, '32856', 'Whole', 'праздник', 882, 890, 'positive'],
#  [39, '32856', 'Service', 'заказывать', 203, 213, 'neutral'],
#  [183, '32856', 'Service', 'отношение', 969, 978, 'positive'],
#  [93, '32856', 'Interior', 'тарелка', 494, 501, 'negative'],
#  ...]

# %%
sent_extracted_data_final = []
for line in sent_extracted_data:
    sent_extracted_data_final.append(line[1:7])
sent_extracted_data_final
# Out:
# [['37784', 'Service', 'обслуживание', 259, 271, 'positive'],
#  ['37784', 'Food', 'кухня', 97, 102, 'positive'],
#  ['37784', 'Whole', 'место', 435, 440, 'positive'],
#  ['37784', 'Food', 'блюдо', 135, 140, 'neutral'],
#  ['37784', 'Service', 'персонал', 357, 365, 'positive'],
#  ['37784', 'Food', 'порция', 160, 166, 'neutral'],
#  ['37784', 'Food', 'салат', 166, 171, 'neutral'],
#  ['37784', 'Food', 'горячий', 128, 135, 'neutral'],
#  ['37784', 'Food', 'мясо', 140, 144, 'positive'],
#  ['37784', 'Interior', 'стол', 416, 420, 'positive'],
#  ['37784', 'Service', 'человек', 376, 383, 'positive'],
#  ['37784', 'Food', 'салат цезарь', 166, 178, 'neutral'],
#  ['37784', 'Food', 'салат цезарь', 171, 183, 'positive'],
#  ['37784', 'Food', 'горячий блюдо', 128, 141, 'neutral'],
#  ['37784', 'Food', 'горячий блюдо', 135, 148, 'neutral'],
#  ['37784', 'Food', 'попробовать', 224, 235, 'positive'],
#  ['37784', 'Food', 'цезарь', 171, 177, 'both'],
#  ['37784', 'Whole', 'вечером', 46, 53, 'positive'],
#  ['37784', 'Food', 'выбор', 90, 95, 'neutral'],
#  ['37784', 'Interior', 'уютный', 429, 435, 'neutral'],
#  ['37784', 'Food', 'порция салат', 160, 172, 'neutral'],
#  ['37784', 'Food', 'порция салат', 166, 178, 'neutral'],
#  ['37784', 'Service', 'совет', 2, 7, 'positive'],
#  ['37784', 'Food', 'большой выбор', 83, 96, 'neutral'],
#  ['37784', 'Food', 'большой выбор', 90, 103, 'neutral'],
#  ['37784', 'Service', 'бронировать', 405, 416, 'neutral'],
#  ['37784', 'Service', 'бронировать стол', 405, 421, 'neutral'],
#  ['37784', 'Interior', 'бронировать стол', 416, 432, 'neutral'],
#  ['37784', 'Whole', 'настроение', 331, 341, 'positive'],
#  ['37784', 'Food', 'количество', 290, 300, 'neutral'],
#  ['37784', 'Price', 'друг', 7, 11, 'positive'],
#  ['37784', 'Price', 'посетить', 11, 19, 'neutral'],
#  ['37784', 'Price', 'людно', 58, 63, 'neutral'],
#  ['37784', 'Price', 'порадовать', 118, 128, 'positive'],
#  ['37784', 'Price', 'огромный', 152, 160, 'neutral'],
#  ['37784', 'Price', 'главное', 196, 203, 'neutral'],
#  ['37784', 'Price', 'отлично', 309, 316, 'neutral'],
#  ['37784', 'Price', 'подарить', 316, 324, 'positive'],
#  ['37784', 'Price', 'говорить', 365, 373, 'neutral'],
#  ['37784', 'Price', 'бывать', 383, 389, 'neutral'],
#  ['35635', 'Whole', 'ресторан', 79, 87, 'positive'],
#  ['35635', 'Service', 'обслуживание', 127, 139, 'neutral'],
#  ['35635', 'Service', 'официант', 422, 430, 'positive'],
#  ['35635', 'Food', 'кухня', 121, 126, 'positive'],
#  ['35635', 'Food', 'меню', 403, 407, 'positive'],
#  ['35635', 'Interior', 'атмосфера', 139, 148, 'positive'],
#  ['35635', 'Service', 'встретить', 293, 302, 'positive'],
#  ['35635', 'Food', 'напиток', 460, 467, 'neutral'],
#  ['35635', 'Whole', 'вечер', 578, 583, 'positive'],
#  ['35635', 'Food', 'поесть', 706, 712, 'positive'],
#  ['35635', 'Service', 'заказ', 701, 706, 'positive'],
#  ['35635', 'Service', 'помочь', 448, 454, 'positive'],
#  ['35635', 'Whole', 'впечатление', 252, 263, 'positive'],
#  ['35635', 'Service', 'подойти', 364, 371, 'both'],
#  ['35635', 'Whole', 'вечером', 277, 284, 'positive'],
#  ['35635', 'Whole', 'визит', 222, 227, 'neutral'],
#  ['35635', 'Service', 'дать меню', 399, 408, 'neutral'],
#  ['35635', 'Service', 'дать меню', 403, 412, 'positive'],
#  ['35635', 'Food', 'выбор', 455, 460, 'neutral'],
#  ['35635', 'Service', 'работа', 777, 783, 'neutral'],
#  ['35635', 'Service', 'сделать заказ', 694, 707, 'neutral'],
#  ['35635', 'Service', 'сделать заказ', 701, 714, 'positive'],
#  ['35635', 'Service', 'дать', 399, 403, 'neutral'],
#  ['35635', 'Whole', 'настроение', 149, 159, 'negative'],
#  ['35635', 'Price', 'давно', 0, 5, 'neutral'],
#  ['35635', 'Price', 'хотеть', 5, 11, 'neutral'],
#  ['35635', 'Price', 'время', 36, 41, 'neutral'],
#  ['35635', 'Price', 'несколько', 59, 68, 'neutral'],
#  ['35635', 'Price', 'год', 68, 71, 'neutral'],
#  ['35635', 'Whole', 'водограй', 93, 101, 'neutral'],
#  ['35635', 'Price', 'всегда', 102, 108, 'neutral'],
#  ['35635', 'Price', 'нравиться', 111, 120, 'positive'],
#  ['35635', 'Price', 'всегда', 102, 108, 'neutral'],
#  ['35635', 'Price', 'чувствоваться', 174, 187, 'neutral'],
#  ['35635', 'Price', 'никто', 286, 291, 'neutral'],
#  ['35635', 'Price', 'минута', 353, 359, 'neutral'],
#  ['35635', 'Price', 'кто-то', 371, 377, 'neutral'],
#  ['35635', 'Price', 'ожидать', 415, 422, 'neutral'],
#  ['35635', 'Price', 'бы', 472, 474, 'neutral'],
#  ['35635', 'Price', 'ли', 518, 520, 'neutral'],
#  ['35635', 'Price', 'при', 536, 539, 'neutral'],
#  ['35635', 'Price', 'условие', 539, 546, 'neutral'],
#  ['35635', 'Price', 'высокий', 557, 564, 'neutral'],
#  ['35635', 'Price', 'ужас', 571, 575, 'negative'],
#  ['35635', 'Price', 'даже', 643, 647, 'neutral'],
#  ['35635', 'Price', 'отличие', 659, 666, 'neutral'],
#  ['35635', 'Price', 'минута', 353, 359, 'neutral'],
#  ['35635', 'Price', 'себя', 725, 729, 'neutral'],
#  ['35635', 'Price', 'себя', 725, 729, 'neutral'],
#  ['35635', 'Price', 'оказываться', 828, 839, 'neutral'],
#  ['35635', 'Price', 'вопрос', 862, 868, 'neutral'],
#  ['35635', 'Price', 'искать', 990, 996, 'neutral'],
#  ['35635', 'Price', 'новый', 996, 1001, 'positive'],
#  ['17999', 'Service', 'обслуживание', 774, 786, 'positive'],
#  ['17999', 'Service', 'официант', 234, 242, 'positive'],
#  ['17999', 'Food', 'кухня', 307, 312, 'positive'],
#  ['17999', 'Whole', 'место', 130, 135, 'positive'],
#  ['17999', 'Food', 'еда', 314, 317, 'positive'],
#  ['17999', 'Food', 'меню', 250, 254, 'positive'],
#  ['17999', 'Service', 'встретить', 190, 199, 'positive'],
#  ['17999', 'Service', 'принести', 242, 250, 'neutral'],
#  ['17999', 'Interior', 'столик', 221, 227, 'positive'],
#  ['17999', 'Price', 'счёт', 579, 583, 'neutral'],
#  ['17999', 'Food', 'сушить', 86, 92, 'positive'],
#  ['17999', 'Service', 'принести меню', 242, 255, 'neutral'],
#  ['17999', 'Service', 'принести меню', 250, 263, 'positive'],
#  ['17999', 'Service', 'заказ принять', 332, 345, 'positive'],
#  ['17999', 'Service', 'чаевой', 529, 535, 'negative'],
#  ['17999', 'Service', 'посадить', 205, 213, 'positive'],
#  ['17999', 'Food', 'сок', 356, 359, 'positive'],
#  ['17999', 'Interior', 'уголок', 228, 234, 'neutral'],
#  ['17999', 'Food', 'невский', 69, 76, 'positive'],
#  ['17999', 'Price', 'открыться', 5, 14, 'neutral'],
#  ['17999', 'Price', 'рядом', 31, 36, 'neutral'],
#  ['17999', 'Price', 'всегда', 92, 98, 'neutral'],
#  ['17999', 'Price', 'радовать', 98, 106, 'positive'],
#  ['17999', 'Price', 'время', 117, 122, 'neutral'],
#  ['17999', 'Price', 'выбирать', 122, 130, 'neutral'],
#  ['17999', 'Price', 'рождение', 153, 161, 'positive'],
#  ['17999', 'Price', 'минута', 271, 277, 'positive'],
#  ['17999', 'Price', 'подруга', 277, 284, 'positive'],
#  ['17999', 'Price', 'без', 396, 399, 'neutral'],
#  ['17999', 'Price', 'разный', 496, 502, 'neutral'],
#  ['17999', 'Price', 'или', 515, 518, 'neutral'],
#  ['17999', 'Price', 'кто', 519, 522, 'neutral'],
#  ['17999', 'Price', 'здесь', 645, 650, 'neutral'],
#  ['17999', 'Price', 'главное', 721, 728, 'neutral'],
#  ['17999', 'Price', 'довольно', 728, 736, 'neutral'],
#  ['17999', 'Price', 'оставлять', 786, 795, 'neutral'],
#  ['17999', 'Price', 'желать', 795, 801, 'neutral'],
#  ['22970', 'Service', 'обслуживание', 406, 418, 'positive'],
#  ['22970', 'Interior', 'интерьер', 21, 29, 'positive'],
#  ['22970', 'Service', 'официант', 312, 320, 'negative'],
#  ['22970', 'Food', 'кухня', 142, 147, 'positive'],
#  ['22970', 'Food', 'пиво', 285, 289, 'positive'],
#  ['22970', 'Interior', 'зал', 354, 357, 'positive'],
#  ['22970', 'Food', 'суп', 198, 201, 'neutral'],
#  ['22970', 'Food', 'съесть', 177, 183, 'neutral'],
#  ['22970', 'Food', 'кофе', 110, 114, 'neutral'],
#  ['22970', 'Food', 'выпить', 104, 110, 'neutral'],
#  ['22970', 'Food', 'пить', 244, 248, 'neutral'],
#  ['22970', 'Service', 'обслужить', 420, 429, 'positive'],
#  ['22970', 'Food', 'есть', 114, 118, 'positive'],
#  ['22970', 'Interior', 'вид из окно', 57, 68, 'positive'],
#  ['22970', 'Interior', 'вид из окно', 60, 71, 'neutral'],
#  ['22970', 'Interior', 'вид из окно', 62, 73, 'positive'],
#  ['22970', 'Service', 'подать', 223, 229, 'negative'],
#  ['22970', 'Interior', 'окно', 62, 66, 'positive'],
#  ['22970', 'Price', 'светло', 15, 21, 'neutral'],
#  ['22970', 'Price', 'поэтому', 128, 135, 'neutral'],
#  ['22970', 'Price', 'оценить', 135, 142, 'neutral'],
#  ['22970', 'Whole', 'достоинство', 149, 160, 'positive'],
#  ['22970', 'Food', 'я', 176, 177, 'neutral'],
#  ['22970', 'Price', 'булочка', 213, 220, 'positive'],
#  ['22970', 'Price', 'надеяться', 252, 261, 'positive'],
#  ['22970', 'Price', 'говорить', 289, 297, 'neutral'],
#  ['22970', 'Price', 'там', 300, 303, 'neutral'],
#  ['22970', 'Price', 'претензия', 320, 329, 'negative'],
#  ['22970', 'Price', 'мало', 357, 361, 'neutral'],
#  ['22970', 'Price', 'там', 300, 303, 'neutral'],
#  ['22970', 'Price', 'быстро', 429, 435, 'neutral'],
#  ['36407', 'Whole', 'ресторан', 41, 49, 'neutral'],
#  ['36407', 'Whole', 'место', 77, 82, 'positive'],
#  ['36407', 'Food', 'еда', 717, 720, 'positive'],
#  ['36407', 'Food', 'паста', 761, 766, 'positive'],
#  ['36407', 'Interior', 'столик', 478, 484, 'positive'],
#  ['36407', 'Food', 'поесть', 149, 155, 'positive'],
#  ['36407', 'Food', 'пицца', 745, 750, 'positive'],
#  ['36407', 'Food', 'закуска', 578, 585, 'positive'],
#  ['36407', 'Interior', 'стол', 587, 591, 'positive'],
#  ['36407', 'Service', 'человек', 685, 692, 'neutral'],
#  ['36407', 'Food', 'выпить', 155, 161, 'neutral'],
#  ['36407', 'Service', 'сотрудник', 384, 393, 'neutral'],
#  ['36407', 'Interior', 'детский комната', 91, 106, 'positive'],
#  ['36407', 'Interior', 'детский комната', 296, 311, 'neutral'],
#  ['36407', 'Whole', 'праздник', 98, 106, 'neutral'],
#  ['36407', 'Food', 'свинина', 792, 799, 'positive'],
#  ['36407', 'Food', 'есть', 965, 969, 'positive'],
#  ['36407', 'Food', 'лосось', 830, 836, 'positive'],
#  ['36407', 'Interior', 'украсить', 638, 646, 'positive'],
#  ['36407', 'Food', 'гриб', 800, 804, 'positive'],
#  ['36407', 'Price', 'бесплатно', 653, 662, 'neutral'],
#  ['36407', 'Service', 'няня', 316, 320, 'positive'],
#  ['36407', 'Interior', 'комната', 296, 303, 'neutral'],
#  ['36407', 'Price', 'март', 25, 29, 'neutral'],
#  ['36407', 'Price', 'отмечать', 29, 37, 'neutral'],
#  ['36407', 'Price', 'рождение', 53, 61, 'positive'],
#  ['36407', 'Price', 'сын', 61, 64, 'positive'],
#  ['36407', 'Price', 'выбирать', 69, 77, 'neutral'],
#  ['36407', 'Price', 'потому', 82, 88, 'neutral'],
#  ['36407', 'Price', 'вы', 109, 111, 'neutral'],
#  ['36407', 'Price', 'хотеть', 127, 133, 'neutral'],
#  ['36407', 'Price', 'ребёнок', 184, 191, 'neutral'],
#  ['36407', 'Price', 'конечно', 191, 198, 'neutral'],
#  ['36407', 'Price', 'разный', 240, 246, 'neutral'],
#  ['36407', 'Price', 'кто', 253, 256, 'neutral'],
#  ['36407', 'Price', 'интересно', 259, 268, 'neutral'],
#  ['36407', 'Price', 'чудесный', 281, 289, 'positive'],
#  ['36407', 'Price', 'замечательный', 303, 316, 'positive'],
#  ['36407', 'Price', 'ребёнок', 184, 191, 'neutral'],
#  ['36407', 'Price', 'при', 330, 333, 'neutral'],
#  ['36407', 'Price', 'что-то', 337, 343, 'neutral'],
#  ['36407', 'Price', 'что-то', 337, 343, 'neutral'],
#  ['36407', 'Price', 'молодец', 399, 406, 'positive'],
#  ['36407', 'Price', 'весь', 406, 410, 'neutral'],
#  ['36407', 'Price', 'себя', 431, 435, 'neutral'],
#  ['36407', 'Price', 'несколько', 451, 460, 'neutral'],
#  ['36407', 'Price', 'выбирать', 69, 77, 'neutral'],
#  ['36407', 'Price', 'говорить', 503, 511, 'neutral'],
#  ['36407', 'Price', 'поставить', 591, 600, 'neutral'],
#  ['36407', 'Price', 'даже', 629, 633, 'neutral'],
#  ['36407', 'Price', 'шарик', 633, 638, 'neutral'],
#  ['36407', 'Price', 'никто', 699, 704, 'neutral'],
#  ['36407', 'Price', 'кто', 253, 256, 'neutral'],
#  ['36407', 'Price', 'ребёнок', 184, 191, 'neutral'],
#  ['36407', 'Price', 'друг', 750, 754, 'positive'],
#  ['36407', 'Price', 'сытно', 843, 848, 'neutral'],
#  ['36407', 'Price', 'голова', 886, 892, 'neutral'],
#  ['36407', 'Price', 'чем', 895, 898, 'neutral'],
#  ['36407', 'Price', 'ребёнок', 184, 191, 'neutral'],
#  ['36407', 'Price', 'друг', 750, 754, 'positive'],
#  ['16714', 'Interior', 'интерьер', 384, 392, 'positive'],
#  ['16714', 'Service', 'официант', 334, 342, 'positive'],
#  ['16714', 'Food', 'кухня', 95, 100, 'positive'],
#  ['16714', 'Service', 'девушка', 591, 598, 'positive'],
#  ['16714', 'Service', 'администратор', 537, 550, 'positive'],
#  ['16714', 'Service', 'сервис', 300, 306, 'positive'],
#  ['16714', 'Interior', 'столик', 28, 34, 'positive'],
#  ['16714', 'Food', 'шашлык', 108, 114, 'positive'],
#  ['16714', 'Whole', 'впечатление', 323, 334, 'positive'],
#  ['16714', 'Service', 'работать', 550, 558, 'positive'],
#  ['16714', 'Food', 'овощ', 172, 176, 'positive'],
#  ['16714', 'Whole', 'праздник', 49, 57, 'positive'],
#  ['16714', 'Food', 'попробовать', 77, 88, 'positive'],
#  ['16714', 'Interior', 'заказывать столик', 28, 45, 'neutral'],
#  ['16714', 'Food', 'овощ на гриль', 172, 185, 'neutral'],
#  ['16714', 'Food', 'овощ на гриль', 57, 70, 'positive'],
#  ['16714', 'Price', 'воскресение', 59, 70, 'positive'],
#  ['16714', 'Price', 'немного', 88, 95, 'neutral'],
#  ['16714', 'Price', 'немного', 88, 95, 'neutral'],
#  ['16714', 'Price', 'достойный', 291, 300, 'neutral'],
#  ['16714', 'Price', 'оставлять', 306, 315, 'neutral'],
#  ['16714', 'Price', 'оценить', 404, 411, 'neutral'],
#  ['16714', 'Price', 'более', 424, 429, 'neutral'],
#  ['16714', 'Price', 'обед', 452, 456, 'positive'],
#  ['16714', 'Price', 'более', 424, 429, 'neutral'],
#  ['16714', 'Price', 'особенно', 498, 506, 'positive'],
#  ['16714', 'Price', 'выразить', 514, 522, 'positive'],
#  ['16714', 'Price', 'запомнить', 579, 588, 'neutral'],
#  ['16714', 'Price', 'выше', 651, 655, 'neutral'],
#  ['5648', 'Service', 'официант', 89, 97, 'positive'],
#  ['5648', 'Whole', 'заведение', 286, 295, 'positive'],
#  ['5648', 'Service', 'персонал', 7, 15, 'negative'],
#  ['5648', 'Service', 'обслуживать', 73, 84, 'positive'],
#  ['5648', 'Service', 'сервис', 399, 405, 'positive'],
#  ['5648', 'Service', 'заказ', 330, 335, 'positive'],
#  ['5648', 'Service', 'приносить', 113, 122, 'positive'],
#  ['5648', 'Service', 'человек', 445, 452, 'positive'],
#  ['5648', 'Service', 'ребята', 420, 426, 'neutral'],
#  ['5648', 'Service', 'заказывать', 129, 139, 'neutral'],
#  ['5648', 'Food', 'невский', 17, 24, 'positive'],
#  ['5648', 'Interior', 'окно', 51, 55, 'positive'],
#  ['5648', 'Food', 'кормить', 438, 445, 'neutral'],
#  ['5648', 'Service', 'клиент', 261, 267, 'negative'],
#  ['5648', 'Price', 'особенно', 32, 40, 'neutral'],
#  ['5648', 'Price', 'если', 40, 44, 'neutral'],
#  ['5648', 'Price', 'некурящий', 55, 64, 'positive'],
#  ['5648', 'Price', 'там', 64, 67, 'positive'],
#  ['5648', 'Price', 'всегда', 67, 73, 'neutral'],
#  ['5648', 'Price', 'новый', 84, 89, 'neutral'],
#  ['5648', 'Price', 'знающий', 102, 109, 'neutral'],
#  ['5648', 'Price', 'всегда', 67, 73, 'neutral'],
#  ['5648', 'Price', 'всегда', 67, 73, 'neutral'],
#  ['5648', 'Price', 'после', 267, 272, 'neutral'],
#  ['5648', 'Price', '2', 272, 273, 'neutral'],
#  ['5648', 'Price', 'месяц', 273, 278, 'positive'],
#  ['5648', 'Price', 'обед', 278, 282, 'positive'],
#  ['5648', 'Price', 'обед', 278, 282, 'positive'],
#  ['5648', 'Price', 'через', 317, 322, 'neutral'],
#  ['5648', 'Price', 'после', 267, 272, 'neutral'],
#  ['5648', 'Price', 'естественно', 335, 346, 'neutral'],
#  ['5648', 'Price', 'весь', 346, 350, 'neutral'],
#  ['5648', 'Price', 'желание', 366, 373, 'positive'],
#  ['5648', 'Price', 'сюда', 381, 385, 'neutral'],
#  ['5648', 'Price', 'если', 40, 44, 'neutral'],
#  ['5648', 'Price', 'вы', 430, 432, 'neutral'],
#  ['5648', 'Price', 'сложно', 432, 438, 'neutral'],
#  ['5648', 'Price', 'обед', 278, 282, 'positive'],
#  ['5648', 'Price', 'делать', 469, 475, 'neutral'],
#  ['37975', 'Whole', 'ресторан', 22, 30, 'positive'],
#  ['37975', 'Interior', 'интерьер', 176, 184, 'positive'],
#  ['37975', 'Whole', 'заведение', 810, 819, 'positive'],
#  ['37975', 'Food', 'блюдо', 415, 420, 'positive'],
#  ['37975', 'Service', 'персонал', 251, 259, 'positive'],
#  ['37975', 'Food', 'меню', 366, 370, 'neutral'],
#  ['37975', 'Interior', 'атмосфера', 193, 202, 'positive'],
#  ['37975', 'Service', 'обслуживать', 631, 642, 'positive'],
#  ['37975', 'Food', 'напиток', 320, 327, 'positive'],
#  ['37975', 'Interior', 'столик', 407, 413, 'positive'],
#  ['37975', 'Service', 'помочь', 383, 389, 'positive'],
#  ['37975', 'Service', 'приносить', 307, 316, 'positive'],
#  ['37975', 'Service', 'человек', 73, 80, 'positive'],
#  ['37975', 'Food', 'фрукт', 352, 357, 'negative'],
#  ['37975', 'Food', 'есть', 370, 374, 'positive'],
#  ['37975', 'Service', 'подать', 658, 664, 'negative'],
#  ['37975', 'Food', 'выбор', 376, 381, 'both'],
#  ['37975', 'Service', 'упаковать', 491, 500, 'positive'],
#  ['37975', 'Interior', 'спокойный', 184, 193, 'neutral'],
#  ['37975', 'Service', 'гость', 89, 94, 'negative'],
#  ['37975', 'Whole', 'банкет', 64, 70, 'neutral'],
#  ['37975', 'Food', 'банкетный меню', 357, 371, 'neutral'],
#  ['37975', 'Food', 'банкетный меню', 366, 380, 'neutral'],
#  ['37975', 'Food', 'блюдо из меню', 415, 428, 'negative'],
#  ['37975', 'Food', 'блюдо из меню', 420, 433, 'neutral'],
#  ['37975', 'Food', 'блюдо из меню', 366, 379, 'neutral'],
#  ['37975', 'Service', 'персонал ресторан', 251, 268, 'positive'],
#  ['37975', 'Service', 'персонал ресторан', 22, 39, 'positive'],
#  ['37975', 'Service', 'клиент', 762, 768, 'neutral'],
#  ['37975', 'Price', 'праздновать', 0, 11, 'positive'],
#  ['37975', 'Price', 'свадьба', 11, 18, 'positive'],
#  ['37975', 'Price', 'г', 41, 42, 'neutral'],
#  ['37975', 'Price', 'небольшой', 55, 64, 'positive'],
#  ['37975', 'Price', '6', 72, 73, 'neutral'],
#  ['37975', 'Price', 'качество', 81, 89, 'neutral'],
#  ['37975', 'Price', 'приехать', 160, 168, 'neutral'],
#  ['37975', 'Price', 'обходительный', 229, 242, 'positive'],
#  ['37975', 'Price', 'небольшой', 55, 64, 'positive'],
#  ['37975', 'Price', 'число', 286, 291, 'neutral'],
#  ['37975', 'Price', 'разрешить', 298, 307, 'positive'],
#  ['37975', 'Price', 'без', 327, 330, 'neutral'],
#  ['37975', 'Price', 'забрать', 471, 478, 'neutral'],
#  ['37975', 'Price', 'домой', 478, 483, 'neutral'],
#  ['37975', 'Price', 'вообщий', 538, 545, 'neutral'],
#  ['37975', 'Price', 'сергей', 623, 629, 'neutral'],
#  ['37975', 'Price', 'время', 665, 670, 'neutral'],
#  ['37975', 'Price', 'весь', 710, 714, 'neutral'],
#  ['37975', 'Price', 'желать', 730, 736, 'neutral'],
#  ['37975', 'Price', 'вы', 736, 738, 'positive'],
#  ['37975', 'Price', 'процветание', 743, 754, 'positive'],
#  ['37975', 'Price', 'посетить', 786, 794, 'neutral'],
#  ['37975', 'Price', 'замечательный', 797, 810, 'neutral'],
#  ['9662', 'Whole', 'ресторан', 100, 108, 'neutral'],
#  ['9662', 'Service', 'обслуживание', 330, 342, 'negative'],
#  ['9662', 'Interior', 'интерьер', 150, 158, 'positive'],
#  ['9662', 'Food', 'блюдо', 421, 426, 'positive'],
#  ['9662', 'Price', 'цена', 280, 284, 'positive'],
#  ['9662', 'Food', 'меню', 240, 244, 'positive'],
#  ['9662', 'Interior', 'музыка', 213, 219, 'positive'],
#  ['9662', 'Service', 'обслуживать', 362, 373, 'positive'],
#  ['9662', 'Food', 'напиток', 443, 450, 'neutral'],
#  ['9662', 'Service', 'принести', 450, 458, 'positive'],
#  ['9662', 'Interior', 'столик', 34, 40, 'positive'],
#  ['9662', 'Service', 'молодой человек', 386, 401, 'positive'],
#  ['9662', 'Service', 'молодой человек', 18, 33, 'positive'],
#  ['9662', 'Service', 'заказ', 470, 475, 'positive'],
#  ['9662', 'Whole', 'провести время', 484, 498, 'neutral'],
#  ['9662', 'Whole', 'провести время', 492, 506, 'positive'],
#  ['9662', 'Service', 'человек', 18, 25, 'positive'],
#  ['9662', 'Price', 'по цена', 278, 285, 'positive'],
#  ['9662', 'Price', 'по цена', 280, 287, 'neutral'],
#  ['9662', 'Food', 'готовиться', 284, 294, 'negative'],
#  ['9662', 'Service', 'бронировать', 40, 51, 'negative'],
#  ['9662', 'Price', 'вчера', 4, 9, 'neutral'],
#  ['9662', 'Price', '6', 17, 18, 'neutral'],
#  ['9662', 'Price', 'всегда', 67, 73, 'neutral'],
#  ['9662', 'Price', 'стоить', 73, 79, 'neutral'],
#  ['9662', 'Price', 'делать', 79, 85, 'neutral'],
#  ['9662', 'Price', 'абсолютно', 166, 175, 'positive'],
#  ['9662', 'Price', 'высокий', 193, 200, 'positive'],
#  ['9662', 'Price', 'тихий', 219, 224, 'neutral'],
#  ['9662', 'Price', 'интересный', 244, 254, 'positive'],
#  ['9662', 'Price', 'быстро', 299, 305, 'neutral'],
#  ['9662', 'Price', 'плохой', 324, 330, 'neutral'],
#  ['9662', 'Price', 'меняться', 426, 434, 'neutral'],
#  ['9662', 'Price', 'же', 463, 465, 'neutral'],
#  ['9662', 'Price', 'после', 465, 470, 'neutral'],
#  ['9662', 'Price', 'отлично', 477, 484, 'neutral'],
#  ['9662', 'Price', 'удовольствие', 498, 510, 'positive'],
#  ['10625', 'Whole', 'ресторан', 165, 173, 'positive'],
#  ['10625', 'Interior', 'интерьер', 381, 389, 'positive'],
#  ['10625', 'Whole', 'место', 809, 814, 'positive'],
#  ['10625', 'Food', 'блюдо', 859, 864, 'neutral'],
#  ['10625', 'Service', 'официантка', 509, 519, 'positive'],
#  ['10625', 'Food', 'салат', 611, 616, 'neutral'],
#  ['10625', 'Service', 'сервис', 501, 507, 'positive'],
#  ['10625', 'Interior', 'зал', 263, 266, 'neutral'],
#  ['10625', 'Whole', 'кафе', 32, 36, 'positive'],
#  ['10625', 'Whole', 'вечер', 128, 133, 'positive'],
#  ['10625', 'Service', 'принести', 191, 199, 'positive'],
#  ['10625', 'Interior', 'столик', 287, 293, 'positive'],
#  ['10625', 'Food', 'соус', 632, 636, 'negative'],
#  ['10625', 'Service', 'заказ', 565, 570, 'positive'],
#  ['10625', 'Service', 'предложить', 142, 152, 'positive'],
#  ['10625', 'Food', 'вкус', 406, 410, 'positive'],
#  ['10625', 'Food', 'кофе', 52, 56, 'neutral'],
#  ['10625', 'Service', 'повар', 652, 657, 'positive'],
#  ['10625', 'Food', 'салат цезарь', 611, 623, 'neutral'],
#  ['10625', 'Food', 'салат цезарь', 616, 628, 'positive'],
#  ['10625', 'Service', 'подходить', 444, 453, 'neutral'],
#  ['10625', 'Food', 'попить', 46, 52, 'neutral'],
#  ['10625', 'Food', 'попробовать', 830, 841, 'positive'],
#  ['10625', 'Food', 'цезарь', 616, 622, 'both'],
#  ['10625', 'Service', 'заказывать', 358, 368, 'neutral'],
#  ['10625', 'Food', 'пирожное', 57, 65, 'negative'],
#  ['10625', 'Whole', 'вечером', 9, 16, 'neutral'],
#  ['10625', 'Service', 'сделать заказ', 398, 411, 'positive'],
#  ['10625', 'Service', 'сделать заказ', 565, 578, 'positive'],
#  ['10625', 'Interior', 'спокойный', 389, 398, 'positive'],
#  ['10625', 'Food', 'готовиться', 702, 712, 'negative'],
#  ['10625', 'Food', 'итальянский блюдо', 848, 865, 'neutral'],
#  ['10625', 'Food', 'итальянский блюдо', 859, 876, 'neutral'],
#  ['10625', 'Whole', 'итальянский ресторан', 848, 868, 'neutral'],
#  ['10625', 'Whole', 'итальянский ресторан', 165, 185, 'positive'],
#  ['10625', 'Interior', 'вентиляция', 330, 340, 'positive'],
#  ['10625', 'Service', 'найти', 276, 281, 'positive'],
#  ['10625', 'Price', 'без', 69, 72, 'neutral'],
#  ['10625', 'Price', 'закрываться', 105, 116, 'neutral'],
#  ['10625', 'Price', 'ровно', 116, 121, 'neutral'],
#  ['10625', 'Price', 'курящий', 296, 303, 'neutral'],
#  ['10625', 'Price', 'сильно', 308, 314, 'neutral'],
#  ['10625', 'Price', 'без', 69, 72, 'neutral'],
#  ['10625', 'Price', 'чем', 464, 467, 'neutral'],
#  ['10625', 'Price', 'вдвоём', 484, 490, 'neutral'],
#  ['10625', 'Price', 'касаться', 493, 501, 'neutral'],
#  ['10625', 'Price', 'чтоб', 554, 558, 'neutral'],
#  ['10625', 'Price', 'без', 69, 72, 'neutral'],
#  ['10625', 'Price', 'лишь', 684, 688, 'neutral'],
#  ['10625', 'Food', 'майонез', 688, 695, 'neutral'],
#  ['10625', 'Price', 'одинаковый', 717, 727, 'neutral'],
#  ['10625', 'Price', 'весь', 730, 734, 'neutral'],
#  ['10625', 'Price', 'через', 740, 745, 'neutral'],
#  ['10625', 'Price', 'снова', 760, 765, 'neutral'],
#  ['10625', 'Price', 'вид', 791, 794, 'positive'],
#  ['10625', 'Price', 'снова', 760, 765, 'neutral'],
#  ['10625', 'Price', 'давно', 864, 869, 'neutral'],
#  ['10625', 'Price', 'хотеть', 872, 878, 'neutral'],
#  ['10625', 'Price', 'себя', 891, 895, 'neutral'],
#  ['10625', 'Price', 'вдруг', 921, 926, 'neutral'],
#  ['10625', 'Price', 'именно', 940, 946, 'neutral'],
#  ['2692', 'Whole', 'ресторан', 15, 23, 'positive'],
#  ['2692', 'Service', 'обслуживание', 200, 212, 'positive'],
#  ['2692', 'Interior', 'интерьер', 130, 138, 'positive'],
#  ['2692', 'Service', 'официант', 421, 429, 'positive'],
#  ['2692', 'Food', 'кухня', 32, 37, 'neutral'],
#  ['2692', 'Whole', 'место', 68, 73, 'positive'],
#  ['2692', 'Food', 'еда', 351, 354, 'positive'],
#  ['2692', 'Interior', 'зал', 371, 374, 'positive'],
#  ['2692', 'Service', 'ждать', 409, 414, 'neutral'],
#  ['2692', 'Interior', 'столик', 621, 627, 'positive'],
#  ['2692', 'Food', 'поесть', 97, 103, 'positive'],
#  ['2692', 'Interior', 'стол', 500, 504, 'positive'],
#  ['2692', 'Food', 'качество еда', 343, 355, 'positive'],
#  ['2692', 'Food', 'качество еда', 351, 363, 'negative'],
#  ['2692', 'Food', 'китайский кухня', 23, 38, 'neutral'],
#  ['2692', 'Food', 'китайский кухня', 32, 47, 'neutral'],
#  ['2692', 'Interior', 'бронировать столик', 621, 639, 'neutral'],
#  ['2692', 'Price', 'дорогой', 114, 121, 'negative'],
#  ['2692', 'Service', 'вынести', 519, 526, 'positive'],
#  ['2692', 'Interior', 'бронировать стол', 500, 516, 'neutral'],
#  ['2692', 'Service', 'владелец', 296, 304, 'positive'],
#  ['2692', 'Food', 'первый блюдо', 526, 538, 'neutral'],
#  ['2692', 'Price', 'весь', 2, 6, 'neutral'],
#  ['2692', 'Food', 'я', 14, 15, 'neutral'],
#  ['2692', 'Price', 'вы', 106, 108, 'neutral'],
#  ['2692', 'Price', 'вы', 106, 108, 'neutral'],
#  ['2692', 'Price', 'отличный', 167, 175, 'neutral'],
#  ['2692', 'Price', 'быстрый', 181, 188, 'neutral'],
#  ['2692', 'Price', 'качественный', 188, 200, 'neutral'],
#  ['2692', 'Price', 'год', 214, 217, 'neutral'],
#  ['2692', 'Price', 'год', 214, 217, 'neutral'],
#  ['2692', 'Price', 'становиться', 231, 242, 'neutral'],
#  ['2692', 'Price', 'плохой', 242, 248, 'negative'],
#  ['2692', 'Price', 'радовать', 259, 267, 'positive'],
#  ['2692', 'Price', 'себя', 328, 332, 'neutral'],
#  ['2692', 'Price', 'более', 354, 359, 'neutral'],
#  ['2692', 'Price', 'бывать', 384, 390, 'neutral'],
#  ['2692', 'Price', 'вы', 106, 108, 'neutral'],
#  ['2692', 'Price', 'или', 418, 421, 'neutral'],
#  ['2692', 'Price', 'февраль', 459, 466, 'neutral'],
#  ['2692', 'Price', '15', 549, 551, 'neutral'],
#  ['2692', 'Price', 'минус', 589, 594, 'neutral'],
#  ['34889', 'Whole', 'ресторан', 137, 145, 'neutral'],
#  ['34889', 'Interior', 'интерьер', 344, 352, 'positive'],
#  ['34889', 'Service', 'официант', 397, 405, 'positive'],
#  ['34889', 'Food', 'кухня', 145, 150, 'positive'],
#  ['34889', 'Whole', 'место', 702, 707, 'positive'],
#  ['34889', 'Food', 'блюдо', 392, 397, 'neutral'],
#  ['34889', 'Food', 'еда', 482, 485, 'positive'],
#  ['34889', 'Food', 'меню', 376, 380, 'positive'],
#  ['34889', 'Interior', 'атмосфера', 317, 326, 'positive'],
#  ['34889', 'Interior', 'десерт', 555, 561, 'positive'],
#  ['34889', 'Service', 'девушка', 274, 281, 'neutral'],
#  ['34889', 'Interior', 'музыка', 237, 243, 'positive'],
#  ['34889', 'Service', 'администратор', 281, 294, 'positive'],
#  ['34889', 'Interior', 'столик', 359, 365, 'positive'],
#  ['34889', 'Food', 'приготовить', 792, 803, 'neutral'],
#  ['34889', 'Whole', 'ресторанчик', 94, 105, 'neutral'],
#  ['34889', 'Food', 'вкус', 372, 376, 'neutral'],
#  ['34889', 'Food', 'пообедать', 105, 114, 'neutral'],
#  ['34889', 'Whole', 'аппетит', 75, 82, 'neutral'],
#  ['34889', 'Service', 'посоветовать', 434, 446, 'positive'],
#  ['34889', 'Food', 'разнообразие', 380, 392, 'neutral'],
#  ['34889', 'Food', 'выбор', 269, 274, 'positive'],
#  ['34889', 'Interior', 'уютный', 311, 317, 'positive'],
#  ['34889', 'Service', 'рекомендовать', 686, 699, 'positive'],
#  ['34889', 'Whole', 'посидеть', 723, 731, 'positive'],
#  ['34889', 'Service', 'найти', 808, 813, 'positive'],
#  ['34889', 'Price', 'центр', 7, 12, 'neutral'],
#  ['34889', 'Price', 'редкий', 50, 56, 'positive'],
#  ['34889', 'Price', 'тёплый', 56, 62, 'neutral'],
#  ['34889', 'Price', 'давно', 114, 119, 'neutral'],
#  ['34889', 'Price', 'посетить', 129, 137, 'neutral'],
#  ['34889', 'Price', 'недалеко', 155, 163, 'neutral'],
#  ['34889', 'Price', 'лёгкий', 195, 201, 'neutral'],
#  ['34889', 'Price', 'чисто', 365, 370, 'neutral'],
#  ['34889', 'Price', 'назвать', 417, 424, 'positive'],
#  ['34889', 'Price', 'ваш', 466, 469, 'neutral'],
#  ['34889', 'Price', 'замечательный', 494, 507, 'positive'],
#  ['34889', 'Price', 'быстро', 507, 513, 'positive'],
#  ['34889', 'Price', 'сытно', 513, 518, 'neutral'],
#  ['34889', 'Price', 'потрясать', 546, 555, 'positive'],
#  ['34889', 'Price', 'каждый', 655, 661, 'neutral'],
#  ['34889', 'Price', 'оценить', 670, 677, 'neutral'],
#  ['34889', 'Price', 'тем', 707, 710, 'neutral'],
#  ['34889', 'Price', 'кто', 710, 713, 'neutral'],
#  ['34889', 'Price', 'хотеть', 713, 719, 'neutral'],
#  ['34889', 'Price', 'бы', 719, 721, 'neutral'],
#  ['34889', 'Price', 'удовольствие', 759, 771, 'positive'],
#  ['34889', 'Price', 'качественно', 781, 792, 'neutral'],
#  ['34889', 'Price', 'минус', 813, 818, 'neutral'],
#  ['34889', 'Price', 'всегда', 818, 824, 'neutral'],
#  ['34889', 'Price', 'любой', 830, 835, 'neutral'],
#  ['34889', 'Price', 'бы', 719, 721, 'neutral'],
#  ['34889', 'Price', 'зависеть', 863, 871, 'negative'],
#  ['34889', 'Price', 'себя', 920, 924, 'neutral'],
#  ['34889', 'Price', 'минус', 813, 818, 'neutral'],
#  ['34889', 'Price', 'здесь', 941, 946, 'neutral'],
#  ['34889', 'Price', 'отличный', 956, 964, 'neutral'],
#  ['11421', 'Whole', 'ресторан', 8, 16, 'positive'],
#  ['11421', 'Service', 'обслуживание', 86, 98, 'positive'],
#  ['11421', 'Food', 'кухня', 235, 240, 'positive'],
#  ['11421', 'Food', 'блюдо', 211, 216, 'positive'],
#  ['11421', 'Food', 'меню', 155, 159, 'positive'],
#  ['11421', 'Interior', 'музыка', 314, 320, 'positive'],
#  ['11421', 'Service', 'заказать', 179, 187, 'neutral'],
#  ['11421', 'Food', 'ужинать', 57, 64, 'positive'],
#  ['11421', 'Food', 'разнообразие', 199, 211, 'neutral'],
#  ['11421', 'Food', 'выбор', 149, 154, 'both'],
#  ['11421', 'Interior', '2 этаж', 73, 79, 'neutral'],
#  ['11421', 'Interior', '2 этаж', 74, 80, 'neutral'],
#  ['11421', 'Price', 'удовольствие', 32, 44, 'positive'],
#  ['11421', 'Price', 'отличный', 78, 86, 'neutral'],
#  ['11421', 'Price', 'быстро', 118, 124, 'neutral'],
#  ['11421', 'Price', 'никакой', 243, 250, 'negative'],
#  ['11421', 'Price', 'музыкант', 287, 295, 'positive'],
#  ['11421', 'Price', 'отличный', 78, 86, 'neutral'],
#  ['11421', 'Price', 'удовольствие', 32, 44, 'positive'],
#  ['38299', 'Interior', 'интерьер', 268, 276, 'positive'],
#  ['38299', 'Service', 'официант', 415, 423, 'positive'],
#  ['38299', 'Whole', 'заведение', 59, 68, 'positive'],
#  ['38299', 'Food', 'еда', 494, 497, 'positive'],
#  ['38299', 'Food', 'порция', 724, 730, 'neutral'],
#  ['38299', 'Food', 'салат', 506, 511, 'positive'],
#  ['38299', 'Interior', 'обстановка', 161, 171, 'positive'],
#  ['38299', 'Interior', 'зал', 213, 216, 'positive'],
#  ['38299', 'Service', 'ждать', 438, 443, 'negative'],
#  ['38299', 'Food', 'напиток', 629, 636, 'neutral'],
#  ['38299', 'Food', 'мясо', 794, 798, 'positive'],
#  ['38299', 'Service', 'заказать', 498, 506, 'neutral'],
#  ['38299', 'Service', 'молодой человек', 384, 399, 'positive'],
#  ['38299', 'Service', 'заказ', 464, 469, 'positive'],
#  ['38299', 'Interior', 'диванчик', 202, 210, 'positive'],
#  ['38299', 'Service', 'человек', 384, 391, 'positive'],
#  ['38299', 'Food', 'коктейль', 650, 658, 'positive'],
#  ['38299', 'Food', 'говядина', 608, 616, 'neutral'],
#  ['38299', 'Food', 'овощ', 764, 768, 'neutral'],
#  ['38299', 'Service', 'принять заказ', 457, 470, 'neutral'],
#  ['38299', 'Service', 'принять заказ', 464, 477, 'neutral'],
#  ['38299', 'Service', 'посоветовать', 518, 530, 'neutral'],
#  ['38299', 'Food', 'есть', 333, 337, 'positive'],
#  ['38299', 'Service', 'подойти', 449, 456, 'both'],
#  ['38299', 'Food', 'салатик', 700, 707, 'positive'],
#  ['38299', 'Service', 'отдать', 237, 243, 'positive'],
#  ['38299', 'Interior', 'уютный', 155, 161, 'neutral'],
#  ['38299', 'Food', 'стейк рибай', 622, 633, 'positive'],
#  ['38299', 'Food', 'рибай', 622, 627, 'positive'],
#  ['38299', 'Food', 'салат с говядина', 506, 522, 'positive'],
#  ['38299', 'Food', 'салат с говядина', 353, 369, 'neutral'],
#  ['38299', 'Food', 'салат с говядина', 608, 624, 'positive'],
#  ['38299', 'Service', 'гость', 252, 257, 'positive'],
#  ['38299', 'Food', 'заправка', 741, 749, 'positive'],
#  ['38299', 'Food', 'больший порция', 724, 738, 'neutral'],
#  ['38299', 'Interior', 'комната', 370, 377, 'positive'],
#  ['38299', 'Price', 'купон', 26, 31, 'positive'],
#  ['38299', 'Food', 'кусок', 789, 794, 'positive'],
#  ['38299', 'Price', 'случайно', 0, 8, 'neutral'],
#  ['38299', 'Price', 'увидеть', 8, 15, 'positive'],
#  ['38299', 'Price', 'акция', 15, 20, 'positive'],
#  ['38299', 'Price', 'сайт', 22, 26, 'neutral'],
#  ['38299', 'Price', 'посетить', 48, 56, 'neutral'],
#  ['38299', 'Price', 'жить', 68, 72, 'positive'],
#  ['38299', 'Price', 'московский', 74, 84, 'neutral'],
#  ['38299', 'Price', 'открыться', 104, 113, 'neutral'],
#  ['38299', 'Price', 'новый', 122, 127, 'neutral'],
#  ['38299', 'Price', 'зря', 147, 150, 'neutral'],
#  ['38299', 'Price', 'часть', 232, 237, 'neutral'],
#  ['38299', 'Price', 'некурящий', 243, 252, 'neutral'],
#  ['38299', 'Price', 'радовать', 260, 268, 'neutral'],
#  ['38299', 'Price', 'отдельный', 337, 346, 'neutral'],
#  ['38299', 'Price', 'детский', 346, 353, 'neutral'],
#  ['38299', 'Price', 'быстро', 443, 449, 'neutral'],
#  ['38299', 'Price', 'профессионально', 477, 492, 'neutral'],
#  ['38299', 'Price', 'достаточно', 707, 717, 'neutral'],
#  ['38299', 'Price', 'интересный', 731, 741, 'neutral'],
#  ['38299', 'Price', 'сытый', 847, 852, 'positive'],
#  ['38299', 'Price', 'вы', 869, 871, 'neutral'],
#  ['38299', 'Price', 'даже', 871, 875, 'neutral'],
#  ['38299', 'Price', 'без', 875, 878, 'neutral'],
#  ['10985', 'Interior', 'интерьер', 229, 237, 'neutral'],
#  ['10985', 'Whole', 'заведение', 357, 366, 'positive'],
#  ['10985', 'Food', 'кухня', 542, 547, 'neutral'],
#  ['10985', 'Whole', 'место', 394, 399, 'neutral'],
#  ['10985', 'Food', 'блюдо', 492, 497, 'positive'],
#  ['10985', 'Service', 'официантка', 701, 711, 'positive'],
#  ['10985', 'Food', 'порция', 592, 598, 'positive'],
#  ['10985', 'Food', 'меню', 439, 443, 'positive'],
#  ['10985', 'Service', 'сервис', 695, 701, 'neutral'],
#  ['10985', 'Food', 'горячий', 635, 642, 'neutral'],
#  ['10985', 'Service', 'ждать', 788, 793, 'negative'],
#  ['10985', 'Service', 'принести', 624, 632, 'positive'],
#  ['10985', 'Interior', 'столик', 825, 831, 'positive'],
#  ['10985', 'Service', 'заказать', 418, 426, 'neutral'],
#  ['10985', 'Food', 'закуска', 585, 592, 'neutral'],
#  ['10985', 'Service', 'заказ', 745, 750, 'positive'],
#  ['10985', 'Price', 'счёт', 776, 780, 'neutral'],
#  ['10985', 'Interior', 'стол', 265, 269, 'positive'],
#  ['10985', 'Whole', 'ресторанчик', 36, 47, 'neutral'],
#  ['10985', 'Interior', 'диванчик', 237, 245, 'positive'],
#  ['10985', 'Food', 'покушать', 840, 848, 'neutral'],
#  ['10985', 'Food', 'говядина', 563, 571, 'neutral'],
#  ['10985', 'Interior', 'посуда', 649, 655, 'positive'],
#  ['10985', 'Food', 'свинина', 571, 578, 'neutral'],
#  ['10985', 'Interior', 'второй этаж', 192, 203, 'neutral'],
#  ['10985', 'Service', 'здороваться', 713, 724, 'positive'],
#  ['10985', 'Food', 'китайский кухня', 27, 42, 'positive'],
#  ['10985', 'Food', 'китайский кухня', 542, 557, 'neutral'],
#  ['10985', 'Food', 'сервировка', 656, 666, 'neutral'],
#  ['10985', 'Service', 'скатерть', 255, 263, 'positive'],
#  ['10985', 'Interior', 'столовая', 278, 286, 'negative'],
#  ['10985', 'Interior', 'танцполый', 142, 151, 'positive'],
#  ['10985', 'Interior', 'антураж', 922, 929, 'neutral'],
#  ['10985', 'Service', 'вынести', 761, 768, 'positive'],
#  ['10985', 'Interior', 'первый этаж', 79, 90, 'neutral'],
#  ['10985', 'Whole', 'китайский ресторан', 27, 45, 'positive'],
#  ['10985', 'Whole', 'китайский ресторанчик', 27, 48, 'positive'],
#  ['10985', 'Whole', 'китайский ресторанчик', 36, 57, 'neutral'],
#  ['10985', 'Interior', 'люстра', 307, 313, 'positive'],
#  ['10985', 'Price', 'недалеко', 6, 14, 'neutral'],
#  ['10985', 'Price', 'внутри', 124, 130, 'neutral'],
#  ['10985', 'Price', 'приятно', 206, 213, 'neutral'],
#  ['10985', 'Price', 'удивить', 213, 220, 'positive'],
#  ['10985', 'Price', 'тип', 271, 274, 'neutral'],
#  ['10985', 'Price', 'никакой', 341, 348, 'neutral'],
#  ['10985', 'Price', 'неуютный', 366, 374, 'negative'],
#  ['10985', 'Price', 'сила', 408, 412, 'positive'],
#  ['10985', 'Price', 'порадовать', 445, 455, 'positive'],
#  ['10985', 'Price', 'состав', 486, 492, 'positive'],
#  ['10985', 'Price', 'картинка', 502, 510, 'neutral'],
#  ['10985', 'Price', 'даже', 510, 514, 'neutral'],
#  ['10985', 'Price', 'знакомый', 547, 555, 'neutral'],
#  ['10985', 'Price', 'пара', 581, 585, 'neutral'],
#  ['10985', 'Price', 'конечно', 642, 649, 'neutral'],
#  ['10985', 'Price', 'бы', 674, 676, 'neutral'],
#  ['10985', 'Price', 'повод', 690, 695, 'neutral'],
#  ['10985', 'Price', 'быстро', 768, 774, 'neutral'],
#  ['10985', 'Price', 'при', 793, 796, 'neutral'],
#  ['10985', 'Price', 'занятый', 813, 820, 'neutral'],
#  ['10985', 'Price', 'весь', 820, 824, 'neutral'],
#  ['10985', 'Price', 'любить', 883, 889, 'positive'],
#  ['10985', 'Price', 'же', 892, 894, 'neutral'],
#  ['10985', 'Price', 'чтоб', 894, 898, 'neutral'],
#  ['7154', 'Whole', 'место', 325, 330, 'positive'],
#  ['7154', 'Service', 'персонал', 106, 114, 'positive'],
#  ['7154', 'Food', 'салат', 201, 206, 'neutral'],
#  ['7154', 'Interior', 'музыка', 287, 293, 'positive'],
#  ['7154', 'Food', 'готовить', 161, 169, 'positive'],
#  ['7154', 'Food', 'есть', 251, 255, 'positive'],
#  ['7154', 'Food', 'мясной', 195, 201, 'neutral'],
#  ['7154', 'Whole', 'посидеть', 80, 88, 'positive'],
#  ['7154', 'Service', 'советовать', 330, 340, 'positive'],
#  ['7154', 'Whole', 'банкет', 44, 50, 'positive'],
#  ['7154', 'Price', 'нравиться', 5, 14, 'positive'],
#  ['7154', 'Price', 'там', 33, 36, 'neutral'],
#  ['7154', 'Price', 'отмечать', 36, 44, 'positive'],
#  ['7154', 'Price', 'разный', 51, 57, 'neutral'],
#  ['7154', 'Price', 'всегда', 119, 125, 'positive'],
#  ['7154', 'Price', 'ночью', 139, 144, 'neutral'],
#  ['7154', 'Price', 'любить', 189, 195, 'positive'],
#  ['7154', 'Price', 'конечно', 212, 219, 'neutral'],
#  ['7154', 'Price', 'же', 219, 221, 'neutral'],
#  ['7154', 'Price', '=', 302, 303, 'neutral'],
#  ['7154', 'Price', 'вообщий', 303, 310, 'neutral'],
#  ['7154', 'Price', 'любить', 189, 195, 'positive'],
#  ['10798', 'Food', 'кухня', 247, 252, 'neutral'],
#  ['10798', 'Whole', 'место', 55, 60, 'positive'],
#  ['10798', 'Price', 'цена', 352, 356, 'neutral'],
#  ['10798', 'Service', 'девушка', 382, 389, 'positive'],
#  ['10798', 'Interior', 'музыка', 213, 219, 'positive'],
#  ['10798', 'Interior', 'обстановка', 127, 137, 'positive'],
#  ['10798', 'Service', 'сервис', 368, 374, 'positive'],
#  ['10798', 'Service', 'принести', 400, 408, 'neutral'],
#  ['10798', 'Service', 'молодой человек', 12, 27, 'neutral'],
#  ['10798', 'Service', 'молодой человек', 19, 34, 'positive'],
#  ['10798', 'Service', 'заказ', 408, 413, 'positive'],
#  ['10798', 'Whole', 'провести время', 102, 116, 'neutral'],
#  ['10798', 'Whole', 'провести время', 110, 124, 'positive'],
#  ['10798', 'Food', 'алкоголь', 431, 439, 'neutral'],
#  ['10798', 'Service', 'человек', 19, 26, 'positive'],
#  ['10798', 'Interior', 'свет', 209, 213, 'positive'],
#  ['10798', 'Interior', 'свеча', 162, 167, 'positive'],
#  ['10798', 'Food', 'японский кухня', 239, 253, 'neutral'],
#  ['10798', 'Food', 'японский кухня', 247, 261, 'neutral'],
#  ['10798', 'Interior', 'уютный', 121, 127, 'neutral'],
#  ['10798', 'Service', 'советовать', 511, 521, 'positive'],
#  ['10798', 'Food', 'европейский кухня', 290, 307, 'neutral'],
#  ['10798', 'Food', 'европейский кухня', 247, 264, 'neutral'],
#  ['10798', 'Food', 'вода', 168, 172, 'positive'],
#  ['10798', 'Service', 'нести заказ', 408, 419, 'negative'],
#  ['10798', 'Food', 'коктель', 423, 430, 'positive'],
#  ['10798', 'Interior', 'кресло', 193, 199, 'positive'],
#  ['10798', 'Price', 'действительно', 64, 77, 'neutral'],
#  ['10798', 'Price', 'стоить', 77, 83, 'neutral'],
#  ['10798', 'Price', 'каждый', 88, 94, 'neutral'],
#  ['10798', 'Price', 'приятно', 95, 102, 'neutral'],
#  ['10798', 'Price', 'тихий', 116, 121, 'neutral'],
#  ['10798', 'Price', 'мило', 148, 152, 'neutral'],
#  ['10798', 'Price', 'каждый', 88, 94, 'neutral'],
#  ['10798', 'Price', 'даже', 225, 229, 'neutral'],
#  ['10798', 'Price', 'сложно', 270, 276, 'neutral'],
#  ['10798', 'Price', 'достаточно', 336, 346, 'neutral'],
#  ['10798', 'Price', 'быстро', 394, 400, 'neutral'],
#  ['32859', 'Whole', 'ресторан', 38, 46, 'positive'],
#  ['32859', 'Interior', 'интерьер', 540, 548, 'positive'],
#  ['32859', 'Service', 'официант', 643, 651, 'positive'],
#  ['32859', 'Interior', 'зал', 485, 488, 'neutral'],
#  ['32859', 'Whole', 'вечер', 734, 739, 'positive'],
#  ['32859', 'Interior', 'стол', 605, 609, 'positive'],
#  ['32859', 'Food', 'оформить', 635, 643, 'neutral'],
#  ['32859', 'Service', 'шеф-повар', 364, 373, 'positive'],
#  ['32859', 'Whole', 'праздник', 791, 799, 'positive'],
#  ['32859', 'Food', 'есть', 343, 347, 'positive'],
#  ['32859', 'Service', 'администрация', 178, 191, 'positive'],
#  ['32859', 'Service', 'заказывать', 375, 385, 'neutral'],
#  ['32859', 'Whole', 'провести вечер', 726, 740, 'neutral'],
#  ['32859', 'Whole', 'провести вечер', 734, 748, 'positive'],
#  ['32859', 'Service', 'отношение', 209, 218, 'positive'],
#  ['32859', 'Service', 'встреча', 230, 237, 'positive'],
#  ['32859', 'Interior', 'уютный', 518, 524, 'positive'],
#  ['32859', 'Service', 'рекомендовать', 805, 818, 'positive'],
#  ['32859', 'Service', 'совет', 294, 299, 'positive'],
#  ['32859', 'Food', 'судак', 386, 391, 'neutral'],
#  ['32859', 'Service', 'дать', 283, 287, 'negative'],
#  ['32859', 'Service', 'выслушать', 258, 267, 'positive'],
#  ['32859', 'Service', 'отношение к свой дело', 209, 230, 'positive'],
#  ['32859', 'Service', 'отношение к свой дело', 218, 239, 'positive'],
#  ['32859', 'Service', 'отношение к свой дело', 219, 240, 'neutral'],
#  ['32859', 'Service', 'отношение к свой дело', 223, 244, 'positive'],
#  ['32859', 'Price', 'отмечать', 9, 17, 'neutral'],
#  ['32859', 'Price', 'рождение', 21, 29, 'positive'],
#  ['32859', 'Price', 'выразить', 59, 67, 'neutral'],
#  ['32859', 'Price', 'огромный', 67, 75, 'positive'],
#  ['32859', 'Price', 'благодарность', 75, 88, 'neutral'],
#  ['32859', 'Price', 'мало', 117, 121, 'neutral'],
#  ['32859', 'Price', 'важный', 121, 127, 'neutral'],
#  ['32859', 'Price', 'поблагодарить', 165, 178, 'neutral'],
#  ['32859', 'Price', 'отличный', 193, 201, 'positive'],
#  ['32859', 'Price', 'при', 227, 230, 'neutral'],
#  ['32859', 'Price', 'всегда', 237, 243, 'neutral'],
#  ['32859', 'Price', 'дружелюбный', 243, 254, 'positive'],
#  ['32859', 'Price', 'бы', 306, 308, 'neutral'],
#  ['32859', 'Price', 'порадовать', 321, 331, 'positive'],
#  ['32859', 'Price', 'сказка', 423, 429, 'positive'],
#  ['32859', 'Price', 'весь', 451, 455, 'neutral'],
#  ['32859', 'Price', 'отдельный', 548, 557, 'neutral'],
#  ['32859', 'Price', 'прекрасный', 586, 596, 'positive'],
#  ['32859', 'Price', 'дружелюбный', 243, 254, 'positive'],
#  ['32859', 'Price', 'улыбчивый', 663, 672, 'positive'],
#  ['32859', 'Price', 'делать', 675, 681, 'neutral'],
#  ['32859', 'Price', 'время', 682, 687, 'neutral'],
#  ['32859', 'Price', 'вы', 767, 769, 'neutral'],
#  ['32859', 'Price', 'огромный', 67, 75, 'positive'],
#  ['32859', 'Price', 'вы', 767, 769, 'neutral'],
#  ['32859', 'Price', 'весь', 451, 455, 'neutral'],
#  ['32859', 'Price', 'друг', 826, 830, 'positive'],
#  ['32859', 'Price', 'знакомый', 831, 839, 'positive'],
#  ['32859', 'Price', 'вы', 767, 769, 'neutral'],
#  ['32859', 'Price', 'процветание', 847, 858, 'positive'],
#  ['32859', 'Price', 'виктория', 867, 875, 'positive'],
#  ['1269', 'Service', 'обслуживание', 526, 538, 'positive'],
#  ['1269', 'Interior', 'интерьер', 198, 206, 'positive'],
#  ['1269', 'Food', 'кухня', 242, 247, 'positive'],
#  ['1269', 'Food', 'блюдо', 622, 627, 'positive'],
#  ['1269', 'Food', 'напиток', 627, 634, 'neutral'],
#  ['1269', 'Interior', 'стол', 225, 229, 'positive'],
#  ['1269', 'Service', 'человек', 289, 296, 'positive'],
#  ['1269', 'Whole', 'впечатление', 30, 41, 'positive'],
#  ['1269', 'Service', 'работать', 308, 316, 'positive'],
#  ['1269', 'Whole', 'праздник', 843, 851, 'positive'],
#  ['1269', 'Interior', 'посуда', 601, 607, 'negative'],
#  ['1269', 'Service', 'отношение', 715, 724, 'positive'],
#  ['1269', 'Service', 'убираться', 586, 595, 'positive'],
#  ['1269', 'Service', 'приветливый', 658, 669, 'positive'],
#  ['1269', 'Food', 'сервировка', 215, 225, 'positive'],
#  ['1269', 'Whole', 'банкет', 357, 363, 'positive'],
#  ['1269', 'Price', 'хотеть', 10, 16, 'neutral'],
#  ['1269', 'Price', 'свадьба', 42, 49, 'positive'],
#  ['1269', 'Price', 'ваш', 85, 88, 'neutral'],
#  ['1269', 'Price', 'год', 108, 111, 'neutral'],
#  ['1269', 'Price', 'если', 116, 120, 'neutral'],
#  ['1269', 'Price', 'именно', 175, 181, 'neutral'],
#  ['1269', 'Price', 'замечательный', 185, 198, 'neutral'],
#  ['1269', 'Price', 'свадебный', 348, 357, 'positive'],
#  ['1269', 'Whole', 'александр', 393, 402, 'neutral'],
#  ['1269', 'Price', 'доброжелательный', 415, 431, 'positive'],
#  ['1269', 'Price', 'знающий', 431, 438, 'positive'],
#  ['1269', 'Price', 'появляться', 607, 617, 'neutral'],
#  ['1269', 'Price', 'новый', 617, 622, 'neutral'],
#  ['1269', 'Price', 'улыбка', 669, 675, 'positive'],
#  ['1269', 'Price', 'вы', 682, 684, 'neutral'],
#  ['1269', 'Price', 'огромный', 684, 692, 'neutral'],
#  ['1269', 'Price', 'ваш', 85, 88, 'neutral'],
#  ['1269', 'Price', 'ваш', 85, 88, 'neutral'],
#  ['1269', 'Price', 'вы', 682, 684, 'neutral'],
#  ['1269', 'Price', 'благодарность', 790, 803, 'positive'],
#  ['1269', 'Price', 'вместе', 863, 869, 'positive'],
#  ['1269', 'Price', 'устроить', 869, 877, 'neutral'],
#  ['1269', 'Price', 'вы', 682, 684, 'neutral'],
#  ['1269', 'Price', 'огромный', 684, 692, 'neutral'],
#  ['1269', 'Price', 'вы', 682, 684, 'neutral'],
#  ['1269', 'Price', 'ваш', 85, 88, 'neutral'],
#  ['1269', 'Price', 'вы', 682, 684, 'neutral'],
#  ['1269', 'Price', 'благодарный', 935, 946, 'neutral'],
#  ['1269', 'Price', 'посетитель', 946, 956, 'positive'],
#  ['37220', 'Whole', 'ресторан', 576, 584, 'neutral'],
#  ['37220', 'Interior', 'интерьер', 22, 30, 'positive'],
#  ['37220', 'Food', 'кухня', 0, 5, 'positive'],
#  ['37220', 'Service', 'официантка', 142, 152, 'positive'],
#  ['37220', 'Service', 'девушка', 114, 121, 'positive'],
#  ['37220', 'Interior', 'столик', 245, 251, 'neutral'],
#  ['37220', 'Interior', 'стол', 350, 354, 'neutral'],
#  ['37220', 'Service', 'повар', 17, 22, 'neutral'],
#  ['37220', 'Service', 'работать', 134, 142, 'neutral'],
#  ['37220', 'Service', 'менеджер', 165, 173, 'neutral'],
#  ['37220', 'Food', 'есть', 66, 70, 'neutral'],
#  ['37220', 'Whole', 'хозяин', 595, 601, 'neutral'],
#  ['37220', 'Service', 'гость', 88, 93, 'neutral'],
#  ['37220', 'Service', 'ответить', 269, 277, 'positive'],
#  ['37220', 'Price', 'более', 57, 62, 'neutral'],
#  ['37220', 'Price', 'год', 63, 66, 'neutral'],
#  ['37220', 'Price', 'постоянный', 78, 88, 'neutral'],
#  ['37220', 'Price', 'желание', 188, 195, 'positive'],
#  ['37220', 'Price', 'спросить', 211, 219, 'neutral'],
#  ['37220', 'Price', 'ли', 227, 229, 'neutral'],
#  ['37220', 'Price', 'именно', 299, 305, 'neutral'],
#  ['37220', 'Price', 'если', 372, 376, 'neutral'],
#  ['37220', 'Price', 'вы', 385, 387, 'neutral'],
#  ['37220', 'Price', 'здесь', 393, 398, 'neutral'],
#  ['37220', 'Price', 'там', 435, 438, 'neutral'],
#  ['37220', 'Price', 'после', 475, 480, 'neutral'],
#  ['37220', 'Price', 'желание', 188, 195, 'positive'],
#  ['37220', 'Price', 'ни', 508, 510, 'neutral'],
#  ['37220', 'Price', 'кто', 511, 514, 'neutral'],
#  ['37220', 'Price', 'вы', 385, 387, 'neutral'],
#  ['37220', 'Price', 'ваш', 557, 560, 'neutral'],
#  ['37220', 'Price', 'вы', 385, 387, 'neutral'],
#  ['37220', 'Price', 'кто', 511, 514, 'neutral'],
#  ['37220', 'Price', 'здесь', 393, 398, 'neutral'],
#  ['37220', 'Price', 'кто', 511, 514, 'neutral'],
#  ['6668', 'Whole', 'ресторан', 552, 560, 'positive'],
#  ['6668', 'Service', 'обслуживание', 403, 415, 'positive'],
#  ['6668', 'Service', 'официант', 893, 901, 'positive'],
#  ['6668', 'Service', 'персонал', 1005, 1013, 'neutral'],
#  ['6668', 'Food', 'порция', 822, 828, 'positive'],
#  ['6668', 'Food', 'салат', 614, 619, 'positive'],
#  ['6668', 'Interior', 'десерт', 883, 889, 'positive'],
#  ['6668', 'Service', 'обслуживать', 423, 434, 'positive'],
#  ['6668', 'Service', 'сервис', 397, 403, 'neutral'],
#  ['6668', 'Food', 'горячий', 648, 655, 'neutral'],
#  ['6668', 'Service', 'ждать', 643, 648, 'negative'],
#  ['6668', 'Food', 'вино', 509, 513, 'neutral'],
#  ['6668', 'Service', 'принести', 524, 532, 'positive'],
#  ['6668', 'Interior', 'столик', 576, 582, 'positive'],
#  ['6668', 'Service', 'заказ', 475, 480, 'positive'],
#  ['6668', 'Food', 'чай', 611, 614, 'neutral'],
#  ['6668', 'Food', 'готовить', 619, 627, 'neutral'],
#  ['6668', 'Whole', 'ресторанчик', 27, 38, 'positive'],
#  ['6668', 'Service', 'помочь', 468, 474, 'positive'],
#  ['6668', 'Service', 'человек', 589, 596, 'positive'],
#  ['6668', 'Service', 'встречать', 442, 451, 'positive'],
#  ['6668', 'Food', 'пить', 607, 611, 'neutral'],
#  ['6668', 'Food', 'ужин', 1045, 1049, 'neutral'],
#  ['6668', 'Service', 'посоветовать', 480, 492, 'positive'],
#  ['6668', 'Food', 'телятина', 731, 739, 'neutral'],
#  ['6668', 'Food', 'есть', 942, 946, 'neutral'],
#  ['6668', 'Service', 'заказ принести', 475, 489, 'positive'],
#  ['6668', 'Service', 'заказ принести', 524, 538, 'positive'],
#  ['6668', 'Food', 'наесться', 854, 862, 'positive'],
#  ['6668', 'Whole', 'вечером', 45, 52, 'neutral'],
#  ['6668', 'Service', 'работа', 254, 260, 'positive'],
#  ['6668', 'Service', 'показать', 135, 143, 'positive'],
#  ['6668', 'Service', 'советовать', 906, 916, 'positive'],
#  ['6668', 'Service', 'гость', 152, 157, 'positive'],
#  ['6668', 'Service', 'выбрать', 222, 229, 'positive'],
#  ['6668', 'Price', 'недорогой', 500, 509, 'neutral'],
#  ['6668', 'Service', 'персонал ресторан', 1005, 1022, 'neutral'],
#  ['6668', 'Service', 'персонал ресторан', 552, 569, 'positive'],
#  ['6668', 'Food', 'кормить', 83, 90, 'positive'],
#  ['6668', 'Interior', 'красота', 180, 187, 'positive'],
#  ['6668', 'Price', 'посетить', 2, 10, 'neutral'],
#  ['6668', 'Price', 'нигде', 76, 81, 'neutral'],
#  ['6668', 'Price', 'плохой', 113, 119, 'neutral'],
#  ['6668', 'Price', 'пытаться', 127, 135, 'neutral'],
#  ['6668', 'Price', 'приехать', 143, 151, 'neutral'],
#  ['6668', 'Price', 'ночь', 207, 211, 'neutral'],
#  ['6668', 'Price', 'повод', 306, 311, 'neutral'],
#  ['6668', 'Price', 'ночь', 207, 211, 'neutral'],
#  ['6668', 'Price', 'слово', 392, 397, 'neutral'],
#  ['6668', 'Price', 'по-домашнему', 456, 468, 'positive'],
#  ['6668', 'Price', 'быстро', 534, 540, 'neutral'],
#  ['6668', 'Price', 'занятый', 564, 571, 'neutral'],
#  ['6668', 'Price', 'весь', 571, 575, 'neutral'],
#  ['6668', 'Price', 'там', 583, 586, 'neutral'],
#  ['6668', 'Price', 'давно', 596, 601, 'neutral'],
#  ['6668', 'Price', 'минута', 627, 633, 'neutral'],
#  ['6668', 'Price', 'потом', 635, 640, 'neutral'],
#  ['6668', 'Price', 'время', 666, 671, 'neutral'],
#  ['6668', 'Food', 'буженина', 745, 753, 'neutral'],
#  ['6668', 'Price', 'гриль', 755, 760, 'neutral'],
#  ['6668', 'Price', 'довольно', 786, 794, 'neutral'],
#  ['6668', 'Price', 'огромный', 830, 838, 'neutral'],
#  ['6668', 'Price', 'повод', 306, 311, 'neutral'],
#  ['6668', 'Price', 'хотеть', 972, 978, 'neutral'],
#  ['18983', 'Whole', 'ресторан', 20, 28, 'positive'],
#  ['18983', 'Service', 'обслуживание', 285, 297, 'positive'],
#  ['18983', 'Interior', 'интерьер', 357, 365, 'positive'],
#  ['18983', 'Service', 'официант', 310, 318, 'positive'],
#  ['18983', 'Whole', 'заведение', 497, 506, 'positive'],
#  ['18983', 'Whole', 'место', 545, 550, 'positive'],
#  ['18983', 'Food', 'еда', 50, 53, 'positive'],
#  ['18983', 'Interior', 'десерт', 204, 210, 'positive'],
#  ['18983', 'Interior', 'музыка', 404, 410, 'positive'],
#  ['18983', 'Interior', 'обстановка', 347, 357, 'neutral'],
#  ['18983', 'Food', 'мясо', 122, 126, 'positive'],
#  ['18983', 'Food', 'соус', 153, 157, 'negative'],
#  ['18983', 'Food', 'рыба', 115, 119, 'positive'],
#  ['18983', 'Food', 'вкус', 135, 139, 'neutral'],
#  ['18983', 'Food', 'мороженое', 227, 236, 'positive'],
#  ['18983', 'Whole', 'впечатление', 29, 40, 'positive'],
#  ['18983', 'Food', 'есть', 318, 322, 'positive'],
#  ['18983', 'Service', 'приветливый', 322, 333, 'positive'],
#  ['18983', 'Food', 'приготовление', 271, 284, 'neutral'],
#  ['18983', 'Interior', 'свободный место', 536, 551, 'neutral'],
#  ['18983', 'Interior', 'свободный место', 545, 560, 'positive'],
#  ['18983', 'Whole', 'китайский ресторан', 95, 113, 'neutral'],
#  ['18983', 'Whole', 'китайский ресторан', 20, 38, 'positive'],
#  ['18983', 'Price', 'несколько', 0, 9, 'neutral'],
#  ['18983', 'Price', 'достаточно', 53, 63, 'neutral'],
#  ['18983', 'Price', 'тем', 148, 151, 'neutral'],
#  ['18983', 'Price', 'же', 151, 153, 'neutral'],
#  ['18983', 'Price', 'конечно', 160, 167, 'neutral'],
#  ['18983', 'Food', 'я', 210, 211, 'neutral'],
#  ['18983', 'Price', 'естественно', 255, 266, 'neutral'],
#  ['18983', 'Price', '2', 284, 285, 'neutral'],
#  ['18983', 'Price', 'зависеть', 300, 308, 'negative'],
#  ['18983', 'Price', 'довольно', 365, 373, 'neutral'],
#  ['18983', 'Price', 'слишком', 410, 417, 'negative'],
#  ['18983', 'Price', 'русский', 441, 448, 'neutral'],
#  ['18983', 'Price', 'плюс', 465, 469, 'neutral'],
#  ['18983', 'Price', 'всегда', 506, 512, 'neutral'],
#  ['18983', 'Price', 'мало', 512, 516, 'neutral'],
#  ['18983', 'Price', 'всегда', 506, 512, 'neutral'],
#  ['32856', 'Service', 'обслуживание', 77, 89, 'positive'],
#  ['32856', 'Whole', 'заведение', 862, 871, 'positive'],
#  ['32856', 'Food', 'кухня', 71, 76, 'positive'],
#  ['32856', 'Food', 'салат', 640, 645, 'positive'],
#  ['32856', 'Interior', 'десерт', 724, 730, 'positive'],
#  ['32856', 'Interior', 'обстановка', 440, 450, 'positive'],
#  ['32856', 'Interior', 'зал', 194, 197, 'neutral'],
#  ['32856', 'Service', 'заказ', 435, 440, 'neutral'],
#  ['32856', 'Interior', 'стол', 197, 201, 'positive'],
#  ['32856', 'Interior', 'диван', 414, 419, 'positive'],
#  ['32856', 'Food', 'покушать', 165, 173, 'neutral'],
#  ['32856', 'Service', 'встречать', 116, 125, 'positive'],
#  ['32856', 'Service', 'ребята', 553, 559, 'positive'],
#  ['32856', 'Service', 'принять заказ', 428, 441, 'neutral'],
#  ['32856', 'Service', 'принять заказ', 435, 448, 'neutral'],
#  ['32856', 'Whole', 'праздник', 882, 890, 'positive'],
#  ['32856', 'Service', 'заказывать', 203, 213, 'neutral'],
#  ['32856', 'Service', 'отношение', 969, 978, 'positive'],
#  ['32856', 'Interior', 'тарелка', 494, 501, 'negative'],
#  ...]

# %%
def review_sent_estimate(sent_extracted_data):

# %% [markdown]
# ### Шаблон для тестирования программы

# %%
from pymorphy2 import MorphAnalyzer
from pymorphy2.tokenizers import simple_word_tokenize

# %%
punct = '/.,:;!?"<>(){}[]*-+'
m = MorphAnalyzer()
def normalize_text(text):
    lemmas = []
    for t in simple_word_tokenize(text):
        if t not in punct:
            lemmas.append(
                m.parse(t)[0].normal_form
            )
    return ' '.join(lemmas)

# %%
with open('tfidf_data.txt', 'w') as f:
    rare_words = f.read().split(' ')

# %%
with open('furnit_list.txt', encoding = 'utf-8') as file:
    f = file.readlines()
    furniture_list = []
    for line in f:
        line = line.rstrip('\r\n').lower()
        furniture_list.append(line)

# %%
with open('dishes_list_from_wiki.txt', encoding = 'utf-8') as file2:
    f2 = file2.readlines()
    dishes_list = []
    for line in f2:
        line = line.rstrip('\r\n').lower()
        dishes_list.append(line)

# %%
with open ('kartaslovsent.csv', encoding = 'utf-8') as csvfile:
    f = csv.reader(csvfile, delimiter=';')
    sent_dict = {}
    for row in f:
        if row[1] == 'NEUT':
            sent_dict[row[0]] = 'neutral'
        elif row[1] == 'NGTV':
            sent_dict[row[0]] = 'negative'
        elif row[1] == 'PSTV':
            sent_dict[row[0]] = 'positive'

# %%
from keybert import KeyBERT
kw_model = KeyBERT('clips/mfaq')

# %%
def keybert_extractor(text):
    kbert_text = kw_model.extract_keywords(text, keyphrase_ngram_range=(1, 3), stop_words=None)
    key_bert_list = []
    key_bert_list_tokens = []
    for elem in kbert_text:
        key_bert_list.append(elem[0])
        key_bert_list_tokens.extend(elem.split(' '))
    return key_bert_list, key_bert_list_tokens

# %%
texts, ids, norm_texts, norm_tokenized_texts, list_of_final_data = cat_mentions_extractor(name_of_file)

# %%
sent_extracted_data = sent_extractor (list_of_final_data)
sent_extracted_data_final = []
for line in sent_extracted_data:
    sent_extracted_data_final.append(line[1:7])
sent_extracted_data_final

# %%
review_sent_estimate
